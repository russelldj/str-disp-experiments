# %% [markdown]
# # Imports

# %%
import shutil
import os
import logging
from pathlib import Path
import subprocess

# Contributed library imports
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread
from pathlib import Path

# %% [markdown]
# # Define constants

# %%
training_sites = sorted(["delta", "valley"])

# %%
IDs_TO_LABELS = {
    0: "ABCO",
    1: "CADE",
    2: "PILA",
    3: "PIPO",
    4: "PSME",
    5: "QUEV",
    6: "SNAG",
    7: "ground",
}

## Python interpreter and script locations
MMSEG_UTILS_PYTHON = "/ofo-share/repos-david/conda/envs/mmseg-utils/bin/python"
MMSEG_PYTHON = "/ofo-share/repos-david/conda/envs/openmmlab/bin/python"

FOLDER_TO_CITYSCAPES_SCRIPT = "/ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py"
VIS_PREDS_SCRIPT = "/ofo-share/repos-david/mmsegmentation_utils/dev/visualization/visualize_semantic_labels.py"
TRAIN_SCRIPT = "/ofo-share/repos-david/mmsegmentation/tools/train.py"

LONG_SITE_NAME_DICT = {"valley": "ValleyA", "chips": "ChipsB", "delta": "DeltaB"}

# One folder up from scripts
PROJECT_ROOT = Path(os.path.abspath(""), "..", "..", "..").resolve()
SCRATCH_ROOT = Path(Path.home(), "scratch", "organized_str_disp_MVMT_experiments")

TRAINING_SITES_STR = "_".join(training_sites)
TRAINING_IMGS_EXT = ".png"

TRAINING_DATA_FOLDER_SCRATCH = Path(
    SCRATCH_ROOT,
    "models",
    "multi_site",
    f"ortho_{TRAINING_SITES_STR}",
)
TRAINING_DATA_FOLDER = Path(
    PROJECT_ROOT,
    "models",
    "multi_site",
    f"ortho_{TRAINING_SITES_STR}",
)
AGGREGATED_LABELS_FOLDER = Path(TRAINING_DATA_FOLDER_SCRATCH, "inputs", "labels")
AGGREGATED_IMAGES_FOLDER = Path(TRAINING_DATA_FOLDER_SCRATCH, "inputs", "images")
WORK_DIR = Path(TRAINING_DATA_FOLDER_SCRATCH, "work_dir")

# %%
logging.basicConfig(level="INFO")

# %%
# We need to merge all the imagery together
# I think this should be stored in the models folder, alongside the real models
# It should be as simple as creating the folders and symlinking the existing ones into it
Path(AGGREGATED_IMAGES_FOLDER).mkdir(exist_ok=True, parents=True)
Path(AGGREGATED_LABELS_FOLDER).mkdir(exist_ok=True, parents=True)

for training_site in training_sites:
    long_site_name = LONG_SITE_NAME_DICT[training_site]

    TRAINING_CHIPS_FOLDER = Path(
        PROJECT_ROOT,
        "per_site_processing",
        training_site,
        "03_training_data",
        f"ortho_chipped_images_{training_site}",
    )
    render_folder = Path(TRAINING_CHIPS_FOLDER, "anns")
    image_folder = Path(TRAINING_CHIPS_FOLDER, "imgs")

    output_render_folder = Path(AGGREGATED_LABELS_FOLDER, training_site)
    output_image_folder = Path(AGGREGATED_IMAGES_FOLDER, training_site)

    # Remove if folder
    shutil.rmtree(output_render_folder, ignore_errors=True)
    shutil.rmtree(output_image_folder, ignore_errors=True)
    # Unlink if symlink
    output_render_folder.unlink(missing_ok=True)
    output_image_folder.unlink(missing_ok=True)
    print(output_render_folder)
    shutil.copytree(render_folder, output_render_folder)
    shutil.copytree(image_folder, output_image_folder)
# Out:
# /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/inputs/labels/delta
# /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/inputs/labels/valley

# %%
class_names = list(IDs_TO_LABELS.values())
class_names_str = " ".join(class_names)
print(class_names_str)

run_str = (
    f"{MMSEG_UTILS_PYTHON} {FOLDER_TO_CITYSCAPES_SCRIPT} --images-folder {AGGREGATED_IMAGES_FOLDER}"
    + f" --labels-folder {AGGREGATED_LABELS_FOLDER} --output-folder {TRAINING_DATA_FOLDER_SCRATCH} "
    + f"--classes {class_names_str} --image-ext {TRAINING_IMGS_EXT} --remove-old "
)
print(run_str)
subprocess.run(
    run_str,
    shell=True,
)
# Out:
# ABCO CADE PILA PIPO PSME QUEV SNAG ground
# /ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/inputs/images --labels-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/inputs/labels --output-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley --classes ABCO CADE PILA PIPO PSME QUEV SNAG ground --image-ext .png --remove-old
# Checking for completely null images: 100%|██████████| 54/54 [00:03<00:00, 15.48it/s]
# Linking files into either train or test folders: 100%|██████████| 54/54 [00:00<00:00, 12314.06it/s]
# 100%|██████████| 20/20 [00:10<00:00,  1.85it/s]
# (2661581, 3)
# mean: [117.56689651752097, 118.13267828407251, 111.02864725890363], std: [62.43623312608687, 58.107059832482165, 54.31533857521856]
# About to save config to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/ortho_delta_valley.py
# visualizing to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/vis/train: 100%|██████████| 3/3 [00:43<00:00, 14.37s/it]
# visualizing to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/vis/val: 100%|██████████| 1/1 [00:13<00:00, 13.99s/it]
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/inputs/images --labels-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/inputs/labels --output-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley --classes ABCO CADE PILA PIPO PSME QUEV SNAG ground --image-ext .png --remove-old ', returncode=0)

# %% [markdown]
# # Show some of the formatted example images

# %%
cmap_file = Path(TRAINING_DATA_FOLDER_SCRATCH, "colormap.png")
plt.imshow(imread(cmap_file))
plt.show()

vis_folder = Path(TRAINING_DATA_FOLDER_SCRATCH, "vis")
vis_files = list(vis_folder.rglob("*" + TRAINING_IMGS_EXT))
for file in np.random.choice(vis_files, 10):
    print(f"showing {file}")
    plt.imshow(imread(file))
    plt.show()
# Out:
# /tmp/ipykernel_47311/380572230.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(cmap_file))
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/vis/train/delta_delta:10944:54720:3648:3648_rgb.png
# /tmp/ipykernel_47311/380572230.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(file))
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/vis/train/delta_delta:23712:18240:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/vis/train/delta_delta:23712:18240:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/vis/train/delta_delta:10944:54720:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/vis/val/delta_delta:10944:52896:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/vis/val/delta_delta:10944:52896:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/vis/val/delta_delta:10944:52896:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/vis/train/delta_delta:23712:18240:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/vis/train/delta_delta:10944:54720:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/vis/train/delta_delta:10944:54720:3648:3648_rgb.png

# %% [markdown]
# # Train a model

# %%
# Identify the config file as the only python file in the
config_file = list(Path(TRAINING_DATA_FOLDER_SCRATCH).glob("*py"))[0]
subprocess.run(
    f"{MMSEG_PYTHON} {TRAIN_SCRIPT} " + f"{config_file} --work-dir {WORK_DIR} --resume",
    shell=True,
)
# Out:
# 02/09 23:59:53 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 765840050
#     GPU 0: GRID A100X-20C
#     CUDA_HOME: /ofo-share/repos-david/conda/envs/MVMT-stable
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 765840050
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/09 23:59:54 - mmengine - INFO - Config:
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[117.56689651752097, 118.13267828407251, 111.02864725890363],
#     std=[62.43623312608687, 58.107059832482165, 54.31533857521856],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(1024, 1024))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[117.56689651752097, 118.13267828407251, 111.02864725890363],
#         std=[62.43623312608687, 58.107059832482165, 54.31533857521856],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(1024, 1024)),
#     pretrained=None,
#     backbone=dict(
#         type='MixVisionTransformer',
#         in_channels=3,
#         embed_dims=64,
#         num_stages=4,
#         num_layers=[3, 6, 40, 3],
#         num_heads=[1, 2, 5, 8],
#         patch_sizes=[7, 3, 3, 3],
#         sr_ratios=[8, 4, 2, 1],
#         out_indices=(0, 1, 2, 3),
#         mlp_ratio=4,
#         qkv_bias=True,
#         drop_rate=0.0,
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
#         )),
#     decode_head=dict(
#         type='SegformerHead',
#         in_channels=[64, 128, 320, 512],
#         in_index=[0, 1, 2, 3],
#         channels=256,
#         dropout_ratio=0.1,
#         num_classes=8,
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='slide', crop_size=(1024, 1024), stride=(768, 768)))
# dataset_type = 'CityscapesForestsDataset'
# data_root = '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley'
# img_suffix = '_rgb.png'
# classes = ['ABCO', 'CADE', 'PILA', 'PIPO', 'PSME', 'QUEV', 'SNAG', 'ground']
# crop_size = (1024, 1024)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(2048, 1024),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley',
#         img_suffix='_rgb.png',
#         classes=[
#             'ABCO', 'CADE', 'PILA', 'PIPO', 'PSME', 'QUEV', 'SNAG', 'ground'
#         ],
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(2048, 1024),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(
#                 type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley',
#         img_suffix='_rgb.png',
#         classes=[
#             'ABCO', 'CADE', 'PILA', 'PIPO', 'PSME', 'QUEV', 'SNAG', 'ground'
#         ],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley',
#         img_suffix='_rgb.png',
#         classes=[
#             'ABCO', 'CADE', 'PILA', 'PIPO', 'PSME', 'QUEV', 'SNAG', 'ground'
#         ],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = True
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(
#         type='AdamW', lr=6e-05, betas=(0.9, 0.999), weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             pos_block=dict(decay_mult=0.0),
#             norm=dict(decay_mult=0.0),
#             head=dict(lr_mult=10.0))))
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=1e-06, by_epoch=False, begin=0,
#         end=1500),
#     dict(
#         type='PolyLR',
#         eta_min=0.0,
#         power=1.0,
#         begin=1500,
#         end=10000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=10000, val_interval=1000)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=5000),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# checkpoint = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
# launcher = 'none'
# work_dir = '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/work_dir'
# /ofo-share/repos-david/mmsegmentation/mmseg/models/builder.py:42: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn(
# /ofo-share/repos-david/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:245: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 02/09 23:59:59 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/09 23:59:59 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /ofo-share/repos-david/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:64: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn(
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:decay_mult=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:lr=6e-05
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:weight_decay=0.0
# 02/10 00:00:02 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:decay_mult=0.0
# ...
# 02/10 01:08:02 - mmengine - INFO - Iter(train) [ 6850/10000]  lr: 2.2238e-05  eta: 0:30:51  time: 0.5479  data_time: 0.0991  memory: 12682  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 100.0000
# 02/10 01:08:32 - mmengine - INFO - Iter(train) [ 6900/10000]  lr: 2.1885e-05  eta: 0:30:22  time: 0.5117  data_time: 0.0561  memory: 12682  loss: 0.0005  decode.loss_ce: 0.0005  decode.acc_seg: 99.0193
# 02/10 01:09:02 - mmengine - INFO - Iter(train) [ 6950/10000]  lr: 2.1532e-05  eta: 0:29:52  time: 0.5657  data_time: 0.1161  memory: 12682  loss: 0.0008  decode.loss_ce: 0.0008  decode.acc_seg: 99.9324
# 02/10 01:09:31 - mmengine - INFO - Exp name: ortho_delta_valley_20240209_235952
# 02/10 01:09:31 - mmengine - INFO - Iter(train) [ 7000/10000]  lr: 2.1179e-05  eta: 0:29:23  time: 0.6247  data_time: 0.1730  memory: 12682  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 99.6770
# 02/10 01:09:39 - mmengine - INFO - per class results:
# 02/10 01:09:39 - mmengine - INFO -
# +--------+-------+-------+
# | Class  |  IoU  |  Acc  |
# +--------+-------+-------+
# |  ABCO  |  99.3 | 99.68 |
# |  CADE  |  98.0 | 98.71 |
# |  PILA  |  98.3 |  99.6 |
# |  PIPO  | 99.08 | 99.48 |
# |  PSME  | 98.52 | 99.02 |
# |  QUEV  |  nan  |  nan  |
# |  SNAG  | 95.23 | 98.39 |
# | ground |  nan  |  nan  |
# +--------+-------+-------+
# 02/10 01:09:39 - mmengine - INFO - Iter(val) [10/10]    aAcc: 99.3200  mIoU: 98.0700  mAcc: 99.1400  data_time: 0.6474  time: 0.7611
# 02/10 01:10:06 - mmengine - INFO - Iter(train) [ 7050/10000]  lr: 2.0826e-05  eta: 0:28:53  time: 0.5609  data_time: 0.1092  memory: 12682  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 100.0000
# 02/10 01:10:36 - mmengine - INFO - Iter(train) [ 7100/10000]  lr: 2.0473e-05  eta: 0:28:23  time: 0.6473  data_time: 0.1933  memory: 12682  loss: 0.0006  decode.loss_ce: 0.0006  decode.acc_seg: 99.6904
# 02/10 01:11:04 - mmengine - INFO - Iter(train) [ 7150/10000]  lr: 2.0120e-05  eta: 0:27:54  time: 0.5530  data_time: 0.0984  memory: 12682  loss: 0.0008  decode.loss_ce: 0.0008  decode.acc_seg: 99.9888
# 02/10 01:11:34 - mmengine - INFO - Iter(train) [ 7200/10000]  lr: 1.9767e-05  eta: 0:27:24  time: 0.5893  data_time: 0.1380  memory: 12682  loss: 0.0007  decode.loss_ce: 0.0007  decode.acc_seg: 99.6961
# 02/10 01:12:03 - mmengine - INFO - Iter(train) [ 7250/10000]  lr: 1.9414e-05  eta: 0:26:55  time: 0.5997  data_time: 0.1508  memory: 12682  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 100.0000
# 02/10 01:12:32 - mmengine - INFO - Iter(train) [ 7300/10000]  lr: 1.9061e-05  eta: 0:26:25  time: 0.6095  data_time: 0.1573  memory: 12682  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 99.7563
# 02/10 01:13:03 - mmengine - INFO - Iter(train) [ 7350/10000]  lr: 1.8708e-05  eta: 0:25:57  time: 0.5785  data_time: 0.1295  memory: 12682  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 100.0000
# 02/10 01:13:32 - mmengine - INFO - Iter(train) [ 7400/10000]  lr: 1.8355e-05  eta: 0:25:27  time: 0.6618  data_time: 0.2113  memory: 12682  loss: 0.0008  decode.loss_ce: 0.0008  decode.acc_seg: 100.0000
# 02/10 01:14:01 - mmengine - INFO - Iter(train) [ 7450/10000]  lr: 1.8002e-05  eta: 0:24:58  time: 0.5414  data_time: 0.0850  memory: 12682  loss: 0.0006  decode.loss_ce: 0.0006  decode.acc_seg: 99.4227
# 02/10 01:14:31 - mmengine - INFO - Iter(train) [ 7500/10000]  lr: 1.7649e-05  eta: 0:24:29  time: 0.6280  data_time: 0.1736  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.7716
# 02/10 01:15:00 - mmengine - INFO - Iter(train) [ 7550/10000]  lr: 1.7296e-05  eta: 0:23:59  time: 0.5311  data_time: 0.0806  memory: 12682  loss: 0.0005  decode.loss_ce: 0.0005  decode.acc_seg: 99.8040
# 02/10 01:15:29 - mmengine - INFO - Iter(train) [ 7600/10000]  lr: 1.6943e-05  eta: 0:23:29  time: 0.6294  data_time: 0.1766  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.6561
# 02/10 01:15:58 - mmengine - INFO - Iter(train) [ 7650/10000]  lr: 1.6590e-05  eta: 0:23:00  time: 0.5754  data_time: 0.1225  memory: 12682  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 99.6036
# 02/10 01:16:28 - mmengine - INFO - Iter(train) [ 7700/10000]  lr: 1.6237e-05  eta: 0:22:31  time: 0.5833  data_time: 0.1345  memory: 12682  loss: 0.0010  decode.loss_ce: 0.0010  decode.acc_seg: 99.5714
# 02/10 01:16:56 - mmengine - INFO - Iter(train) [ 7750/10000]  lr: 1.5884e-05  eta: 0:22:01  time: 0.5446  data_time: 0.0950  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 96.8622
# 02/10 01:17:26 - mmengine - INFO - Iter(train) [ 7800/10000]  lr: 1.5531e-05  eta: 0:21:32  time: 0.5822  data_time: 0.1267  memory: 12682  loss: 0.0005  decode.loss_ce: 0.0005  decode.acc_seg: 99.6973
# 02/10 01:17:55 - mmengine - INFO - Iter(train) [ 7850/10000]  lr: 1.5178e-05  eta: 0:21:02  time: 0.5827  data_time: 0.1301  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.3566
# 02/10 01:18:24 - mmengine - INFO - Iter(train) [ 7900/10000]  lr: 1.4825e-05  eta: 0:20:33  time: 0.5666  data_time: 0.1162  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 100.0000
# 02/10 01:18:54 - mmengine - INFO - Iter(train) [ 7950/10000]  lr: 1.4472e-05  eta: 0:20:04  time: 0.6037  data_time: 0.1491  memory: 12682  loss: 0.0005  decode.loss_ce: 0.0005  decode.acc_seg: 99.7241
# 02/10 01:19:23 - mmengine - INFO - Exp name: ortho_delta_valley_20240209_235952
# 02/10 01:19:23 - mmengine - INFO - Iter(train) [ 8000/10000]  lr: 1.4119e-05  eta: 0:19:34  time: 0.6968  data_time: 0.2436  memory: 12682  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 99.6488
# 02/10 01:19:31 - mmengine - INFO - per class results:
# 02/10 01:19:31 - mmengine - INFO -
# +--------+-------+-------+
# | Class  |  IoU  |  Acc  |
# +--------+-------+-------+
# |  ABCO  | 99.49 | 99.73 |
# |  CADE  | 97.86 | 98.14 |
# |  PILA  | 98.66 | 99.57 |
# |  PIPO  | 99.09 | 99.47 |
# |  PSME  | 98.48 | 99.43 |
# |  QUEV  |  nan  |  nan  |
# |  SNAG  | 98.75 | 98.86 |
# | ground |  nan  |  nan  |
# +--------+-------+-------+
# 02/10 01:19:31 - mmengine - INFO - Iter(val) [10/10]    aAcc: 99.4000  mIoU: 98.7200  mAcc: 99.2000  data_time: 0.5495  time: 0.6661
# 02/10 01:19:58 - mmengine - INFO - Iter(train) [ 8050/10000]  lr: 1.3766e-05  eta: 0:19:04  time: 0.6207  data_time: 0.1709  memory: 12682  loss: 0.0005  decode.loss_ce: 0.0005  decode.acc_seg: 99.4337
# 02/10 01:20:27 - mmengine - INFO - Iter(train) [ 8100/10000]  lr: 1.3413e-05  eta: 0:18:35  time: 0.5900  data_time: 0.1398  memory: 12682  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 99.8293
# 02/10 01:20:57 - mmengine - INFO - Iter(train) [ 8150/10000]  lr: 1.3060e-05  eta: 0:18:06  time: 0.6416  data_time: 0.1902  memory: 12682  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 99.5815
# 02/10 01:21:25 - mmengine - INFO - Iter(train) [ 8200/10000]  lr: 1.2707e-05  eta: 0:17:36  time: 0.5520  data_time: 0.0814  memory: 12682  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 99.9427
# 02/10 01:21:55 - mmengine - INFO - Iter(train) [ 8250/10000]  lr: 1.2354e-05  eta: 0:17:07  time: 0.5915  data_time: 0.1367  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.9061
# 02/10 01:22:24 - mmengine - INFO - Iter(train) [ 8300/10000]  lr: 1.2001e-05  eta: 0:16:38  time: 0.6083  data_time: 0.1515  memory: 12682  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 99.8251
# 02/10 01:22:54 - mmengine - INFO - Iter(train) [ 8350/10000]  lr: 1.1648e-05  eta: 0:16:08  time: 0.5950  data_time: 0.1393  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 100.0000
# 02/10 01:23:24 - mmengine - INFO - Iter(train) [ 8400/10000]  lr: 1.1295e-05  eta: 0:15:39  time: 0.6828  data_time: 0.2276  memory: 12682  loss: 0.0006  decode.loss_ce: 0.0006  decode.acc_seg: 99.7094
# 02/10 01:23:55 - mmengine - INFO - Iter(train) [ 8450/10000]  lr: 1.0942e-05  eta: 0:15:10  time: 0.6209  data_time: 0.1654  memory: 12682  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 100.0000
# 02/10 01:24:24 - mmengine - INFO - Iter(train) [ 8500/10000]  lr: 1.0589e-05  eta: 0:14:41  time: 0.5456  data_time: 0.0927  memory: 12682  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 99.8754
# 02/10 01:24:54 - mmengine - INFO - Iter(train) [ 8550/10000]  lr: 1.0236e-05  eta: 0:14:11  time: 0.5854  data_time: 0.1324  memory: 12682  loss: 0.0007  decode.loss_ce: 0.0007  decode.acc_seg: 99.8275
# 02/10 01:25:24 - mmengine - INFO - Iter(train) [ 8600/10000]  lr: 9.8835e-06  eta: 0:13:42  time: 0.6135  data_time: 0.1580  memory: 12682  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 100.0000
# 02/10 01:25:53 - mmengine - INFO - Iter(train) [ 8650/10000]  lr: 9.5305e-06  eta: 0:13:13  time: 0.5410  data_time: 0.0857  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.7347
# 02/10 01:26:22 - mmengine - INFO - Iter(train) [ 8700/10000]  lr: 9.1776e-06  eta: 0:12:43  time: 0.5619  data_time: 0.1094  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.8056
# 02/10 01:26:51 - mmengine - INFO - Iter(train) [ 8750/10000]  lr: 8.8246e-06  eta: 0:12:14  time: 0.5781  data_time: 0.1240  memory: 12682  loss: 0.0006  decode.loss_ce: 0.0006  decode.acc_seg: 99.4581
# 02/10 01:27:20 - mmengine - INFO - Iter(train) [ 8800/10000]  lr: 8.4716e-06  eta: 0:11:44  time: 0.5380  data_time: 0.0871  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.1387
# 02/10 01:27:50 - mmengine - INFO - Iter(train) [ 8850/10000]  lr: 8.1186e-06  eta: 0:11:15  time: 0.5634  data_time: 0.1112  memory: 12682  loss: 0.0006  decode.loss_ce: 0.0006  decode.acc_seg: 99.9456
# 02/10 01:28:20 - mmengine - INFO - Iter(train) [ 8900/10000]  lr: 7.7656e-06  eta: 0:10:46  time: 0.6560  data_time: 0.2064  memory: 12682  loss: 0.0005  decode.loss_ce: 0.0005  decode.acc_seg: 99.5080
# 02/10 01:28:49 - mmengine - INFO - Iter(train) [ 8950/10000]  lr: 7.4126e-06  eta: 0:10:16  time: 0.5548  data_time: 0.1053  memory: 12682  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 99.6538
# 02/10 01:29:17 - mmengine - INFO - Exp name: ortho_delta_valley_20240209_235952
# 02/10 01:29:17 - mmengine - INFO - Iter(train) [ 9000/10000]  lr: 7.0597e-06  eta: 0:09:47  time: 0.5668  data_time: 0.1107  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.8082
# 02/10 01:29:25 - mmengine - INFO - per class results:
# 02/10 01:29:25 - mmengine - INFO -
# +--------+-------+-------+
# | Class  |  IoU  |  Acc  |
# +--------+-------+-------+
# |  ABCO  | 99.23 | 99.47 |
# |  CADE  | 98.34 | 98.99 |
# |  PILA  | 98.85 | 99.49 |
# |  PIPO  | 99.45 |  99.7 |
# |  PSME  | 98.74 | 99.51 |
# |  QUEV  |  nan  |  nan  |
# |  SNAG  | 98.63 | 98.77 |
# | ground |  nan  |  nan  |
# +--------+-------+-------+
# 02/10 01:29:25 - mmengine - INFO - Iter(val) [10/10]    aAcc: 99.5200  mIoU: 98.8700  mAcc: 99.3200  data_time: 0.6571  time: 0.7710
# 02/10 01:29:52 - mmengine - INFO - Iter(train) [ 9050/10000]  lr: 6.7067e-06  eta: 0:09:17  time: 0.5927  data_time: 0.1415  memory: 12682  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 98.5294
# 02/10 01:30:22 - mmengine - INFO - Iter(train) [ 9100/10000]  lr: 6.3537e-06  eta: 0:08:48  time: 0.6085  data_time: 0.1487  memory: 12682  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 100.0000
# 02/10 01:30:50 - mmengine - INFO - Iter(train) [ 9150/10000]  lr: 6.0007e-06  eta: 0:08:18  time: 0.5908  data_time: 0.1321  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 100.0000
# 02/10 01:31:19 - mmengine - INFO - Iter(train) [ 9200/10000]  lr: 5.6477e-06  eta: 0:07:49  time: 0.5707  data_time: 0.1176  memory: 12682  loss: 0.0008  decode.loss_ce: 0.0008  decode.acc_seg: 99.6486
# 02/10 01:31:48 - mmengine - INFO - Iter(train) [ 9250/10000]  lr: 5.2947e-06  eta: 0:07:20  time: 0.5404  data_time: 0.0823  memory: 12682  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 68.3150
# 02/10 01:32:17 - mmengine - INFO - Iter(train) [ 9300/10000]  lr: 4.9418e-06  eta: 0:06:50  time: 0.6432  data_time: 0.1930  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.2885
# 02/10 01:32:46 - mmengine - INFO - Iter(train) [ 9350/10000]  lr: 4.5888e-06  eta: 0:06:21  time: 0.5367  data_time: 0.0833  memory: 12682  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 99.6195
# 02/10 01:33:15 - mmengine - INFO - Iter(train) [ 9400/10000]  lr: 4.2358e-06  eta: 0:05:52  time: 0.4874  data_time: 0.0338  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.6683
# 02/10 01:33:44 - mmengine - INFO - Iter(train) [ 9450/10000]  lr: 3.8828e-06  eta: 0:05:22  time: 0.5202  data_time: 0.0663  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.9121
# 02/10 01:34:13 - mmengine - INFO - Iter(train) [ 9500/10000]  lr: 3.5298e-06  eta: 0:04:53  time: 0.5606  data_time: 0.1018  memory: 12682  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 99.7113
# 02/10 01:34:43 - mmengine - INFO - Iter(train) [ 9550/10000]  lr: 3.1768e-06  eta: 0:04:24  time: 0.6250  data_time: 0.1711  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 100.0000
# 02/10 01:35:12 - mmengine - INFO - Iter(train) [ 9600/10000]  lr: 2.8239e-06  eta: 0:03:54  time: 0.5724  data_time: 0.1175  memory: 12682  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 99.5151
# 02/10 01:35:43 - mmengine - INFO - Iter(train) [ 9650/10000]  lr: 2.4709e-06  eta: 0:03:25  time: 0.6461  data_time: 0.1869  memory: 12682  loss: 0.0001  decode.loss_ce: 0.0001  decode.acc_seg: 100.0000
# 02/10 01:36:11 - mmengine - INFO - Iter(train) [ 9700/10000]  lr: 2.1179e-06  eta: 0:02:56  time: 0.4861  data_time: 0.0320  memory: 12682  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 99.4620
# 02/10 01:36:40 - mmengine - INFO - Iter(train) [ 9750/10000]  lr: 1.7649e-06  eta: 0:02:26  time: 0.5924  data_time: 0.1361  memory: 12682  loss: 0.0001  decode.loss_ce: 0.0001  decode.acc_seg: 100.0000
# 02/10 01:37:09 - mmengine - INFO - Iter(train) [ 9800/10000]  lr: 1.4119e-06  eta: 0:01:57  time: 0.6047  data_time: 0.1463  memory: 12682  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 100.0000
# 02/10 01:37:39 - mmengine - INFO - Iter(train) [ 9850/10000]  lr: 1.0589e-06  eta: 0:01:28  time: 0.6749  data_time: 0.2166  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.7879
# 02/10 01:38:08 - mmengine - INFO - Iter(train) [ 9900/10000]  lr: 7.0597e-07  eta: 0:00:58  time: 0.5564  data_time: 0.1020  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.9054
# 02/10 01:38:38 - mmengine - INFO - Iter(train) [ 9950/10000]  lr: 3.5298e-07  eta: 0:00:29  time: 0.5502  data_time: 0.0916  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.7429
# 02/10 01:39:06 - mmengine - INFO - Exp name: ortho_delta_valley_20240209_235952
# 02/10 01:39:06 - mmengine - INFO - Iter(train) [10000/10000]  lr: 0.0000e+00  eta: 0:00:00  time: 0.5402  data_time: 0.0855  memory: 12682  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 99.6998
# 02/10 01:39:06 - mmengine - INFO - Saving checkpoint at 10000 iterations
# 02/10 01:39:16 - mmengine - INFO - per class results:
# 02/10 01:39:16 - mmengine - INFO -
# +--------+-------+-------+
# | Class  |  IoU  |  Acc  |
# +--------+-------+-------+
# |  ABCO  | 99.39 | 99.47 |
# |  CADE  |  98.5 | 98.77 |
# |  PILA  | 98.93 | 99.43 |
# |  PIPO  | 99.29 | 99.78 |
# |  PSME  |  98.8 | 99.49 |
# |  QUEV  |  nan  |  nan  |
# |  SNAG  | 98.94 | 99.05 |
# | ground |  nan  |  nan  |
# +--------+-------+-------+
# 02/10 01:39:16 - mmengine - INFO - Iter(val) [10/10]    aAcc: 99.5200  mIoU: 98.9800  mAcc: 99.3300  data_time: 0.4171  time: 0.5302
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/openmmlab/bin/python /ofo-share/repos-david/mmsegmentation/tools/train.py /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/ortho_delta_valley.py --work-dir /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/ortho_delta_valley/work_dir --resume', returncode=0)

# %%
shutil.copytree(
    src=TRAINING_DATA_FOLDER_SCRATCH, dst=TRAINING_DATA_FOLDER, dirs_exist_ok=True
)
# Out:
# PosixPath('/ofo-share/scratch-david/organized-str-disp-MVMT-experiments/models/multi_site/ortho_delta_valley')
