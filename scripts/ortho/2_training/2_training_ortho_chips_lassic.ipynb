# %% [markdown]
# # Imports

# %%
import shutil
import sys
import logging
from pathlib import Path
import subprocess

# Contributed library imports
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread
from pathlib import Path

sys.path.append("../..")
from constants import (
    get_aggregated_images_folder,
    get_aggregated_labels_folder,
    get_IDs_to_labels,
    get_training_chips_folder,
    get_training_data_scratch_folder,
    get_work_dir,
    get_training_data_folder,
    TRAINING_IMGS_EXT,
    MMSEG_PYTHON,
    TRAIN_SCRIPT,
    MMSEG_UTILS_PYTHON,
    FOLDER_TO_CITYSCAPES_SCRIPT,
)

# %% [markdown]
# # Define constants

# %%
TRAINING_SITES = sorted(["chips", "lassic"])

# %%
logging.basicConfig(level="INFO")

# %%
AGGREGATED_IMAGES_FOLDER = get_aggregated_images_folder(
    training_sites=TRAINING_SITES, is_ortho=True
)
AGGREGATED_LABELS_FOLDER = get_aggregated_labels_folder(
    training_sites=TRAINING_SITES, is_ortho=True
)

# We need to merge all the imagery together
# I think this should be stored in the models folder, alongside the real models
# It should be as simple as creating the folders and symlinking the existing ones into it
Path(AGGREGATED_IMAGES_FOLDER).mkdir(exist_ok=True, parents=True)
Path(AGGREGATED_LABELS_FOLDER).mkdir(exist_ok=True, parents=True)

for training_site in TRAINING_SITES:

    TRAINING_CHIPS_FOLDER = get_training_chips_folder(training_site=training_site)
    render_folder = Path(TRAINING_CHIPS_FOLDER, "anns")
    image_folder = Path(TRAINING_CHIPS_FOLDER, "imgs")

    output_render_folder = Path(AGGREGATED_LABELS_FOLDER, training_site)
    output_image_folder = Path(AGGREGATED_IMAGES_FOLDER, training_site)

    # Remove if folder
    shutil.rmtree(output_render_folder, ignore_errors=True)
    shutil.rmtree(output_image_folder, ignore_errors=True)
    # Unlink if symlink
    output_render_folder.unlink(missing_ok=True)
    output_image_folder.unlink(missing_ok=True)
    print(output_render_folder)
    shutil.copytree(render_folder, output_render_folder)
    shutil.copytree(image_folder, output_image_folder)
# Out:
# /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/ortho/inputs/labels/chips
# /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/ortho/inputs/labels/lassic

# %%
IDs_TO_LABELS = get_IDs_to_labels()
TRAINING_DATA_FOLDER_SCRATCH = get_training_data_scratch_folder(
    training_sites=TRAINING_SITES
)

class_names = list(IDs_TO_LABELS.values())
class_names_str = " ".join(class_names)
print(class_names_str)

run_str = (
    f"{MMSEG_UTILS_PYTHON} {FOLDER_TO_CITYSCAPES_SCRIPT} --images-folder {AGGREGATED_IMAGES_FOLDER}"
    + f" --labels-folder {AGGREGATED_LABELS_FOLDER} --output-folder {TRAINING_DATA_FOLDER_SCRATCH} "
    + f"--classes {class_names_str} --image-ext {TRAINING_IMGS_EXT} --remove-old "
)
print(run_str)
subprocess.run(
    run_str,
    shell=True,
)
# Out:
# ABCO CADE PILA PIPJ PSME
# /ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/ortho/inputs/images --labels-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/ortho/inputs/labels --output-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic --classes ABCO CADE PILA PIPJ PSME --image-ext .png --remove-old
# Checking for completely null images: 100%|██████████| 52/52 [00:03<00:00, 16.63it/s]
# Linking files into either train or test folders: 100%|██████████| 52/52 [00:00<00:00, 12533.26it/s]
# 100%|██████████| 20/20 [00:10<00:00,  1.92it/s]
# (2661581, 3)
# mean: [122.65940356502395, 122.06570380536982, 107.06273151183451], std: [59.97113238279224, 56.143206425231874, 51.79636693518005]
# About to save config to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/chips_lassic.py
# visualizing to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/train: 100%|██████████| 11/11 [02:27<00:00, 13.37s/it]
# visualizing to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/val: 100%|██████████| 10/10 [02:14<00:00, 13.48s/it]
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/ortho/inputs/images --labels-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/ortho/inputs/labels --output-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic --classes ABCO CADE PILA PIPJ PSME --image-ext .png --remove-old ', returncode=0)

# %% [markdown]
# # Show some of the formatted example images

# %%
cmap_file = Path(TRAINING_DATA_FOLDER_SCRATCH, "colormap.png")
plt.imshow(imread(cmap_file))
plt.show()

vis_folder = Path(TRAINING_DATA_FOLDER_SCRATCH, "vis")
vis_files = list(vis_folder.rglob("*" + TRAINING_IMGS_EXT))
for file in vis_files:
    print(f"showing {file}")
    plt.imshow(imread(file))
    plt.show()
# Out:
# /tmp/ipykernel_7028/3709348006.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(cmap_file))
# /tmp/ipykernel_7028/3709348006.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(file))
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/val/chips_chips:29184:18240:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/val/chips_chips:25536:7296:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/val/lassic_lassic:12768:27360:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/val/chips_chips:29184:14592:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/val/lassic_lassic:29184:31008:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/val/chips_chips:27360:10944:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/val/chips_chips:27360:16416:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/val/chips_chips:23712:7296:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/val/lassic_lassic:16416:29184:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/val/lassic_lassic:12768:29184:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/train/lassic_lassic:25536:25536:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/train/chips_chips:21888:10944:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/train/chips_chips:25536:14592:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/train/chips_chips:27360:9120:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/train/chips_chips:23712:18240:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/train/lassic_lassic:27360:25536:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/train/chips_chips:23712:10944:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/train/lassic_lassic:29184:25536:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/train/lassic_lassic:14592:27360:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/train/lassic_lassic:31008:27360:3648:3648_rgb.png
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/vis/train/chips_chips:27360:12768:3648:3648_rgb.png

# %% [markdown]
# # Train a model

# %%
WORK_DIR = get_work_dir(training_sites=TRAINING_SITES)
# Identify the config file as the only python file in the
config_file = list(Path(TRAINING_DATA_FOLDER_SCRATCH).glob("*py"))[0]
subprocess.run(
    f"{MMSEG_PYTHON} {TRAIN_SCRIPT} " + f"{config_file} --work-dir {WORK_DIR}",
    shell=True,
)
# Out:
# 02/20 14:56:06 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1494974981
#     GPU 0: GRID A100X-20C
#     CUDA_HOME: /ofo-share/repos-david/conda/envs/MVMT-stable
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1494974981
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/20 14:56:07 - mmengine - INFO - Config:
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[122.65940356502395, 122.06570380536982, 107.06273151183451],
#     std=[59.97113238279224, 56.143206425231874, 51.79636693518005],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(1024, 1024))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[122.65940356502395, 122.06570380536982, 107.06273151183451],
#         std=[59.97113238279224, 56.143206425231874, 51.79636693518005],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(1024, 1024)),
#     pretrained=None,
#     backbone=dict(
#         type='MixVisionTransformer',
#         in_channels=3,
#         embed_dims=64,
#         num_stages=4,
#         num_layers=[3, 6, 40, 3],
#         num_heads=[1, 2, 5, 8],
#         patch_sizes=[7, 3, 3, 3],
#         sr_ratios=[8, 4, 2, 1],
#         out_indices=(0, 1, 2, 3),
#         mlp_ratio=4,
#         qkv_bias=True,
#         drop_rate=0.0,
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
#         )),
#     decode_head=dict(
#         type='SegformerHead',
#         in_channels=[64, 128, 320, 512],
#         in_index=[0, 1, 2, 3],
#         channels=256,
#         dropout_ratio=0.1,
#         num_classes=5,
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='slide', crop_size=(1024, 1024), stride=(768, 768)))
# dataset_type = 'CityscapesForestsDataset'
# data_root = '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic'
# img_suffix = '_rgb.png'
# classes = ['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME']
# crop_size = (1024, 1024)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(2048, 1024),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic',
#         img_suffix='_rgb.png',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(2048, 1024),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(
#                 type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic',
#         img_suffix='_rgb.png',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic',
#         img_suffix='_rgb.png',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(
#         type='AdamW', lr=6e-05, betas=(0.9, 0.999), weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             pos_block=dict(decay_mult=0.0),
#             norm=dict(decay_mult=0.0),
#             head=dict(lr_mult=10.0))))
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=1e-06, by_epoch=False, begin=0,
#         end=1500),
#     dict(
#         type='PolyLR',
#         eta_min=0.0,
#         power=1.0,
#         begin=1500,
#         end=10000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=10000, val_interval=1000)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=5000),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# checkpoint = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
# launcher = 'none'
# work_dir = '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/work_dir'
# /ofo-share/repos-david/mmsegmentation/mmseg/models/builder.py:42: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn(
# /ofo-share/repos-david/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:245: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 02/20 14:56:11 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/20 14:56:11 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /ofo-share/repos-david/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:64: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn(
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:weight_decay=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:decay_mult=0.0
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.attn.norm.weight:lr=6e-05
# 02/20 14:56:13 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.attn.norm.weight:weight_decay=0.0
# ...
# 02/20 15:56:52 - mmengine - INFO - Iter(train) [ 6750/10000]  lr: 2.2944e-05  eta: 0:28:49  time: 0.5565  data_time: 0.1159  memory: 12680  loss: 0.0012  decode.loss_ce: 0.0012  decode.acc_seg: 99.3377
# 02/20 15:57:18 - mmengine - INFO - Iter(train) [ 6800/10000]  lr: 2.2591e-05  eta: 0:28:22  time: 0.5671  data_time: 0.1080  memory: 12680  loss: 0.0016  decode.loss_ce: 0.0016  decode.acc_seg: 99.7829
# 02/20 15:57:44 - mmengine - INFO - Iter(train) [ 6850/10000]  lr: 2.2238e-05  eta: 0:27:55  time: 0.5000  data_time: 0.0591  memory: 12680  loss: 0.0010  decode.loss_ce: 0.0010  decode.acc_seg: 100.0000
# 02/20 15:58:11 - mmengine - INFO - Iter(train) [ 6900/10000]  lr: 2.1885e-05  eta: 0:27:28  time: 0.5296  data_time: 0.0757  memory: 12680  loss: 0.0011  decode.loss_ce: 0.0011  decode.acc_seg: 99.7086
# 02/20 15:58:37 - mmengine - INFO - Iter(train) [ 6950/10000]  lr: 2.1532e-05  eta: 0:27:02  time: 0.5130  data_time: 0.0707  memory: 12680  loss: 0.0011  decode.loss_ce: 0.0011  decode.acc_seg: 99.7864
# 02/20 15:59:04 - mmengine - INFO - Exp name: chips_lassic_20240220_145605
# 02/20 15:59:04 - mmengine - INFO - Iter(train) [ 7000/10000]  lr: 2.1179e-05  eta: 0:26:35  time: 0.5428  data_time: 0.1023  memory: 12680  loss: 0.0007  decode.loss_ce: 0.0007  decode.acc_seg: 99.7931
# 02/20 15:59:11 - mmengine - INFO - per class results:
# 02/20 15:59:11 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 99.21 | 99.42 |
# |  CADE | 98.27 | 100.0 |
# |  PILA | 97.99 | 99.01 |
# |  PIPJ | 98.16 | 99.62 |
# |  PSME | 97.75 | 97.86 |
# +-------+-------+-------+
# 02/20 15:59:11 - mmengine - INFO - Iter(val) [10/10]    aAcc: 99.1100  mIoU: 98.2800  mAcc: 99.1800  data_time: 0.5932  time: 0.6984
# 02/20 15:59:35 - mmengine - INFO - Iter(train) [ 7050/10000]  lr: 2.0826e-05  eta: 0:26:07  time: 0.5206  data_time: 0.0808  memory: 12680  loss: 0.0007  decode.loss_ce: 0.0007  decode.acc_seg: 97.0607
# 02/20 16:00:02 - mmengine - INFO - Iter(train) [ 7100/10000]  lr: 2.0473e-05  eta: 0:25:41  time: 0.5415  data_time: 0.0985  memory: 12680  loss: 0.0019  decode.loss_ce: 0.0019  decode.acc_seg: 99.0263
# 02/20 16:00:29 - mmengine - INFO - Iter(train) [ 7150/10000]  lr: 2.0120e-05  eta: 0:25:14  time: 0.5382  data_time: 0.0976  memory: 12680  loss: 0.0008  decode.loss_ce: 0.0008  decode.acc_seg: 99.9808
# 02/20 16:00:56 - mmengine - INFO - Iter(train) [ 7200/10000]  lr: 1.9767e-05  eta: 0:24:48  time: 0.4997  data_time: 0.0580  memory: 12680  loss: 0.0008  decode.loss_ce: 0.0008  decode.acc_seg: 99.6617
# 02/20 16:01:22 - mmengine - INFO - Iter(train) [ 7250/10000]  lr: 1.9414e-05  eta: 0:24:22  time: 0.5197  data_time: 0.0784  memory: 12679  loss: 0.0010  decode.loss_ce: 0.0010  decode.acc_seg: 99.2002
# 02/20 16:01:49 - mmengine - INFO - Iter(train) [ 7300/10000]  lr: 1.9061e-05  eta: 0:23:55  time: 0.5549  data_time: 0.1117  memory: 12680  loss: 0.0007  decode.loss_ce: 0.0007  decode.acc_seg: 98.8517
# 02/20 16:02:16 - mmengine - INFO - Iter(train) [ 7350/10000]  lr: 1.8708e-05  eta: 0:23:29  time: 0.6179  data_time: 0.1737  memory: 12680  loss: 0.0011  decode.loss_ce: 0.0011  decode.acc_seg: 100.0000
# 02/20 16:02:42 - mmengine - INFO - Iter(train) [ 7400/10000]  lr: 1.8355e-05  eta: 0:23:02  time: 0.5118  data_time: 0.0727  memory: 12680  loss: 0.0012  decode.loss_ce: 0.0012  decode.acc_seg: 99.3837
# 02/20 16:03:09 - mmengine - INFO - Iter(train) [ 7450/10000]  lr: 1.8002e-05  eta: 0:22:35  time: 0.5492  data_time: 0.1105  memory: 12680  loss: 0.0016  decode.loss_ce: 0.0016  decode.acc_seg: 100.0000
# 02/20 16:03:35 - mmengine - INFO - Iter(train) [ 7500/10000]  lr: 1.7649e-05  eta: 0:22:09  time: 0.5003  data_time: 0.0519  memory: 12680  loss: 0.0007  decode.loss_ce: 0.0007  decode.acc_seg: 99.8929
# 02/20 16:04:01 - mmengine - INFO - Iter(train) [ 7550/10000]  lr: 1.7296e-05  eta: 0:21:42  time: 0.5136  data_time: 0.0707  memory: 12680  loss: 0.0011  decode.loss_ce: 0.0011  decode.acc_seg: 99.1657
# 02/20 16:04:29 - mmengine - INFO - Iter(train) [ 7600/10000]  lr: 1.6943e-05  eta: 0:21:15  time: 0.5509  data_time: 0.1108  memory: 12680  loss: 0.0007  decode.loss_ce: 0.0007  decode.acc_seg: 99.7023
# 02/20 16:04:56 - mmengine - INFO - Iter(train) [ 7650/10000]  lr: 1.6590e-05  eta: 0:20:49  time: 0.5984  data_time: 0.1451  memory: 12680  loss: 0.0007  decode.loss_ce: 0.0007  decode.acc_seg: 100.0000
# 02/20 16:05:23 - mmengine - INFO - Iter(train) [ 7700/10000]  lr: 1.6237e-05  eta: 0:20:23  time: 0.5437  data_time: 0.0990  memory: 12680  loss: 0.0006  decode.loss_ce: 0.0006  decode.acc_seg: 100.0000
# 02/20 16:05:48 - mmengine - INFO - Iter(train) [ 7750/10000]  lr: 1.5884e-05  eta: 0:19:56  time: 0.5194  data_time: 0.0748  memory: 12680  loss: 0.0005  decode.loss_ce: 0.0005  decode.acc_seg: 99.6284
# 02/20 16:06:16 - mmengine - INFO - Iter(train) [ 7800/10000]  lr: 1.5531e-05  eta: 0:19:29  time: 0.5137  data_time: 0.0658  memory: 12680  loss: 0.0009  decode.loss_ce: 0.0009  decode.acc_seg: 99.0253
# 02/20 16:06:42 - mmengine - INFO - Iter(train) [ 7850/10000]  lr: 1.5178e-05  eta: 0:19:03  time: 0.5219  data_time: 0.0715  memory: 12680  loss: 0.0011  decode.loss_ce: 0.0011  decode.acc_seg: 99.9956
# 02/20 16:07:08 - mmengine - INFO - Iter(train) [ 7900/10000]  lr: 1.4825e-05  eta: 0:18:36  time: 0.5424  data_time: 0.1004  memory: 12680  loss: 0.0009  decode.loss_ce: 0.0009  decode.acc_seg: 97.7858
# 02/20 16:07:35 - mmengine - INFO - Iter(train) [ 7950/10000]  lr: 1.4472e-05  eta: 0:18:09  time: 0.5126  data_time: 0.0691  memory: 12680  loss: 0.0005  decode.loss_ce: 0.0005  decode.acc_seg: 97.9103
# 02/20 16:08:02 - mmengine - INFO - Exp name: chips_lassic_20240220_145605
# 02/20 16:08:02 - mmengine - INFO - Iter(train) [ 8000/10000]  lr: 1.4119e-05  eta: 0:17:43  time: 0.5054  data_time: 0.0656  memory: 12680  loss: 0.0008  decode.loss_ce: 0.0008  decode.acc_seg: 100.0000
# 02/20 16:08:09 - mmengine - INFO - per class results:
# 02/20 16:08:09 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 99.65 |  99.8 |
# |  CADE | 99.11 | 99.89 |
# |  PILA | 98.59 |  99.3 |
# |  PIPJ | 98.97 | 99.89 |
# |  PSME | 98.65 | 98.72 |
# +-------+-------+-------+
# 02/20 16:08:09 - mmengine - INFO - Iter(val) [10/10]    aAcc: 99.4800  mIoU: 98.9900  mAcc: 99.5200  data_time: 0.5935  time: 0.6980
# 02/20 16:08:33 - mmengine - INFO - Iter(train) [ 8050/10000]  lr: 1.3766e-05  eta: 0:17:16  time: 0.5166  data_time: 0.0775  memory: 12680  loss: 0.0011  decode.loss_ce: 0.0011  decode.acc_seg: 99.6960
# 02/20 16:09:00 - mmengine - INFO - Iter(train) [ 8100/10000]  lr: 1.3413e-05  eta: 0:16:49  time: 0.5442  data_time: 0.1056  memory: 12680  loss: 0.0010  decode.loss_ce: 0.0010  decode.acc_seg: 100.0000
# 02/20 16:09:26 - mmengine - INFO - Iter(train) [ 8150/10000]  lr: 1.3060e-05  eta: 0:16:23  time: 0.4898  data_time: 0.0514  memory: 12680  loss: 0.0011  decode.loss_ce: 0.0011  decode.acc_seg: 99.2773
# 02/20 16:09:54 - mmengine - INFO - Iter(train) [ 8200/10000]  lr: 1.2707e-05  eta: 0:15:56  time: 0.5254  data_time: 0.0832  memory: 12680  loss: 0.0007  decode.loss_ce: 0.0007  decode.acc_seg: 96.4457
# 02/20 16:10:20 - mmengine - INFO - Iter(train) [ 8250/10000]  lr: 1.2354e-05  eta: 0:15:30  time: 0.5246  data_time: 0.0758  memory: 12680  loss: 0.0006  decode.loss_ce: 0.0006  decode.acc_seg: 99.7621
# 02/20 16:10:47 - mmengine - INFO - Iter(train) [ 8300/10000]  lr: 1.2001e-05  eta: 0:15:03  time: 0.5411  data_time: 0.1011  memory: 12680  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 100.0000
# 02/20 16:11:13 - mmengine - INFO - Iter(train) [ 8350/10000]  lr: 1.1648e-05  eta: 0:14:36  time: 0.5168  data_time: 0.0764  memory: 12680  loss: 0.0013  decode.loss_ce: 0.0013  decode.acc_seg: 100.0000
# 02/20 16:11:39 - mmengine - INFO - Iter(train) [ 8400/10000]  lr: 1.1295e-05  eta: 0:14:10  time: 0.5565  data_time: 0.1168  memory: 12680  loss: 0.0011  decode.loss_ce: 0.0011  decode.acc_seg: 97.6038
# 02/20 16:12:06 - mmengine - INFO - Iter(train) [ 8450/10000]  lr: 1.0942e-05  eta: 0:13:43  time: 0.5601  data_time: 0.1199  memory: 12680  loss: 0.0002  decode.loss_ce: 0.0002  decode.acc_seg: 100.0000
# 02/20 16:12:33 - mmengine - INFO - Iter(train) [ 8500/10000]  lr: 1.0589e-05  eta: 0:13:17  time: 0.5104  data_time: 0.0690  memory: 12680  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 99.7848
# 02/20 16:13:00 - mmengine - INFO - Iter(train) [ 8550/10000]  lr: 1.0236e-05  eta: 0:12:50  time: 0.6328  data_time: 0.1920  memory: 12680  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 99.2902
# 02/20 16:13:26 - mmengine - INFO - Iter(train) [ 8600/10000]  lr: 9.8835e-06  eta: 0:12:24  time: 0.5119  data_time: 0.0723  memory: 12680  loss: 0.0021  decode.loss_ce: 0.0021  decode.acc_seg: 100.0000
# 02/20 16:13:53 - mmengine - INFO - Iter(train) [ 8650/10000]  lr: 9.5305e-06  eta: 0:11:57  time: 0.5527  data_time: 0.1129  memory: 12680  loss: 0.0008  decode.loss_ce: 0.0008  decode.acc_seg: 99.2584
# 02/20 16:14:19 - mmengine - INFO - Iter(train) [ 8700/10000]  lr: 9.1776e-06  eta: 0:11:30  time: 0.5409  data_time: 0.1015  memory: 12680  loss: 0.0009  decode.loss_ce: 0.0009  decode.acc_seg: 99.5880
# 02/20 16:14:46 - mmengine - INFO - Iter(train) [ 8750/10000]  lr: 8.8246e-06  eta: 0:11:04  time: 0.5824  data_time: 0.1428  memory: 12680  loss: 0.0006  decode.loss_ce: 0.0006  decode.acc_seg: 99.9139
# 02/20 16:15:12 - mmengine - INFO - Iter(train) [ 8800/10000]  lr: 8.4716e-06  eta: 0:10:37  time: 0.5010  data_time: 0.0617  memory: 12680  loss: 0.0009  decode.loss_ce: 0.0009  decode.acc_seg: 99.5966
# 02/20 16:15:39 - mmengine - INFO - Iter(train) [ 8850/10000]  lr: 8.1186e-06  eta: 0:10:11  time: 0.5210  data_time: 0.0815  memory: 12680  loss: 0.0005  decode.loss_ce: 0.0005  decode.acc_seg: 99.7458
# 02/20 16:16:06 - mmengine - INFO - Iter(train) [ 8900/10000]  lr: 7.7656e-06  eta: 0:09:44  time: 0.6078  data_time: 0.1684  memory: 12680  loss: 0.0012  decode.loss_ce: 0.0012  decode.acc_seg: 99.5972
# 02/20 16:16:33 - mmengine - INFO - Iter(train) [ 8950/10000]  lr: 7.4126e-06  eta: 0:09:18  time: 0.6208  data_time: 0.1816  memory: 12680  loss: 0.0010  decode.loss_ce: 0.0010  decode.acc_seg: 99.7999
# 02/20 16:17:00 - mmengine - INFO - Exp name: chips_lassic_20240220_145605
# 02/20 16:17:00 - mmengine - INFO - Iter(train) [ 9000/10000]  lr: 7.0597e-06  eta: 0:08:51  time: 0.5447  data_time: 0.1046  memory: 12680  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 99.6245
# 02/20 16:17:07 - mmengine - INFO - per class results:
# 02/20 16:17:07 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO |  99.6 | 99.61 |
# |  CADE |  98.2 | 100.0 |
# |  PILA | 98.52 | 99.41 |
# |  PIPJ | 98.63 |  99.4 |
# |  PSME | 98.39 | 98.53 |
# +-------+-------+-------+
# 02/20 16:17:07 - mmengine - INFO - Iter(val) [10/10]    aAcc: 99.3200  mIoU: 98.6700  mAcc: 99.3900  data_time: 0.5410  time: 0.6484
# 02/20 16:17:31 - mmengine - INFO - Iter(train) [ 9050/10000]  lr: 6.7067e-06  eta: 0:08:24  time: 0.5703  data_time: 0.1306  memory: 12680  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 98.4542
# 02/20 16:17:57 - mmengine - INFO - Iter(train) [ 9100/10000]  lr: 6.3537e-06  eta: 0:07:58  time: 0.5033  data_time: 0.0634  memory: 12680  loss: 0.0008  decode.loss_ce: 0.0008  decode.acc_seg: 99.5866
# 02/20 16:18:25 - mmengine - INFO - Iter(train) [ 9150/10000]  lr: 6.0007e-06  eta: 0:07:31  time: 0.5266  data_time: 0.0861  memory: 12680  loss: 0.0003  decode.loss_ce: 0.0003  decode.acc_seg: 99.8099
# 02/20 16:18:51 - mmengine - INFO - Iter(train) [ 9200/10000]  lr: 5.6477e-06  eta: 0:07:05  time: 0.4809  data_time: 0.0391  memory: 12680  loss: 0.0005  decode.loss_ce: 0.0005  decode.acc_seg: 99.5982
# 02/20 16:19:17 - mmengine - INFO - Iter(train) [ 9250/10000]  lr: 5.2947e-06  eta: 0:06:38  time: 0.5752  data_time: 0.1326  memory: 12680  loss: 0.0005  decode.loss_ce: 0.0005  decode.acc_seg: 100.0000
# 02/20 16:19:43 - mmengine - INFO - Iter(train) [ 9300/10000]  lr: 4.9418e-06  eta: 0:06:11  time: 0.5272  data_time: 0.0860  memory: 12680  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 99.8723
# 02/20 16:20:10 - mmengine - INFO - Iter(train) [ 9350/10000]  lr: 4.5888e-06  eta: 0:05:45  time: 0.5331  data_time: 0.0913  memory: 12680  loss: 0.0009  decode.loss_ce: 0.0009  decode.acc_seg: 100.0000
# 02/20 16:20:36 - mmengine - INFO - Iter(train) [ 9400/10000]  lr: 4.2358e-06  eta: 0:05:18  time: 0.4918  data_time: 0.0497  memory: 12680  loss: 0.0006  decode.loss_ce: 0.0006  decode.acc_seg: 99.7398
# 02/20 16:21:03 - mmengine - INFO - Iter(train) [ 9450/10000]  lr: 3.8828e-06  eta: 0:04:52  time: 0.4765  data_time: 0.0351  memory: 12680  loss: 0.0009  decode.loss_ce: 0.0009  decode.acc_seg: 99.8207
# 02/20 16:21:29 - mmengine - INFO - Iter(train) [ 9500/10000]  lr: 3.5298e-06  eta: 0:04:25  time: 0.5375  data_time: 0.0944  memory: 12680  loss: 0.0005  decode.loss_ce: 0.0005  decode.acc_seg: 99.7979
# 02/20 16:21:56 - mmengine - INFO - Iter(train) [ 9550/10000]  lr: 3.1768e-06  eta: 0:03:59  time: 0.5259  data_time: 0.0827  memory: 12680  loss: 0.0012  decode.loss_ce: 0.0012  decode.acc_seg: 99.9543
# 02/20 16:22:23 - mmengine - INFO - Iter(train) [ 9600/10000]  lr: 2.8239e-06  eta: 0:03:32  time: 0.5295  data_time: 0.0874  memory: 12680  loss: 0.0011  decode.loss_ce: 0.0011  decode.acc_seg: 99.9065
# 02/20 16:22:49 - mmengine - INFO - Iter(train) [ 9650/10000]  lr: 2.4709e-06  eta: 0:03:05  time: 0.5293  data_time: 0.0892  memory: 12680  loss: 0.0007  decode.loss_ce: 0.0007  decode.acc_seg: 98.5071
# 02/20 16:23:16 - mmengine - INFO - Iter(train) [ 9700/10000]  lr: 2.1179e-06  eta: 0:02:39  time: 0.5151  data_time: 0.0758  memory: 12680  loss: 0.0009  decode.loss_ce: 0.0009  decode.acc_seg: 99.2782
# 02/20 16:23:43 - mmengine - INFO - Iter(train) [ 9750/10000]  lr: 1.7649e-06  eta: 0:02:12  time: 0.5269  data_time: 0.0858  memory: 12680  loss: 0.0004  decode.loss_ce: 0.0004  decode.acc_seg: 99.8131
# 02/20 16:24:10 - mmengine - INFO - Iter(train) [ 9800/10000]  lr: 1.4119e-06  eta: 0:01:46  time: 0.5424  data_time: 0.1031  memory: 12680  loss: 0.0009  decode.loss_ce: 0.0009  decode.acc_seg: 100.0000
# 02/20 16:24:37 - mmengine - INFO - Iter(train) [ 9850/10000]  lr: 1.0589e-06  eta: 0:01:19  time: 0.4933  data_time: 0.0550  memory: 12680  loss: 0.0008  decode.loss_ce: 0.0008  decode.acc_seg: 99.8091
# 02/20 16:25:03 - mmengine - INFO - Iter(train) [ 9900/10000]  lr: 7.0597e-07  eta: 0:00:53  time: 0.5395  data_time: 0.1005  memory: 12680  loss: 0.0009  decode.loss_ce: 0.0009  decode.acc_seg: 100.0000
# 02/20 16:25:30 - mmengine - INFO - Iter(train) [ 9950/10000]  lr: 3.5298e-07  eta: 0:00:26  time: 0.5726  data_time: 0.1314  memory: 12680  loss: 0.0008  decode.loss_ce: 0.0008  decode.acc_seg: 99.4470
# 02/20 16:25:56 - mmengine - INFO - Exp name: chips_lassic_20240220_145605
# 02/20 16:25:56 - mmengine - INFO - Iter(train) [10000/10000]  lr: 0.0000e+00  eta: 0:00:00  time: 0.5060  data_time: 0.0672  memory: 12680  loss: 0.0008  decode.loss_ce: 0.0008  decode.acc_seg: 99.6600
# 02/20 16:25:56 - mmengine - INFO - Saving checkpoint at 10000 iterations
# 02/20 16:26:04 - mmengine - INFO - per class results:
# 02/20 16:26:04 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 99.68 | 99.76 |
# |  CADE | 99.27 | 99.98 |
# |  PILA |  98.8 | 99.43 |
# |  PIPJ | 99.07 | 99.86 |
# |  PSME | 98.69 | 98.83 |
# +-------+-------+-------+
# 02/20 16:26:04 - mmengine - INFO - Iter(val) [10/10]    aAcc: 99.5300  mIoU: 99.1000  mAcc: 99.5700  data_time: 0.3788  time: 0.4805
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/openmmlab/bin/python /ofo-share/repos-david/mmsegmentation/tools/train.py /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/chips_lassic.py --work-dir /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_lassic/work_dir', returncode=0)

# %%
TRAINING_DATA_FOLDER = get_training_data_folder(training_sites=TRAINING_SITES)
shutil.move(
    src=TRAINING_DATA_FOLDER_SCRATCH, dst=TRAINING_DATA_FOLDER, dirs_exist_ok=True
)
# Out:
# PosixPath('/ofo-share/scratch-david/organized-str-disp-MVMT-experiments/models/multi_site/chips_lassic')
