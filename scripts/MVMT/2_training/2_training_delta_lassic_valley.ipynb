# %%
# Standard library imports
import subprocess
import json
import shutil
import sys

# Contributed library imports
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread
from pathlib import Path

# Imports from the constants
sys.path.append("../..")
from constants import (
    get_aggregated_images_folder,
    get_aggregated_labels_folder,
    get_images_near_labels_folder,
    get_render_folder,
    get_training_data_folder,
    get_work_dir,
    MMSEG_PYTHON,
    TRAIN_SCRIPT,
    MMSEG_UTILS_PYTHON,
    FOLDER_TO_CITYSCAPES_SCRIPT,
)

# %% [markdown]
# # Set constants
# You should be able to define most of the behavior from these constants

# %%
TRAINING_SITES = sorted(["delta", "lassic", "valley"])

# %%
AGGREGATED_IMAGES_FOLDER = get_aggregated_images_folder(
    training_sites=TRAINING_SITES, is_ortho=False
)
AGGREGATED_LABELS_FOLDER = get_aggregated_labels_folder(
    training_sites=TRAINING_SITES, is_ortho=False
)

# We need to merge all the imagery together
# I think this should be stored in the models folder, alongside the real models
# It should be as simple as creating the folders and symlinking the existing ones into it
Path(AGGREGATED_IMAGES_FOLDER).mkdir(exist_ok=True, parents=True)
Path(AGGREGATED_LABELS_FOLDER).mkdir(exist_ok=True, parents=True)

for training_site in TRAINING_SITES:
    render_folder = get_render_folder(training_site)
    images_near_labels_folder = get_images_near_labels_folder(training_site)

    output_render_folder = Path(AGGREGATED_LABELS_FOLDER, training_site)
    output_image_folder = Path(AGGREGATED_IMAGES_FOLDER, training_site)

    # Unlink if symlink
    output_render_folder.unlink(missing_ok=True)
    output_image_folder.unlink(missing_ok=True)
    # Remove if folder
    shutil.rmtree(output_render_folder, ignore_errors=True)
    shutil.rmtree(output_image_folder, ignore_errors=True)

    shutil.copytree(render_folder, output_render_folder)
    shutil.copytree(images_near_labels_folder, output_image_folder)

# %%
TRAINING_DATA_FOLDER_SCRATCH = get_training_data_folder(
    training_sites=TRAINING_SITES, is_ortho=False, is_scratch=True
)

# Use one of the render folders, assuming they are all the same
IDs_to_labels_file = Path(render_folder, "IDs_to_labels.json")
with open(IDs_to_labels_file, "r") as infile:
    data = json.load(infile)

class_names = list(data.values())
class_names_str = " ".join(class_names)
print(class_names_str)

run_str = (
    f"{MMSEG_UTILS_PYTHON} {FOLDER_TO_CITYSCAPES_SCRIPT} --images-folder {AGGREGATED_IMAGES_FOLDER}"
    + f" --labels-folder {AGGREGATED_LABELS_FOLDER} --output-folder "
    + f"{TRAINING_DATA_FOLDER_SCRATCH} --classes {class_names_str} --remove-old"
)
print(run_str)
subprocess.run(
    run_str,
    shell=True,
)
# Out:
# ABCO CADE PILA PIPJ PSME
# /ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/MVMT/inputs/images --labels-folder /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/MVMT/inputs/labels --output-folder /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley --classes ABCO CADE PILA PIPJ PSME --remove-old
# Checking for completely null images: 100%|██████████| 1106/1106 [01:56<00:00,  9.47it/s]
# Linking files into either train or test folders: 100%|██████████| 1094/1094 [00:10<00:00, 100.85it/s]
# 100%|██████████| 20/20 [00:07<00:00,  2.63it/s]
# (3992372, 3)
# mean: [116.38644670386427, 119.81403937308447, 111.2464875517612], std: [58.99921706947808, 54.88850822503624, 51.974702102918954]
# About to save config to /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/MVMT_delta_lassic_valley.py
# visualizing to /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/vis/train: 100%|██████████| 11/11 [00:24<00:00,  2.27s/it]
# visualizing to /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/vis/val: 100%|██████████| 11/11 [00:23<00:00,  2.10s/it]
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/MVMT/inputs/images --labels-folder /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/MVMT/inputs/labels --output-folder /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley --classes ABCO CADE PILA PIPJ PSME --remove-old', returncode=0)

# %% [markdown]
# # Show some of the formatted example images

# %%
cmap_file = Path(TRAINING_DATA_FOLDER_SCRATCH, "colormap.png")
plt.imshow(imread(cmap_file))
plt.show()

vis_folder = Path(TRAINING_DATA_FOLDER_SCRATCH, "vis")
vis_files = list(vis_folder.rglob("*JPG"))
for file in np.random.choice(vis_files, 10):
    print(f"showing {file}")
    plt.imshow(imread(file))
    plt.show()
# Out:
# /tmp/ipykernel_1159908/4204227826.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(cmap_file))
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/vis/train/valley_ValleyA_120m_PART_01_101MEDIA_DJI_0604_rgb.JPG
# /tmp/ipykernel_1159908/4204227826.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(file))
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/vis/train/valley_ValleyA_120m_PART_01_101MEDIA_DJI_0021_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/vis/val/lassic_Lassic_120m_pt3_102MEDIA_DJI_0459_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/vis/val/lassic_Lassic_120m_pt2_patch_105MEDIA_DJI_0808_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/vis/train/delta_DeltaB_120m_PART_01_102MEDIA_DJI_0467_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/vis/train/lassic_Lassic_120m_pt3_102MEDIA_DJI_0163_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/vis/train/lassic_Lassic_120m_pt3_101MEDIA_DJI_0480_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/vis/train/lassic_Lassic_120m_part1_n_103MEDIA_DJI_0870_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/vis/train/delta_DeltaB_120m_PART_03_100MEDIA_DJI_0702_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/vis/train/lassic_Lassic_120m_part1_n_103MEDIA_DJI_0870_rgb.JPG

# %% [markdown]
# # Train a model

# %%
WORK_DIR_SCRATCH = get_work_dir(training_sites=TRAINING_SITES, is_ortho=False, is_scratch=True)

# Identify the config file as the only python file in the
config_file = list(Path(TRAINING_DATA_FOLDER_SCRATCH).glob("*py"))[0]
subprocess.run(
    f"{MMSEG_PYTHON} {TRAIN_SCRIPT} {config_file} --work-dir {WORK_DIR_SCRATCH}", shell=True
)
# Out:
# 03/06 18:51:22 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1187327867
#     GPU 0: GRID A100X-40C
#     CUDA_HOME: /ofo-share/repos-david/conda/envs/MVMT-stable
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1187327867
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/06 18:51:24 - mmengine - INFO - Config:
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[116.38644670386427, 119.81403937308447, 111.2464875517612],
#     std=[58.99921706947808, 54.88850822503624, 51.974702102918954],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(1024, 1024))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[116.38644670386427, 119.81403937308447, 111.2464875517612],
#         std=[58.99921706947808, 54.88850822503624, 51.974702102918954],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(1024, 1024)),
#     pretrained=None,
#     backbone=dict(
#         type='MixVisionTransformer',
#         in_channels=3,
#         embed_dims=64,
#         num_stages=4,
#         num_layers=[3, 6, 40, 3],
#         num_heads=[1, 2, 5, 8],
#         patch_sizes=[7, 3, 3, 3],
#         sr_ratios=[8, 4, 2, 1],
#         out_indices=(0, 1, 2, 3),
#         mlp_ratio=4,
#         qkv_bias=True,
#         drop_rate=0.0,
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
#         )),
#     decode_head=dict(
#         type='SegformerHead',
#         in_channels=[64, 128, 320, 512],
#         in_index=[0, 1, 2, 3],
#         channels=256,
#         dropout_ratio=0.1,
#         num_classes=5,
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='slide', crop_size=(1024, 1024), stride=(768, 768)))
# dataset_type = 'CityscapesForestsDataset'
# data_root = '/ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley'
# img_suffix = '_rgb.JPG'
# classes = ['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME']
# crop_size = (1024, 1024)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(2048, 1024),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(2048, 1024),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(
#                 type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(
#         type='AdamW', lr=6e-05, betas=(0.9, 0.999), weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             pos_block=dict(decay_mult=0.0),
#             norm=dict(decay_mult=0.0),
#             head=dict(lr_mult=10.0))))
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=1e-06, by_epoch=False, begin=0,
#         end=1500),
#     dict(
#         type='PolyLR',
#         eta_min=0.0,
#         power=1.0,
#         begin=1500,
#         end=10000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=10000, val_interval=1000)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=5000),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# checkpoint = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
# launcher = 'none'
# work_dir = '/ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/work_dir'
# /ofo-share/repos-david/mmsegmentation/mmseg/models/builder.py:42: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn(
# /ofo-share/repos-david/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:245: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 03/06 18:51:28 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 03/06 18:51:28 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /ofo-share/repos-david/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:64: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn(
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:lr=6e-05
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:weight_decay=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:decay_mult=0.0
# 03/06 18:51:33 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.attn.norm.weight:lr=6e-05
# ...
# |  ABCO | 90.28 | 95.94 |
# |  CADE | 89.71 | 95.18 |
# |  PILA | 85.88 | 88.86 |
# |  PIPJ | 90.27 | 94.47 |
# |  PSME | 83.64 | 91.38 |
# +-------+-------+-------+
# 03/06 19:57:56 - mmengine - INFO - Iter(val) [218/218]    aAcc: 94.1100  mIoU: 87.9600  mAcc: 93.1700  data_time: 0.2126  time: 0.4175
# 03/06 19:58:20 - mmengine - INFO - Iter(train) [ 7050/10000]  lr: 2.0826e-05  eta: 0:23:23  time: 0.4669  data_time: 0.0106  memory: 12681  loss: 0.0128  decode.loss_ce: 0.0128  decode.acc_seg: 93.8734
# 03/06 19:58:43 - mmengine - INFO - Iter(train) [ 7100/10000]  lr: 2.0473e-05  eta: 0:22:59  time: 0.4664  data_time: 0.0101  memory: 12681  loss: 0.0182  decode.loss_ce: 0.0182  decode.acc_seg: 92.0882
# 03/06 19:59:06 - mmengine - INFO - Iter(train) [ 7150/10000]  lr: 2.0120e-05  eta: 0:22:35  time: 0.4666  data_time: 0.0104  memory: 12681  loss: 0.0102  decode.loss_ce: 0.0102  decode.acc_seg: 90.0842
# 03/06 19:59:30 - mmengine - INFO - Iter(train) [ 7200/10000]  lr: 1.9767e-05  eta: 0:22:11  time: 0.4689  data_time: 0.0113  memory: 12681  loss: 0.0098  decode.loss_ce: 0.0098  decode.acc_seg: 92.6236
# 03/06 19:59:53 - mmengine - INFO - Iter(train) [ 7250/10000]  lr: 1.9414e-05  eta: 0:21:47  time: 0.4639  data_time: 0.0096  memory: 12681  loss: 0.0094  decode.loss_ce: 0.0094  decode.acc_seg: 96.7938
# 03/06 20:00:17 - mmengine - INFO - Iter(train) [ 7300/10000]  lr: 1.9061e-05  eta: 0:21:23  time: 0.4688  data_time: 0.0107  memory: 12681  loss: 0.0087  decode.loss_ce: 0.0087  decode.acc_seg: 100.0000
# 03/06 20:00:40 - mmengine - INFO - Iter(train) [ 7350/10000]  lr: 1.8708e-05  eta: 0:20:59  time: 0.4670  data_time: 0.0109  memory: 12681  loss: 0.0083  decode.loss_ce: 0.0083  decode.acc_seg: 89.2811
# 03/06 20:01:03 - mmengine - INFO - Iter(train) [ 7400/10000]  lr: 1.8355e-05  eta: 0:20:35  time: 0.4668  data_time: 0.0104  memory: 12681  loss: 0.0059  decode.loss_ce: 0.0059  decode.acc_seg: 97.4504
# 03/06 20:01:27 - mmengine - INFO - Iter(train) [ 7450/10000]  lr: 1.8002e-05  eta: 0:20:11  time: 0.4660  data_time: 0.0102  memory: 12681  loss: 0.0116  decode.loss_ce: 0.0116  decode.acc_seg: 97.0566
# 03/06 20:01:50 - mmengine - INFO - Iter(train) [ 7500/10000]  lr: 1.7649e-05  eta: 0:19:47  time: 0.4660  data_time: 0.0102  memory: 12681  loss: 0.0051  decode.loss_ce: 0.0051  decode.acc_seg: 98.3666
# 03/06 20:02:14 - mmengine - INFO - Iter(train) [ 7550/10000]  lr: 1.7296e-05  eta: 0:19:23  time: 0.4636  data_time: 0.0097  memory: 12681  loss: 0.0043  decode.loss_ce: 0.0043  decode.acc_seg: 98.3558
# 03/06 20:02:37 - mmengine - INFO - Iter(train) [ 7600/10000]  lr: 1.6943e-05  eta: 0:19:00  time: 0.4801  data_time: 0.0112  memory: 12681  loss: 0.0052  decode.loss_ce: 0.0052  decode.acc_seg: 94.9666
# 03/06 20:03:00 - mmengine - INFO - Iter(train) [ 7650/10000]  lr: 1.6590e-05  eta: 0:18:36  time: 0.4686  data_time: 0.0109  memory: 12681  loss: 0.0078  decode.loss_ce: 0.0078  decode.acc_seg: 95.2463
# 03/06 20:03:24 - mmengine - INFO - Iter(train) [ 7700/10000]  lr: 1.6237e-05  eta: 0:18:12  time: 0.4668  data_time: 0.0103  memory: 12681  loss: 0.0169  decode.loss_ce: 0.0169  decode.acc_seg: 92.0173
# 03/06 20:03:47 - mmengine - INFO - Iter(train) [ 7750/10000]  lr: 1.5884e-05  eta: 0:17:48  time: 0.4686  data_time: 0.0116  memory: 12681  loss: 0.0092  decode.loss_ce: 0.0092  decode.acc_seg: 93.3814
# 03/06 20:04:11 - mmengine - INFO - Iter(train) [ 7800/10000]  lr: 1.5531e-05  eta: 0:17:24  time: 0.4682  data_time: 0.0110  memory: 12681  loss: 0.0074  decode.loss_ce: 0.0074  decode.acc_seg: 95.2455
# 03/06 20:04:34 - mmengine - INFO - Iter(train) [ 7850/10000]  lr: 1.5178e-05  eta: 0:17:00  time: 0.4691  data_time: 0.0107  memory: 12681  loss: 0.0063  decode.loss_ce: 0.0063  decode.acc_seg: 95.3731
# 03/06 20:04:58 - mmengine - INFO - Iter(train) [ 7900/10000]  lr: 1.4825e-05  eta: 0:16:37  time: 0.4655  data_time: 0.0103  memory: 12681  loss: 0.0117  decode.loss_ce: 0.0117  decode.acc_seg: 95.5091
# 03/06 20:05:21 - mmengine - INFO - Iter(train) [ 7950/10000]  lr: 1.4472e-05  eta: 0:16:13  time: 0.4678  data_time: 0.0108  memory: 12681  loss: 0.0179  decode.loss_ce: 0.0179  decode.acc_seg: 94.5031
# 03/06 20:05:45 - mmengine - INFO - Exp name: MVMT_delta_lassic_valley_20240306_185120
# 03/06 20:05:45 - mmengine - INFO - Iter(train) [ 8000/10000]  lr: 1.4119e-05  eta: 0:15:49  time: 0.4693  data_time: 0.0106  memory: 12681  loss: 0.0072  decode.loss_ce: 0.0072  decode.acc_seg: 97.6043
# 03/06 20:06:07 - mmengine - INFO - Iter(val) [ 50/218]    eta: 0:01:15  time: 0.4565  data_time: 0.2518  memory: 1864
# 03/06 20:06:27 - mmengine - INFO - Iter(val) [100/218]    eta: 0:00:50  time: 0.3739  data_time: 0.1660  memory: 1864
# 03/06 20:06:48 - mmengine - INFO - Iter(val) [150/218]    eta: 0:00:28  time: 0.4552  data_time: 0.2514  memory: 1864
# 03/06 20:07:09 - mmengine - INFO - Iter(val) [200/218]    eta: 0:00:07  time: 0.3864  data_time: 0.1801  memory: 1864
# 03/06 20:07:16 - mmengine - INFO - per class results:
# 03/06 20:07:16 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 91.43 | 96.21 |
# |  CADE | 90.16 | 94.18 |
# |  PILA | 89.66 | 93.55 |
# |  PIPJ | 91.79 |  96.5 |
# |  PSME | 85.91 |  91.5 |
# +-------+-------+-------+
# 03/06 20:07:16 - mmengine - INFO - Iter(val) [218/218]    aAcc: 94.9200  mIoU: 89.7900  mAcc: 94.3900  data_time: 0.2122  time: 0.4187
# 03/06 20:07:40 - mmengine - INFO - Iter(train) [ 8050/10000]  lr: 1.3766e-05  eta: 0:15:25  time: 0.4699  data_time: 0.0114  memory: 12681  loss: 0.0073  decode.loss_ce: 0.0073  decode.acc_seg: 94.3800
# 03/06 20:08:03 - mmengine - INFO - Iter(train) [ 8100/10000]  lr: 1.3413e-05  eta: 0:15:01  time: 0.4686  data_time: 0.0110  memory: 12681  loss: 0.0048  decode.loss_ce: 0.0048  decode.acc_seg: 97.2555
# 03/06 20:08:27 - mmengine - INFO - Iter(train) [ 8150/10000]  lr: 1.3060e-05  eta: 0:14:38  time: 0.4704  data_time: 0.0115  memory: 12681  loss: 0.0095  decode.loss_ce: 0.0095  decode.acc_seg: 91.5020
# 03/06 20:08:50 - mmengine - INFO - Iter(train) [ 8200/10000]  lr: 1.2707e-05  eta: 0:14:14  time: 0.4715  data_time: 0.0111  memory: 12681  loss: 0.0102  decode.loss_ce: 0.0102  decode.acc_seg: 89.2913
# 03/06 20:09:14 - mmengine - INFO - Iter(train) [ 8250/10000]  lr: 1.2354e-05  eta: 0:13:50  time: 0.4665  data_time: 0.0106  memory: 12681  loss: 0.0105  decode.loss_ce: 0.0105  decode.acc_seg: 88.7929
# 03/06 20:09:37 - mmengine - INFO - Iter(train) [ 8300/10000]  lr: 1.2001e-05  eta: 0:13:26  time: 0.4679  data_time: 0.0108  memory: 12681  loss: 0.0054  decode.loss_ce: 0.0054  decode.acc_seg: 96.9469
# 03/06 20:10:01 - mmengine - INFO - Iter(train) [ 8350/10000]  lr: 1.1648e-05  eta: 0:13:02  time: 0.4707  data_time: 0.0118  memory: 12681  loss: 0.0056  decode.loss_ce: 0.0056  decode.acc_seg: 100.0000
# 03/06 20:10:24 - mmengine - INFO - Iter(train) [ 8400/10000]  lr: 1.1295e-05  eta: 0:12:39  time: 0.4683  data_time: 0.0107  memory: 12681  loss: 0.0151  decode.loss_ce: 0.0151  decode.acc_seg: 99.0727
# 03/06 20:10:48 - mmengine - INFO - Iter(train) [ 8450/10000]  lr: 1.0942e-05  eta: 0:12:15  time: 0.4701  data_time: 0.0107  memory: 12681  loss: 0.0070  decode.loss_ce: 0.0070  decode.acc_seg: 100.0000
# 03/06 20:11:11 - mmengine - INFO - Iter(train) [ 8500/10000]  lr: 1.0589e-05  eta: 0:11:51  time: 0.4664  data_time: 0.0101  memory: 12681  loss: 0.0056  decode.loss_ce: 0.0056  decode.acc_seg: 100.0000
# 03/06 20:11:34 - mmengine - INFO - Iter(train) [ 8550/10000]  lr: 1.0236e-05  eta: 0:11:27  time: 0.4716  data_time: 0.0114  memory: 12681  loss: 0.0063  decode.loss_ce: 0.0063  decode.acc_seg: 95.1857
# 03/06 20:11:58 - mmengine - INFO - Iter(train) [ 8600/10000]  lr: 9.8835e-06  eta: 0:11:04  time: 0.4678  data_time: 0.0117  memory: 12681  loss: 0.0137  decode.loss_ce: 0.0137  decode.acc_seg: 97.1643
# 03/06 20:12:21 - mmengine - INFO - Iter(train) [ 8650/10000]  lr: 9.5305e-06  eta: 0:10:40  time: 0.4662  data_time: 0.0106  memory: 12681  loss: 0.0065  decode.loss_ce: 0.0065  decode.acc_seg: 93.4336
# 03/06 20:12:45 - mmengine - INFO - Iter(train) [ 8700/10000]  lr: 9.1776e-06  eta: 0:10:16  time: 0.4720  data_time: 0.0125  memory: 12681  loss: 0.0123  decode.loss_ce: 0.0123  decode.acc_seg: 96.4709
# 03/06 20:13:08 - mmengine - INFO - Iter(train) [ 8750/10000]  lr: 8.8246e-06  eta: 0:09:52  time: 0.4699  data_time: 0.0109  memory: 12681  loss: 0.0086  decode.loss_ce: 0.0086  decode.acc_seg: 95.2099
# 03/06 20:13:32 - mmengine - INFO - Iter(train) [ 8800/10000]  lr: 8.4716e-06  eta: 0:09:29  time: 0.4704  data_time: 0.0118  memory: 12681  loss: 0.0084  decode.loss_ce: 0.0084  decode.acc_seg: 89.3402
# 03/06 20:13:55 - mmengine - INFO - Iter(train) [ 8850/10000]  lr: 8.1186e-06  eta: 0:09:05  time: 0.4698  data_time: 0.0114  memory: 12681  loss: 0.0073  decode.loss_ce: 0.0073  decode.acc_seg: 99.3697
# 03/06 20:14:19 - mmengine - INFO - Iter(train) [ 8900/10000]  lr: 7.7656e-06  eta: 0:08:41  time: 0.4692  data_time: 0.0115  memory: 12681  loss: 0.0057  decode.loss_ce: 0.0057  decode.acc_seg: 98.3164
# 03/06 20:14:42 - mmengine - INFO - Iter(train) [ 8950/10000]  lr: 7.4126e-06  eta: 0:08:17  time: 0.4843  data_time: 0.0111  memory: 12681  loss: 0.0082  decode.loss_ce: 0.0082  decode.acc_seg: 96.3523
# 03/06 20:15:06 - mmengine - INFO - Exp name: MVMT_delta_lassic_valley_20240306_185120
# 03/06 20:15:06 - mmengine - INFO - Iter(train) [ 9000/10000]  lr: 7.0597e-06  eta: 0:07:54  time: 0.4698  data_time: 0.0109  memory: 12681  loss: 0.0051  decode.loss_ce: 0.0051  decode.acc_seg: 99.8533
# 03/06 20:15:28 - mmengine - INFO - Iter(val) [ 50/218]    eta: 0:01:14  time: 0.4439  data_time: 0.2414  memory: 1864
# 03/06 20:15:48 - mmengine - INFO - Iter(val) [100/218]    eta: 0:00:50  time: 0.3804  data_time: 0.1771  memory: 1864
# 03/06 20:16:09 - mmengine - INFO - Iter(val) [150/218]    eta: 0:00:28  time: 0.4557  data_time: 0.2526  memory: 1864
# 03/06 20:16:30 - mmengine - INFO - Iter(val) [200/218]    eta: 0:00:07  time: 0.3792  data_time: 0.1739  memory: 1864
# 03/06 20:16:37 - mmengine - INFO - per class results:
# 03/06 20:16:37 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 91.95 | 95.48 |
# |  CADE |  90.9 | 94.95 |
# |  PILA | 88.54 | 90.91 |
# |  PIPJ | 91.82 | 96.99 |
# |  PSME | 86.51 | 93.38 |
# +-------+-------+-------+
# 03/06 20:16:37 - mmengine - INFO - Iter(val) [218/218]    aAcc: 95.0900  mIoU: 89.9400  mAcc: 94.3400  data_time: 0.2113  time: 0.4167
# 03/06 20:17:01 - mmengine - INFO - Iter(train) [ 9050/10000]  lr: 6.7067e-06  eta: 0:07:30  time: 0.4715  data_time: 0.0115  memory: 12681  loss: 0.0079  decode.loss_ce: 0.0079  decode.acc_seg: 99.9678
# 03/06 20:17:24 - mmengine - INFO - Iter(train) [ 9100/10000]  lr: 6.3537e-06  eta: 0:07:06  time: 0.4664  data_time: 0.0103  memory: 12681  loss: 0.0057  decode.loss_ce: 0.0057  decode.acc_seg: 88.6520
# 03/06 20:17:47 - mmengine - INFO - Iter(train) [ 9150/10000]  lr: 6.0007e-06  eta: 0:06:42  time: 0.4685  data_time: 0.0113  memory: 12681  loss: 0.0125  decode.loss_ce: 0.0125  decode.acc_seg: 98.4562
# 03/06 20:18:11 - mmengine - INFO - Iter(train) [ 9200/10000]  lr: 5.6477e-06  eta: 0:06:19  time: 0.4677  data_time: 0.0107  memory: 12681  loss: 0.0058  decode.loss_ce: 0.0058  decode.acc_seg: 99.9822
# 03/06 20:18:34 - mmengine - INFO - Iter(train) [ 9250/10000]  lr: 5.2947e-06  eta: 0:05:55  time: 0.4696  data_time: 0.0110  memory: 12681  loss: 0.0053  decode.loss_ce: 0.0053  decode.acc_seg: 97.6061
# 03/06 20:18:58 - mmengine - INFO - Iter(train) [ 9300/10000]  lr: 4.9418e-06  eta: 0:05:31  time: 0.4725  data_time: 0.0125  memory: 12681  loss: 0.0079  decode.loss_ce: 0.0079  decode.acc_seg: 96.2701
# 03/06 20:19:21 - mmengine - INFO - Iter(train) [ 9350/10000]  lr: 4.5888e-06  eta: 0:05:08  time: 0.4691  data_time: 0.0106  memory: 12681  loss: 0.0126  decode.loss_ce: 0.0126  decode.acc_seg: 98.0113
# 03/06 20:19:45 - mmengine - INFO - Iter(train) [ 9400/10000]  lr: 4.2358e-06  eta: 0:04:44  time: 0.4680  data_time: 0.0114  memory: 12681  loss: 0.0085  decode.loss_ce: 0.0085  decode.acc_seg: 97.8429
# 03/06 20:20:08 - mmengine - INFO - Iter(train) [ 9450/10000]  lr: 3.8828e-06  eta: 0:04:20  time: 0.4717  data_time: 0.0113  memory: 12681  loss: 0.0064  decode.loss_ce: 0.0064  decode.acc_seg: 97.3795
# 03/06 20:20:32 - mmengine - INFO - Iter(train) [ 9500/10000]  lr: 3.5298e-06  eta: 0:03:56  time: 0.4699  data_time: 0.0116  memory: 12681  loss: 0.0067  decode.loss_ce: 0.0067  decode.acc_seg: 98.2068
# 03/06 20:20:55 - mmengine - INFO - Iter(train) [ 9550/10000]  lr: 3.1768e-06  eta: 0:03:33  time: 0.4675  data_time: 0.0106  memory: 12681  loss: 0.0053  decode.loss_ce: 0.0053  decode.acc_seg: 95.2837
# 03/06 20:21:19 - mmengine - INFO - Iter(train) [ 9600/10000]  lr: 2.8239e-06  eta: 0:03:09  time: 0.4704  data_time: 0.0114  memory: 12681  loss: 0.0054  decode.loss_ce: 0.0054  decode.acc_seg: 91.3719
# 03/06 20:21:42 - mmengine - INFO - Iter(train) [ 9650/10000]  lr: 2.4709e-06  eta: 0:02:45  time: 0.4676  data_time: 0.0104  memory: 12681  loss: 0.0079  decode.loss_ce: 0.0079  decode.acc_seg: 97.8773
# 03/06 20:22:06 - mmengine - INFO - Iter(train) [ 9700/10000]  lr: 2.1179e-06  eta: 0:02:22  time: 0.4718  data_time: 0.0121  memory: 12681  loss: 0.0074  decode.loss_ce: 0.0074  decode.acc_seg: 92.2450
# 03/06 20:22:29 - mmengine - INFO - Iter(train) [ 9750/10000]  lr: 1.7649e-06  eta: 0:01:58  time: 0.4696  data_time: 0.0111  memory: 12681  loss: 0.0042  decode.loss_ce: 0.0042  decode.acc_seg: 98.7744
# 03/06 20:22:53 - mmengine - INFO - Iter(train) [ 9800/10000]  lr: 1.4119e-06  eta: 0:01:34  time: 0.4690  data_time: 0.0108  memory: 12681  loss: 0.0037  decode.loss_ce: 0.0037  decode.acc_seg: 100.0000
# 03/06 20:23:16 - mmengine - INFO - Iter(train) [ 9850/10000]  lr: 1.0589e-06  eta: 0:01:11  time: 0.4711  data_time: 0.0115  memory: 12681  loss: 0.0065  decode.loss_ce: 0.0065  decode.acc_seg: 98.9413
# 03/06 20:23:40 - mmengine - INFO - Iter(train) [ 9900/10000]  lr: 7.0597e-07  eta: 0:00:47  time: 0.4712  data_time: 0.0117  memory: 12681  loss: 0.0068  decode.loss_ce: 0.0068  decode.acc_seg: 96.7309
# 03/06 20:24:03 - mmengine - INFO - Iter(train) [ 9950/10000]  lr: 3.5298e-07  eta: 0:00:23  time: 0.4690  data_time: 0.0111  memory: 12681  loss: 0.0090  decode.loss_ce: 0.0090  decode.acc_seg: 97.5075
# 03/06 20:24:27 - mmengine - INFO - Exp name: MVMT_delta_lassic_valley_20240306_185120
# 03/06 20:24:27 - mmengine - INFO - Iter(train) [10000/10000]  lr: 0.0000e+00  eta: 0:00:00  time: 0.4675  data_time: 0.0106  memory: 12681  loss: 0.0036  decode.loss_ce: 0.0036  decode.acc_seg: 98.0828
# 03/06 20:24:27 - mmengine - INFO - Saving checkpoint at 10000 iterations
# 03/06 20:24:54 - mmengine - INFO - Iter(val) [ 50/218]    eta: 0:01:16  time: 0.4437  data_time: 0.2319  memory: 1864
# 03/06 20:25:15 - mmengine - INFO - Iter(val) [100/218]    eta: 0:00:50  time: 0.3737  data_time: 0.1629  memory: 1864
# 03/06 20:25:35 - mmengine - INFO - Iter(val) [150/218]    eta: 0:00:28  time: 0.4536  data_time: 0.2419  memory: 1864
# 03/06 20:25:56 - mmengine - INFO - Iter(val) [200/218]    eta: 0:00:07  time: 0.3779  data_time: 0.1644  memory: 1864
# 03/06 20:26:03 - mmengine - INFO - per class results:
# 03/06 20:26:03 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 92.08 | 97.09 |
# |  CADE | 90.64 | 94.41 |
# |  PILA |  89.2 | 92.18 |
# |  PIPJ | 92.15 | 96.14 |
# |  PSME | 86.95 | 93.22 |
# +-------+-------+-------+
# 03/06 20:26:03 - mmengine - INFO - Iter(val) [218/218]    aAcc: 95.1800  mIoU: 90.2000  mAcc: 94.6100  data_time: 0.2058  time: 0.4166
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/openmmlab/bin/python /ofo-share/repos-david/mmsegmentation/tools/train.py /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/MVMT_delta_lassic_valley.py --work-dir /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_delta_lassic_valley/work_dir', returncode=0)

# %% [markdown]
# # Move resuts from scratch

# %%
TRAINING_DATA_FOLDER = get_training_data_folder(training_sites=TRAINING_SITES, is_ortho=False, is_scratch=False)
shutil.move(TRAINING_DATA_FOLDER_SCRATCH, TRAINING_DATA_FOLDER)
# Out:
# PosixPath('/ofo-share/scratch-derek/organized-str-disp-MVMT-experiments/models/multi_site/MVMT_delta_lassic_valley')
