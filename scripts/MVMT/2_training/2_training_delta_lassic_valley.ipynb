# %%
# Standard library imports
import subprocess
import json
import shutil
import sys

# Contributed library imports
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread
from pathlib import Path

# Imports from the constants
sys.path.append("../..")
from constants import (
    get_aggregated_images_folder,
    get_aggregated_labels_folder,
    get_images_near_labels_folder,
    get_render_folder,
    get_training_data_folder,
    get_work_dir,
    MMSEG_PYTHON,
    TRAIN_SCRIPT,
    MMSEG_UTILS_PYTHON,
    FOLDER_TO_CITYSCAPES_SCRIPT,
)

# %% [markdown]
# # Set constants
# You should be able to define most of the behavior from these constants

# %%
TRAINING_SITES = sorted(["delta", "lassic", "valley"])

# %%
AGGREGATED_IMAGES_FOLDER = get_aggregated_images_folder(
    training_sites=TRAINING_SITES, is_ortho=False
)
AGGREGATED_LABELS_FOLDER = get_aggregated_labels_folder(
    training_sites=TRAINING_SITES, is_ortho=False
)

# We need to merge all the imagery together
# I think this should be stored in the models folder, alongside the real models
# It should be as simple as creating the folders and symlinking the existing ones into it
Path(AGGREGATED_IMAGES_FOLDER).mkdir(exist_ok=True, parents=True)
Path(AGGREGATED_LABELS_FOLDER).mkdir(exist_ok=True, parents=True)

for training_site in TRAINING_SITES:
    render_folder = get_render_folder(training_site)
    images_near_labels_folder = get_images_near_labels_folder(training_site)

    output_render_folder = Path(AGGREGATED_LABELS_FOLDER, training_site)
    output_image_folder = Path(AGGREGATED_IMAGES_FOLDER, training_site)

    # Unlink if symlink
    output_render_folder.unlink(missing_ok=True)
    output_image_folder.unlink(missing_ok=True)
    # Remove if folder
    shutil.rmtree(output_render_folder, ignore_errors=True)
    shutil.rmtree(output_image_folder, ignore_errors=True)

    shutil.copytree(render_folder, output_render_folder)
    shutil.copytree(images_near_labels_folder, output_image_folder)

# %%
TRAINING_DATA_FOLDER_SCRATCH = get_training_data_folder(
    training_sites=TRAINING_SITES, is_ortho=False, is_scratch=True
)

# Use one of the render folders, assuming they are all the same
IDs_to_labels_file = Path(render_folder, "IDs_to_labels.json")
with open(IDs_to_labels_file, "r") as infile:
    data = json.load(infile)

class_names = list(data.values())
class_names_str = " ".join(class_names)
print(class_names_str)

run_str = (
    f"{MMSEG_UTILS_PYTHON} {FOLDER_TO_CITYSCAPES_SCRIPT} --images-folder {AGGREGATED_IMAGES_FOLDER}"
    + f" --labels-folder {AGGREGATED_LABELS_FOLDER} --output-folder "
    + f"{TRAINING_DATA_FOLDER_SCRATCH} --classes {class_names_str} --remove-old"
)
print(run_str)
subprocess.run(
    run_str,
    shell=True,
)
# Out:
# ABCO CADE PILA PIPJ PSME
# /ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/MVMT/inputs/images --labels-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/MVMT/inputs/labels --output-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley --classes ABCO CADE PILA PIPJ PSME --remove-old
# Checking for completely null images: 100%|██████████| 1340/1340 [02:01<00:00, 10.99it/s]
# Linking files into either train or test folders: 100%|██████████| 1083/1083 [00:00<00:00, 12565.93it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.04it/s]
# (3992372, 3)
# mean: [111.86396808714218, 115.38363734641962, 100.87370841194158], std: [62.99529928616175, 59.40815749999912, 54.149430308670674]
# About to save config to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/MVMT_delta_lassic_valley.py
# visualizing to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/vis/train: 100%|██████████| 11/11 [00:21<00:00,  1.92s/it]
# visualizing to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/vis/val: 100%|██████████| 11/11 [00:20<00:00,  1.91s/it]
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/MVMT/inputs/images --labels-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/MVMT/inputs/labels --output-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley --classes ABCO CADE PILA PIPJ PSME --remove-old', returncode=0)

# %% [markdown]
# # Show some of the formatted example images

# %%
cmap_file = Path(TRAINING_DATA_FOLDER_SCRATCH, "colormap.png")
plt.imshow(imread(cmap_file))
plt.show()

vis_folder = Path(TRAINING_DATA_FOLDER_SCRATCH, "vis")
vis_files = list(vis_folder.rglob("*JPG"))
for file in np.random.choice(vis_files, 10):
    print(f"showing {file}")
    plt.imshow(imread(file))
    plt.show()
# Out:
# /tmp/ipykernel_4403/4204227826.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(cmap_file))
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/vis/train/delta_DeltaB_80m_PART_03_100MEDIA_DJI_0318_rgb.JPG
# /tmp/ipykernel_4403/4204227826.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(file))
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/vis/train/delta_DeltaB_80m_PART_02_104MEDIA_DJI_0601_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/vis/train/delta_DeltaB_80m_PART_03_102MEDIA_DJI_0584_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/vis/train/valley_ValleyA_90m_PART_01_103MEDIA_DJI_0506_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/vis/train/delta_DeltaB_80m_PART_01_104MEDIA_DJI_0177_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/vis/train/delta_DeltaB_80m_PART_01_104MEDIA_DJI_0177_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/vis/val/lassic_Lassic_80m_pt3_ew_104MEDIA_DJI_0987_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/vis/val/delta_DeltaB_80m_PART_01_104MEDIA_DJI_0182_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/vis/train/delta_DeltaB_80m_PART_02_103MEDIA_DJI_0583_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/vis/val/lassic_Lassic_80m_pt1_ns_104MEDIA_DJI_0798_rgb.JPG

# %% [markdown]
# # Train a model

# %%
WORK_DIR_SCRATCH = get_work_dir(training_sites=TRAINING_SITES, is_ortho=False, is_scratch=True)

# Identify the config file as the only python file in the
config_file = list(Path(TRAINING_DATA_FOLDER_SCRATCH).glob("*py"))[0]
subprocess.run(
    f"{MMSEG_PYTHON} {TRAIN_SCRIPT} {config_file} --work-dir {WORK_DIR_SCRATCH}", shell=True
)
# Out:
# 02/25 21:37:32 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 589649322
#     GPU 0: GRID A100X-20C
#     CUDA_HOME: /ofo-share/repos-david/conda/envs/MVMT-stable
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 589649322
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/25 21:37:33 - mmengine - INFO - Config:
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[111.86396808714218, 115.38363734641962, 100.87370841194158],
#     std=[62.99529928616175, 59.40815749999912, 54.149430308670674],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(1024, 1024))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[111.86396808714218, 115.38363734641962, 100.87370841194158],
#         std=[62.99529928616175, 59.40815749999912, 54.149430308670674],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(1024, 1024)),
#     pretrained=None,
#     backbone=dict(
#         type='MixVisionTransformer',
#         in_channels=3,
#         embed_dims=64,
#         num_stages=4,
#         num_layers=[3, 6, 40, 3],
#         num_heads=[1, 2, 5, 8],
#         patch_sizes=[7, 3, 3, 3],
#         sr_ratios=[8, 4, 2, 1],
#         out_indices=(0, 1, 2, 3),
#         mlp_ratio=4,
#         qkv_bias=True,
#         drop_rate=0.0,
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
#         )),
#     decode_head=dict(
#         type='SegformerHead',
#         in_channels=[64, 128, 320, 512],
#         in_index=[0, 1, 2, 3],
#         channels=256,
#         dropout_ratio=0.1,
#         num_classes=5,
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='slide', crop_size=(1024, 1024), stride=(768, 768)))
# dataset_type = 'CityscapesForestsDataset'
# data_root = '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley'
# img_suffix = '_rgb.JPG'
# classes = ['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME']
# crop_size = (1024, 1024)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(2048, 1024),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(2048, 1024),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(
#                 type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(
#         type='AdamW', lr=6e-05, betas=(0.9, 0.999), weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             pos_block=dict(decay_mult=0.0),
#             norm=dict(decay_mult=0.0),
#             head=dict(lr_mult=10.0))))
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=1e-06, by_epoch=False, begin=0,
#         end=1500),
#     dict(
#         type='PolyLR',
#         eta_min=0.0,
#         power=1.0,
#         begin=1500,
#         end=10000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=10000, val_interval=1000)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=5000),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# checkpoint = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
# launcher = 'none'
# work_dir = '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/work_dir'
#
# 02/25 21:37:42 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/25 21:37:42 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /ofo-share/repos-david/mmsegmentation/mmseg/models/builder.py:42: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn(
# /ofo-share/repos-david/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:245: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# /ofo-share/repos-david/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:64: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn(
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:lr=6e-05
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:weight_decay=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:decay_mult=0.0
# 02/25 21:37:45 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.attn.norm.weight:lr=6e-05
# ...
# +-------+-------+-------+
# |  ABCO | 83.66 |  89.0 |
# |  CADE | 83.78 | 90.33 |
# |  PILA | 83.66 | 92.03 |
# |  PIPJ | 86.31 | 95.52 |
# |  PSME | 78.01 | 84.84 |
# +-------+-------+-------+
# 02/25 22:46:55 - mmengine - INFO - Iter(val) [216/216]    aAcc: 91.1700  mIoU: 83.0900  mAcc: 90.3400  data_time: 0.2456  time: 0.4466
# 02/25 22:47:19 - mmengine - INFO - Iter(train) [ 7050/10000]  lr: 2.0826e-05  eta: 0:24:16  time: 0.4721  data_time: 0.0144  memory: 12680  loss: 0.0193  decode.loss_ce: 0.0193  decode.acc_seg: 92.2689
# 02/25 22:47:43 - mmengine - INFO - Iter(train) [ 7100/10000]  lr: 2.0473e-05  eta: 0:23:51  time: 0.4701  data_time: 0.0133  memory: 12680  loss: 0.0136  decode.loss_ce: 0.0136  decode.acc_seg: 94.5039
# 02/25 22:48:07 - mmengine - INFO - Iter(train) [ 7150/10000]  lr: 2.0120e-05  eta: 0:23:26  time: 0.4817  data_time: 0.0206  memory: 12680  loss: 0.0337  decode.loss_ce: 0.0337  decode.acc_seg: 56.2570
# 02/25 22:48:30 - mmengine - INFO - Iter(train) [ 7200/10000]  lr: 1.9767e-05  eta: 0:23:01  time: 0.4746  data_time: 0.0147  memory: 12680  loss: 0.0109  decode.loss_ce: 0.0109  decode.acc_seg: 88.9954
# 02/25 22:48:55 - mmengine - INFO - Iter(train) [ 7250/10000]  lr: 1.9414e-05  eta: 0:22:37  time: 0.4741  data_time: 0.0174  memory: 12680  loss: 0.0339  decode.loss_ce: 0.0339  decode.acc_seg: 82.6185
# 02/25 22:49:19 - mmengine - INFO - Iter(train) [ 7300/10000]  lr: 1.9061e-05  eta: 0:22:12  time: 0.4730  data_time: 0.0137  memory: 12680  loss: 0.0212  decode.loss_ce: 0.0212  decode.acc_seg: 100.0000
# 02/25 22:49:44 - mmengine - INFO - Iter(train) [ 7350/10000]  lr: 1.8708e-05  eta: 0:21:47  time: 0.4706  data_time: 0.0124  memory: 12680  loss: 0.0100  decode.loss_ce: 0.0100  decode.acc_seg: 100.0000
# 02/25 22:50:08 - mmengine - INFO - Iter(train) [ 7400/10000]  lr: 1.8355e-05  eta: 0:21:22  time: 0.4728  data_time: 0.0137  memory: 12680  loss: 0.0137  decode.loss_ce: 0.0137  decode.acc_seg: 96.3641
# 02/25 22:50:33 - mmengine - INFO - Iter(train) [ 7450/10000]  lr: 1.8002e-05  eta: 0:20:58  time: 0.4867  data_time: 0.0346  memory: 12680  loss: 0.0142  decode.loss_ce: 0.0142  decode.acc_seg: 93.0556
# 02/25 22:50:58 - mmengine - INFO - Iter(train) [ 7500/10000]  lr: 1.7649e-05  eta: 0:20:33  time: 0.5222  data_time: 0.0644  memory: 12680  loss: 0.0217  decode.loss_ce: 0.0217  decode.acc_seg: 83.7679
# 02/25 22:51:23 - mmengine - INFO - Iter(train) [ 7550/10000]  lr: 1.7296e-05  eta: 0:20:08  time: 0.4747  data_time: 0.0217  memory: 12680  loss: 0.0168  decode.loss_ce: 0.0168  decode.acc_seg: 90.4764
# 02/25 22:51:48 - mmengine - INFO - Iter(train) [ 7600/10000]  lr: 1.6943e-05  eta: 0:19:44  time: 0.4752  data_time: 0.0194  memory: 12680  loss: 0.0131  decode.loss_ce: 0.0131  decode.acc_seg: 100.0000
# 02/25 22:52:13 - mmengine - INFO - Iter(train) [ 7650/10000]  lr: 1.6590e-05  eta: 0:19:19  time: 0.5390  data_time: 0.0839  memory: 12680  loss: 0.0122  decode.loss_ce: 0.0122  decode.acc_seg: 94.6305
# 02/25 22:52:38 - mmengine - INFO - Iter(train) [ 7700/10000]  lr: 1.6237e-05  eta: 0:18:55  time: 0.5008  data_time: 0.0485  memory: 12680  loss: 0.0080  decode.loss_ce: 0.0080  decode.acc_seg: 92.8204
# 02/25 22:53:03 - mmengine - INFO - Iter(train) [ 7750/10000]  lr: 1.5884e-05  eta: 0:18:30  time: 0.4833  data_time: 0.0281  memory: 12680  loss: 0.0278  decode.loss_ce: 0.0278  decode.acc_seg: 94.0001
# 02/25 22:53:27 - mmengine - INFO - Iter(train) [ 7800/10000]  lr: 1.5531e-05  eta: 0:18:05  time: 0.4700  data_time: 0.0135  memory: 12680  loss: 0.0164  decode.loss_ce: 0.0164  decode.acc_seg: 99.1510
# 02/25 22:53:51 - mmengine - INFO - Iter(train) [ 7850/10000]  lr: 1.5178e-05  eta: 0:17:41  time: 0.4991  data_time: 0.0440  memory: 12680  loss: 0.0144  decode.loss_ce: 0.0144  decode.acc_seg: 99.5845
# 02/25 22:54:17 - mmengine - INFO - Iter(train) [ 7900/10000]  lr: 1.4825e-05  eta: 0:17:16  time: 0.5283  data_time: 0.0740  memory: 12680  loss: 0.0074  decode.loss_ce: 0.0074  decode.acc_seg: 100.0000
# 02/25 22:54:43 - mmengine - INFO - Iter(train) [ 7950/10000]  lr: 1.4472e-05  eta: 0:16:52  time: 0.4685  data_time: 0.0122  memory: 12680  loss: 0.0181  decode.loss_ce: 0.0181  decode.acc_seg: 95.6402
# 02/25 22:55:07 - mmengine - INFO - Exp name: MVMT_delta_lassic_valley_20240225_213730
# 02/25 22:55:07 - mmengine - INFO - Iter(train) [ 8000/10000]  lr: 1.4119e-05  eta: 0:16:27  time: 0.4894  data_time: 0.0302  memory: 12680  loss: 0.0193  decode.loss_ce: 0.0193  decode.acc_seg: 92.4413
# 02/25 22:55:32 - mmengine - INFO - Iter(val) [ 50/216]    eta: 0:01:23  time: 0.4742  data_time: 0.2734  memory: 1863
# 02/25 22:55:53 - mmengine - INFO - Iter(val) [100/216]    eta: 0:00:53  time: 0.3894  data_time: 0.1880  memory: 1863
# 02/25 22:56:15 - mmengine - INFO - Iter(val) [150/216]    eta: 0:00:30  time: 0.4700  data_time: 0.2662  memory: 1863
# 02/25 22:56:37 - mmengine - INFO - Iter(val) [200/216]    eta: 0:00:07  time: 0.3913  data_time: 0.1901  memory: 1863
# 02/25 22:56:44 - mmengine - INFO - per class results:
# 02/25 22:56:44 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 85.29 | 91.11 |
# |  CADE | 85.13 | 90.05 |
# |  PILA | 86.38 | 94.99 |
# |  PIPJ | 88.88 | 95.78 |
# |  PSME | 80.56 | 88.32 |
# +-------+-------+-------+
# 02/25 22:56:44 - mmengine - INFO - Iter(val) [216/216]    aAcc: 92.3900  mIoU: 85.2500  mAcc: 92.0500  data_time: 0.2458  time: 0.4475
# 02/25 22:57:07 - mmengine - INFO - Iter(train) [ 8050/10000]  lr: 1.3766e-05  eta: 0:16:02  time: 0.4680  data_time: 0.0130  memory: 12680  loss: 0.0117  decode.loss_ce: 0.0117  decode.acc_seg: 34.8425
# 02/25 22:57:32 - mmengine - INFO - Iter(train) [ 8100/10000]  lr: 1.3413e-05  eta: 0:15:37  time: 0.4751  data_time: 0.0151  memory: 12680  loss: 0.0174  decode.loss_ce: 0.0174  decode.acc_seg: 96.0952
# 02/25 22:57:56 - mmengine - INFO - Iter(train) [ 8150/10000]  lr: 1.3060e-05  eta: 0:15:12  time: 0.4919  data_time: 0.0372  memory: 12680  loss: 0.0174  decode.loss_ce: 0.0174  decode.acc_seg: 98.8098
# 02/25 22:58:21 - mmengine - INFO - Iter(train) [ 8200/10000]  lr: 1.2707e-05  eta: 0:14:48  time: 0.5292  data_time: 0.0769  memory: 12680  loss: 0.0203  decode.loss_ce: 0.0203  decode.acc_seg: 76.3578
# 02/25 22:58:45 - mmengine - INFO - Iter(train) [ 8250/10000]  lr: 1.2354e-05  eta: 0:14:23  time: 0.4702  data_time: 0.0145  memory: 12680  loss: 0.0241  decode.loss_ce: 0.0241  decode.acc_seg: 83.2926
# 02/25 22:59:11 - mmengine - INFO - Iter(train) [ 8300/10000]  lr: 1.2001e-05  eta: 0:13:59  time: 0.4665  data_time: 0.0114  memory: 12680  loss: 0.0262  decode.loss_ce: 0.0262  decode.acc_seg: 86.4920
# 02/25 22:59:35 - mmengine - INFO - Iter(train) [ 8350/10000]  lr: 1.1648e-05  eta: 0:13:34  time: 0.4668  data_time: 0.0121  memory: 12680  loss: 0.0175  decode.loss_ce: 0.0175  decode.acc_seg: 94.8580
# 02/25 23:00:00 - mmengine - INFO - Iter(train) [ 8400/10000]  lr: 1.1295e-05  eta: 0:13:09  time: 0.5153  data_time: 0.0579  memory: 12680  loss: 0.0165  decode.loss_ce: 0.0165  decode.acc_seg: 100.0000
# 02/25 23:00:25 - mmengine - INFO - Iter(train) [ 8450/10000]  lr: 1.0942e-05  eta: 0:12:45  time: 0.4660  data_time: 0.0117  memory: 12680  loss: 0.0175  decode.loss_ce: 0.0175  decode.acc_seg: 100.0000
# 02/25 23:00:50 - mmengine - INFO - Iter(train) [ 8500/10000]  lr: 1.0589e-05  eta: 0:12:20  time: 0.5224  data_time: 0.0676  memory: 12680  loss: 0.0105  decode.loss_ce: 0.0105  decode.acc_seg: 97.3893
# 02/25 23:01:14 - mmengine - INFO - Iter(train) [ 8550/10000]  lr: 1.0236e-05  eta: 0:11:55  time: 0.4755  data_time: 0.0192  memory: 12680  loss: 0.0117  decode.loss_ce: 0.0117  decode.acc_seg: 99.4052
# 02/25 23:01:39 - mmengine - INFO - Iter(train) [ 8600/10000]  lr: 9.8835e-06  eta: 0:11:30  time: 0.4674  data_time: 0.0121  memory: 12680  loss: 0.0183  decode.loss_ce: 0.0183  decode.acc_seg: 98.5698
# 02/25 23:02:04 - mmengine - INFO - Iter(train) [ 8650/10000]  lr: 9.5305e-06  eta: 0:11:06  time: 0.4783  data_time: 0.0221  memory: 12680  loss: 0.0206  decode.loss_ce: 0.0206  decode.acc_seg: 100.0000
# 02/25 23:02:28 - mmengine - INFO - Iter(train) [ 8700/10000]  lr: 9.1776e-06  eta: 0:10:41  time: 0.5138  data_time: 0.0567  memory: 12680  loss: 0.0127  decode.loss_ce: 0.0127  decode.acc_seg: 94.5889
# 02/25 23:02:55 - mmengine - INFO - Iter(train) [ 8750/10000]  lr: 8.8246e-06  eta: 0:10:17  time: 0.4664  data_time: 0.0149  memory: 12680  loss: 0.0181  decode.loss_ce: 0.0181  decode.acc_seg: 97.8588
# 02/25 23:03:18 - mmengine - INFO - Iter(train) [ 8800/10000]  lr: 8.4716e-06  eta: 0:09:52  time: 0.4971  data_time: 0.0282  memory: 12680  loss: 0.0259  decode.loss_ce: 0.0259  decode.acc_seg: 92.3739
# 02/25 23:03:42 - mmengine - INFO - Iter(train) [ 8850/10000]  lr: 8.1186e-06  eta: 0:09:27  time: 0.4835  data_time: 0.0236  memory: 12680  loss: 0.0254  decode.loss_ce: 0.0254  decode.acc_seg: 88.8173
# 02/25 23:04:07 - mmengine - INFO - Iter(train) [ 8900/10000]  lr: 7.7656e-06  eta: 0:09:02  time: 0.5078  data_time: 0.0542  memory: 12680  loss: 0.0098  decode.loss_ce: 0.0098  decode.acc_seg: 95.6237
# 02/25 23:04:32 - mmengine - INFO - Iter(train) [ 8950/10000]  lr: 7.4126e-06  eta: 0:08:38  time: 0.4865  data_time: 0.0305  memory: 12680  loss: 0.0112  decode.loss_ce: 0.0112  decode.acc_seg: 96.0746
# 02/25 23:04:57 - mmengine - INFO - Exp name: MVMT_delta_lassic_valley_20240225_213730
# 02/25 23:04:57 - mmengine - INFO - Iter(train) [ 9000/10000]  lr: 7.0597e-06  eta: 0:08:13  time: 0.4877  data_time: 0.0318  memory: 12680  loss: 0.0267  decode.loss_ce: 0.0267  decode.acc_seg: 87.9101
# 02/25 23:05:22 - mmengine - INFO - Iter(val) [ 50/216]    eta: 0:01:23  time: 0.4739  data_time: 0.2771  memory: 1863
# 02/25 23:05:43 - mmengine - INFO - Iter(val) [100/216]    eta: 0:00:53  time: 0.3901  data_time: 0.1924  memory: 1863
# 02/25 23:06:05 - mmengine - INFO - Iter(val) [150/216]    eta: 0:00:29  time: 0.4711  data_time: 0.2748  memory: 1863
# 02/25 23:06:26 - mmengine - INFO - Iter(val) [200/216]    eta: 0:00:07  time: 0.3898  data_time: 0.1919  memory: 1863
# 02/25 23:06:33 - mmengine - INFO - per class results:
# 02/25 23:06:33 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 84.68 | 95.14 |
# |  CADE | 84.32 | 87.51 |
# |  PILA | 87.39 | 93.57 |
# |  PIPJ | 89.18 | 95.84 |
# |  PSME |  82.0 |  88.7 |
# +-------+-------+-------+
# 02/25 23:06:33 - mmengine - INFO - Iter(val) [216/216]    aAcc: 92.4500  mIoU: 85.5100  mAcc: 92.1500  data_time: 0.2477  time: 0.4452
# 02/25 23:06:56 - mmengine - INFO - Iter(train) [ 9050/10000]  lr: 6.7067e-06  eta: 0:07:48  time: 0.4715  data_time: 0.0121  memory: 12680  loss: 0.0043  decode.loss_ce: 0.0043  decode.acc_seg: 100.0000
# 02/25 23:07:21 - mmengine - INFO - Iter(train) [ 9100/10000]  lr: 6.3537e-06  eta: 0:07:24  time: 0.4726  data_time: 0.0125  memory: 12680  loss: 0.0240  decode.loss_ce: 0.0240  decode.acc_seg: 94.6104
# 02/25 23:07:45 - mmengine - INFO - Iter(train) [ 9150/10000]  lr: 6.0007e-06  eta: 0:06:59  time: 0.4757  data_time: 0.0151  memory: 12680  loss: 0.0085  decode.loss_ce: 0.0085  decode.acc_seg: 95.9827
# 02/25 23:08:09 - mmengine - INFO - Iter(train) [ 9200/10000]  lr: 5.6477e-06  eta: 0:06:34  time: 0.4758  data_time: 0.0166  memory: 12680  loss: 0.0155  decode.loss_ce: 0.0155  decode.acc_seg: 89.7530
# 02/25 23:08:33 - mmengine - INFO - Iter(train) [ 9250/10000]  lr: 5.2947e-06  eta: 0:06:09  time: 0.4781  data_time: 0.0179  memory: 12680  loss: 0.0142  decode.loss_ce: 0.0142  decode.acc_seg: 100.0000
# 02/25 23:08:57 - mmengine - INFO - Iter(train) [ 9300/10000]  lr: 4.9418e-06  eta: 0:05:45  time: 0.4639  data_time: 0.0107  memory: 12680  loss: 0.0097  decode.loss_ce: 0.0097  decode.acc_seg: 91.2197
# 02/25 23:09:21 - mmengine - INFO - Iter(train) [ 9350/10000]  lr: 4.5888e-06  eta: 0:05:20  time: 0.4906  data_time: 0.0340  memory: 12680  loss: 0.0086  decode.loss_ce: 0.0086  decode.acc_seg: 98.4970
# 02/25 23:09:47 - mmengine - INFO - Iter(train) [ 9400/10000]  lr: 4.2358e-06  eta: 0:04:55  time: 0.4906  data_time: 0.0313  memory: 12680  loss: 0.0145  decode.loss_ce: 0.0145  decode.acc_seg: 95.8673
# 02/25 23:10:11 - mmengine - INFO - Iter(train) [ 9450/10000]  lr: 3.8828e-06  eta: 0:04:31  time: 0.4792  data_time: 0.0114  memory: 12680  loss: 0.0203  decode.loss_ce: 0.0203  decode.acc_seg: 100.0000
# 02/25 23:10:37 - mmengine - INFO - Iter(train) [ 9500/10000]  lr: 3.5298e-06  eta: 0:04:06  time: 0.5486  data_time: 0.0967  memory: 12680  loss: 0.0157  decode.loss_ce: 0.0157  decode.acc_seg: 97.8815
# 02/25 23:11:00 - mmengine - INFO - Iter(train) [ 9550/10000]  lr: 3.1768e-06  eta: 0:03:41  time: 0.4759  data_time: 0.0192  memory: 12680  loss: 0.0154  decode.loss_ce: 0.0154  decode.acc_seg: 100.0000
# 02/25 23:11:25 - mmengine - INFO - Iter(train) [ 9600/10000]  lr: 2.8239e-06  eta: 0:03:17  time: 0.4674  data_time: 0.0116  memory: 12680  loss: 0.0207  decode.loss_ce: 0.0207  decode.acc_seg: 91.3974
# 02/25 23:11:49 - mmengine - INFO - Iter(train) [ 9650/10000]  lr: 2.4709e-06  eta: 0:02:52  time: 0.4852  data_time: 0.0260  memory: 12680  loss: 0.0164  decode.loss_ce: 0.0164  decode.acc_seg: 58.7043
# 02/25 23:12:14 - mmengine - INFO - Iter(train) [ 9700/10000]  lr: 2.1179e-06  eta: 0:02:27  time: 0.4994  data_time: 0.0451  memory: 12680  loss: 0.0158  decode.loss_ce: 0.0158  decode.acc_seg: 95.5241
# 02/25 23:12:40 - mmengine - INFO - Iter(train) [ 9750/10000]  lr: 1.7649e-06  eta: 0:02:03  time: 0.4891  data_time: 0.0370  memory: 12680  loss: 0.0127  decode.loss_ce: 0.0127  decode.acc_seg: 100.0000
# 02/25 23:13:04 - mmengine - INFO - Iter(train) [ 9800/10000]  lr: 1.4119e-06  eta: 0:01:38  time: 0.5220  data_time: 0.0656  memory: 12680  loss: 0.0104  decode.loss_ce: 0.0104  decode.acc_seg: 96.4535
# 02/25 23:13:29 - mmengine - INFO - Iter(train) [ 9850/10000]  lr: 1.0589e-06  eta: 0:01:13  time: 0.5347  data_time: 0.0813  memory: 12680  loss: 0.0070  decode.loss_ce: 0.0070  decode.acc_seg: 78.3120
# 02/25 23:13:55 - mmengine - INFO - Iter(train) [ 9900/10000]  lr: 7.0597e-07  eta: 0:00:49  time: 0.4753  data_time: 0.0124  memory: 12680  loss: 0.0105  decode.loss_ce: 0.0105  decode.acc_seg: 100.0000
# 02/25 23:14:19 - mmengine - INFO - Iter(train) [ 9950/10000]  lr: 3.5298e-07  eta: 0:00:24  time: 0.4872  data_time: 0.0311  memory: 12680  loss: 0.0182  decode.loss_ce: 0.0182  decode.acc_seg: 90.5562
# 02/25 23:14:44 - mmengine - INFO - Exp name: MVMT_delta_lassic_valley_20240225_213730
# 02/25 23:14:44 - mmengine - INFO - Iter(train) [10000/10000]  lr: 0.0000e+00  eta: 0:00:00  time: 0.4671  data_time: 0.0122  memory: 12680  loss: 0.0136  decode.loss_ce: 0.0136  decode.acc_seg: 100.0000
# 02/25 23:14:44 - mmengine - INFO - Saving checkpoint at 10000 iterations
# 02/25 23:15:13 - mmengine - INFO - Iter(val) [ 50/216]    eta: 0:01:19  time: 0.5048  data_time: 0.3000  memory: 1863
# 02/25 23:15:35 - mmengine - INFO - Iter(val) [100/216]    eta: 0:00:53  time: 0.4061  data_time: 0.2023  memory: 1863
# 02/25 23:15:58 - mmengine - INFO - Iter(val) [150/216]    eta: 0:00:30  time: 0.4915  data_time: 0.2912  memory: 1863
# 02/25 23:16:20 - mmengine - INFO - Iter(val) [200/216]    eta: 0:00:07  time: 0.4189  data_time: 0.2182  memory: 1863
# 02/25 23:16:26 - mmengine - INFO - per class results:
# 02/25 23:16:26 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 86.16 | 92.29 |
# |  CADE | 86.01 | 90.82 |
# |  PILA |  87.7 | 94.59 |
# |  PIPJ |  89.3 |  95.7 |
# |  PSME | 82.37 | 89.66 |
# +-------+-------+-------+
# 02/25 23:16:26 - mmengine - INFO - Iter(val) [216/216]    aAcc: 92.9200  mIoU: 86.3100  mAcc: 92.6100  data_time: 0.2506  time: 0.4523
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/openmmlab/bin/python /ofo-share/repos-david/mmsegmentation/tools/train.py /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/MVMT_delta_lassic_valley.py --work-dir /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_delta_lassic_valley/work_dir', returncode=0)

# %% [markdown]
# # Move resuts from scratch

# %%
TRAINING_DATA_FOLDER = get_training_data_folder(training_sites=TRAINING_SITES, is_ortho=False, is_scratch=False)
shutil.move(TRAINING_DATA_FOLDER_SCRATCH, TRAINING_DATA_FOLDER)
# Out:
# PosixPath('/ofo-share/scratch-david/organized-str-disp-MVMT-experiments/models/multi_site/MVMT_delta_lassic_valley')
