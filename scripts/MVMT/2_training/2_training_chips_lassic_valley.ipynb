# %%
# Standard library imports
import subprocess
import json
import shutil
import sys

# Contributed library imports
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread
from pathlib import Path

# Imports from the constants
sys.path.append("../..")
from constants import (
    get_aggregated_images_folder,
    get_aggregated_labels_folder,
    get_images_near_labels_folder,
    get_render_folder,
    get_training_data_folder,
    get_work_dir,
    MMSEG_PYTHON,
    TRAIN_SCRIPT,
    MMSEG_UTILS_PYTHON,
    FOLDER_TO_CITYSCAPES_SCRIPT,
)

# %% [markdown]
# # Set constants
# You should be able to define most of the behavior from these constants

# %%
TRAINING_SITES = sorted(["chips", "lassic", "valley"])

# %%
AGGREGATED_IMAGES_FOLDER = get_aggregated_images_folder(
    training_sites=TRAINING_SITES, is_ortho=False
)
AGGREGATED_LABELS_FOLDER = get_aggregated_labels_folder(
    training_sites=TRAINING_SITES, is_ortho=False
)

# We need to merge all the imagery together
# I think this should be stored in the models folder, alongside the real models
# It should be as simple as creating the folders and symlinking the existing ones into it
Path(AGGREGATED_IMAGES_FOLDER).mkdir(exist_ok=True, parents=True)
Path(AGGREGATED_LABELS_FOLDER).mkdir(exist_ok=True, parents=True)

for training_site in TRAINING_SITES:
    render_folder = get_render_folder(training_site)
    images_near_labels_folder = get_images_near_labels_folder(training_site)

    output_render_folder = Path(AGGREGATED_LABELS_FOLDER, training_site)
    output_image_folder = Path(AGGREGATED_IMAGES_FOLDER, training_site)

    # Unlink if symlink
    output_render_folder.unlink(missing_ok=True)
    output_image_folder.unlink(missing_ok=True)
    # Remove if folder
    shutil.rmtree(output_render_folder, ignore_errors=True)
    shutil.rmtree(output_image_folder, ignore_errors=True)

    shutil.copytree(render_folder, output_render_folder)
    shutil.copytree(images_near_labels_folder, output_image_folder)

# %%
TRAINING_DATA_FOLDER_SCRATCH = get_training_data_folder(
    training_sites=TRAINING_SITES, is_ortho=False, is_scratch=True
)

# Use one of the render folders, assuming they are all the same
IDs_to_labels_file = Path(render_folder, "IDs_to_labels.json")
with open(IDs_to_labels_file, "r") as infile:
    data = json.load(infile)

class_names = list(data.values())
class_names_str = " ".join(class_names)
print(class_names_str)

run_str = (
    f"{MMSEG_UTILS_PYTHON} {FOLDER_TO_CITYSCAPES_SCRIPT} --images-folder {AGGREGATED_IMAGES_FOLDER}"
    + f" --labels-folder {AGGREGATED_LABELS_FOLDER} --output-folder "
    + f"{TRAINING_DATA_FOLDER_SCRATCH} --classes {class_names_str} --remove-old"
)
print(run_str)
subprocess.run(
    run_str,
    shell=True,
)
# Out:
# ABCO CADE PILA PIPJ PSME
# /ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/MVMT/inputs/images --labels-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/MVMT/inputs/labels --output-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley --classes ABCO CADE PILA PIPJ PSME --remove-old
# Checking for completely null images: 100%|██████████| 1076/1076 [01:45<00:00, 10.22it/s]
# Linking files into either train or test folders: 100%|██████████| 907/907 [00:00<00:00, 11552.98it/s]
# 100%|██████████| 20/20 [00:05<00:00,  3.53it/s]
# (3992372, 3)
# mean: [120.04748856068522, 124.20751072294867, 110.08807996849993], std: [64.87567597674773, 61.4307227498997, 57.864462900931095]
# About to save config to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/MVMT_chips_lassic_valley.py
# visualizing to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/vis/train: 100%|██████████| 11/11 [00:21<00:00,  1.98s/it]
# visualizing to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/vis/val: 100%|██████████| 11/11 [00:20<00:00,  1.88s/it]
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/MVMT/inputs/images --labels-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/MVMT/inputs/labels --output-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley --classes ABCO CADE PILA PIPJ PSME --remove-old', returncode=0)

# %% [markdown]
# # Show some of the formatted example images

# %%
cmap_file = Path(TRAINING_DATA_FOLDER_SCRATCH, "colormap.png")
plt.imshow(imread(cmap_file))
plt.show()

vis_folder = Path(TRAINING_DATA_FOLDER_SCRATCH, "vis")
vis_files = list(vis_folder.rglob("*JPG"))
for file in np.random.choice(vis_files, 10):
    print(f"showing {file}")
    plt.imshow(imread(file))
    plt.show()
# Out:
# /tmp/ipykernel_4202/4204227826.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(cmap_file))
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/vis/train/chips_ChipsB_80m_2021_complete_SD_card_25_104MEDIA_DJI_0063_rgb.JPG
# /tmp/ipykernel_4202/4204227826.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(file))
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/vis/train/chips_ChipsB_80m_2021_complete_SD_card_26_101MEDIA_DJI_0593_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/vis/train/lassic_Lassic_80m_pt3_ew_104MEDIA_DJI_0815_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/vis/train/valley_ValleyA_90m_PART_01_103MEDIA_DJI_0619_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/vis/val/chips_ChipsB_80m_2021_complete_SD_card_25_103MEDIA_DJI_0936_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/vis/train/chips_ChipsB_80m_2021_complete_SD_card_25_103MEDIA_DJI_0935_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/vis/val/lassic_Lassic_80m_pt1_ns_104MEDIA_DJI_0804_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/vis/train/lassic_Lassic_80m_pt3_ew_104MEDIA_DJI_0815_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/vis/train/chips_ChipsB_80m_2021_complete_SD_card_25_103MEDIA_DJI_0935_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/vis/val/chips_ChipsB_80m_2021_complete_SD_card_25_103MEDIA_DJI_0936_rgb.JPG

# %% [markdown]
# # Train a model

# %%
WORK_DIR_SCRATCH = get_work_dir(training_sites=TRAINING_SITES, is_ortho=False, is_scratch=True)

# Identify the config file as the only python file in the
config_file = list(Path(TRAINING_DATA_FOLDER_SCRATCH).glob("*py"))[0]
subprocess.run(
    f"{MMSEG_PYTHON} {TRAIN_SCRIPT} {config_file} --work-dir {WORK_DIR_SCRATCH}", shell=True
)
# Out:
# 02/25 20:14:46 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 6485197
#     GPU 0: GRID A100X-20C
#     CUDA_HOME: /ofo-share/repos-david/conda/envs/MVMT-stable
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 6485197
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/25 20:14:48 - mmengine - INFO - Config:
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[120.04748856068522, 124.20751072294867, 110.08807996849993],
#     std=[64.87567597674773, 61.4307227498997, 57.864462900931095],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(1024, 1024))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[120.04748856068522, 124.20751072294867, 110.08807996849993],
#         std=[64.87567597674773, 61.4307227498997, 57.864462900931095],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(1024, 1024)),
#     pretrained=None,
#     backbone=dict(
#         type='MixVisionTransformer',
#         in_channels=3,
#         embed_dims=64,
#         num_stages=4,
#         num_layers=[3, 6, 40, 3],
#         num_heads=[1, 2, 5, 8],
#         patch_sizes=[7, 3, 3, 3],
#         sr_ratios=[8, 4, 2, 1],
#         out_indices=(0, 1, 2, 3),
#         mlp_ratio=4,
#         qkv_bias=True,
#         drop_rate=0.0,
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
#         )),
#     decode_head=dict(
#         type='SegformerHead',
#         in_channels=[64, 128, 320, 512],
#         in_index=[0, 1, 2, 3],
#         channels=256,
#         dropout_ratio=0.1,
#         num_classes=5,
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='slide', crop_size=(1024, 1024), stride=(768, 768)))
# dataset_type = 'CityscapesForestsDataset'
# data_root = '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley'
# img_suffix = '_rgb.JPG'
# classes = ['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME']
# crop_size = (1024, 1024)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(2048, 1024),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(2048, 1024),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(
#                 type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(
#         type='AdamW', lr=6e-05, betas=(0.9, 0.999), weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             pos_block=dict(decay_mult=0.0),
#             norm=dict(decay_mult=0.0),
#             head=dict(lr_mult=10.0))))
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=1e-06, by_epoch=False, begin=0,
#         end=1500),
#     dict(
#         type='PolyLR',
#         eta_min=0.0,
#         power=1.0,
#         begin=1500,
#         end=10000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=10000, val_interval=1000)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=5000),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# checkpoint = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
# launcher = 'none'
# work_dir = '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/work_dir'
#
# 02/25 20:14:54 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/25 20:14:54 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /ofo-share/repos-david/mmsegmentation/mmseg/models/builder.py:42: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn(
# /ofo-share/repos-david/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:245: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# /ofo-share/repos-david/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:64: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn(
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:lr=6e-05
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:weight_decay=0.0
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:decay_mult=0.0
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:lr=6e-05
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:weight_decay=0.0
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:decay_mult=0.0
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:lr=6e-05
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:weight_decay=0.0
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:decay_mult=0.0
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:lr=6e-05
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:weight_decay=0.0
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:decay_mult=0.0
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:lr=6e-05
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:lr=6e-05
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:56 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:lr=6e-05
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:weight_decay=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:decay_mult=0.0
# 02/25 20:14:57 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.attn.norm.weight:lr=6e-05
# ...
# 02/25 21:21:43 - mmengine - INFO - Iter(val) [150/181]    eta: 0:00:14  time: 0.4984  data_time: 0.2918  memory: 1929
# 02/25 21:21:56 - mmengine - INFO - per class results:
# 02/25 21:21:56 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 86.59 | 91.48 |
# |  CADE |  87.8 | 94.34 |
# |  PILA | 73.33 | 80.75 |
# |  PIPJ | 87.52 | 93.94 |
# |  PSME | 78.52 | 90.21 |
# +-------+-------+-------+
# 02/25 21:21:56 - mmengine - INFO - Iter(val) [181/181]    aAcc: 91.2700  mIoU: 82.7500  mAcc: 90.1400  data_time: 0.2615  time: 0.4613
# 02/25 21:22:20 - mmengine - INFO - Iter(train) [ 7050/10000]  lr: 2.0826e-05  eta: 0:24:08  time: 0.4804  data_time: 0.0129  memory: 12679  loss: 0.0177  decode.loss_ce: 0.0177  decode.acc_seg: 91.2837
# 02/25 21:22:44 - mmengine - INFO - Iter(train) [ 7100/10000]  lr: 2.0473e-05  eta: 0:23:44  time: 0.4767  data_time: 0.0115  memory: 12679  loss: 0.0344  decode.loss_ce: 0.0344  decode.acc_seg: 100.0000
# 02/25 21:23:08 - mmengine - INFO - Iter(train) [ 7150/10000]  lr: 2.0120e-05  eta: 0:23:19  time: 0.4799  data_time: 0.0126  memory: 12679  loss: 0.0075  decode.loss_ce: 0.0075  decode.acc_seg: 95.9643
# 02/25 21:23:32 - mmengine - INFO - Iter(train) [ 7200/10000]  lr: 1.9767e-05  eta: 0:22:54  time: 0.4772  data_time: 0.0125  memory: 12679  loss: 0.0283  decode.loss_ce: 0.0283  decode.acc_seg: 77.7413
# 02/25 21:23:56 - mmengine - INFO - Iter(train) [ 7250/10000]  lr: 1.9414e-05  eta: 0:22:29  time: 0.4774  data_time: 0.0157  memory: 12679  loss: 0.0120  decode.loss_ce: 0.0120  decode.acc_seg: 100.0000
# 02/25 21:24:21 - mmengine - INFO - Iter(train) [ 7300/10000]  lr: 1.9061e-05  eta: 0:22:05  time: 0.5169  data_time: 0.0552  memory: 12679  loss: 0.0173  decode.loss_ce: 0.0173  decode.acc_seg: 93.5324
# 02/25 21:24:45 - mmengine - INFO - Iter(train) [ 7350/10000]  lr: 1.8708e-05  eta: 0:21:40  time: 0.4752  data_time: 0.0130  memory: 12679  loss: 0.0163  decode.loss_ce: 0.0163  decode.acc_seg: 99.2459
# 02/25 21:25:10 - mmengine - INFO - Iter(train) [ 7400/10000]  lr: 1.8355e-05  eta: 0:21:16  time: 0.4790  data_time: 0.0148  memory: 12679  loss: 0.0139  decode.loss_ce: 0.0139  decode.acc_seg: 98.0075
# 02/25 21:25:35 - mmengine - INFO - Iter(train) [ 7450/10000]  lr: 1.8002e-05  eta: 0:20:51  time: 0.4905  data_time: 0.0294  memory: 12679  loss: 0.0210  decode.loss_ce: 0.0210  decode.acc_seg: 99.8702
# 02/25 21:26:01 - mmengine - INFO - Iter(train) [ 7500/10000]  lr: 1.7649e-05  eta: 0:20:27  time: 0.5590  data_time: 0.0979  memory: 12679  loss: 0.0144  decode.loss_ce: 0.0144  decode.acc_seg: 99.9638
# 02/25 21:26:24 - mmengine - INFO - Iter(train) [ 7550/10000]  lr: 1.7296e-05  eta: 0:20:02  time: 0.4785  data_time: 0.0147  memory: 12679  loss: 0.0602  decode.loss_ce: 0.0602  decode.acc_seg: 94.1145
# 02/25 21:26:50 - mmengine - INFO - Iter(train) [ 7600/10000]  lr: 1.6943e-05  eta: 0:19:38  time: 0.4776  data_time: 0.0129  memory: 12679  loss: 0.0206  decode.loss_ce: 0.0206  decode.acc_seg: 95.2366
# 02/25 21:27:13 - mmengine - INFO - Iter(train) [ 7650/10000]  lr: 1.6590e-05  eta: 0:19:13  time: 0.4723  data_time: 0.0121  memory: 12679  loss: 0.0095  decode.loss_ce: 0.0095  decode.acc_seg: 100.0000
# 02/25 21:27:37 - mmengine - INFO - Iter(train) [ 7700/10000]  lr: 1.6237e-05  eta: 0:18:48  time: 0.4785  data_time: 0.0139  memory: 12679  loss: 0.0262  decode.loss_ce: 0.0262  decode.acc_seg: 100.0000
# 02/25 21:28:01 - mmengine - INFO - Iter(train) [ 7750/10000]  lr: 1.5884e-05  eta: 0:18:24  time: 0.4765  data_time: 0.0125  memory: 12679  loss: 0.0393  decode.loss_ce: 0.0393  decode.acc_seg: 87.1329
# 02/25 21:28:25 - mmengine - INFO - Iter(train) [ 7800/10000]  lr: 1.5531e-05  eta: 0:17:59  time: 0.4854  data_time: 0.0211  memory: 12679  loss: 0.0201  decode.loss_ce: 0.0201  decode.acc_seg: 95.0114
# 02/25 21:28:49 - mmengine - INFO - Iter(train) [ 7850/10000]  lr: 1.5178e-05  eta: 0:17:34  time: 0.4740  data_time: 0.0132  memory: 12679  loss: 0.0245  decode.loss_ce: 0.0245  decode.acc_seg: 100.0000
# 02/25 21:29:15 - mmengine - INFO - Iter(train) [ 7900/10000]  lr: 1.4825e-05  eta: 0:17:10  time: 0.5020  data_time: 0.0396  memory: 12679  loss: 0.0398  decode.loss_ce: 0.0398  decode.acc_seg: 100.0000
# 02/25 21:29:40 - mmengine - INFO - Iter(train) [ 7950/10000]  lr: 1.4472e-05  eta: 0:16:46  time: 0.5268  data_time: 0.0645  memory: 12679  loss: 0.0206  decode.loss_ce: 0.0206  decode.acc_seg: 93.3430
# 02/25 21:30:05 - mmengine - INFO - Exp name: MVMT_chips_lassic_valley_20240225_201445
# 02/25 21:30:05 - mmengine - INFO - Iter(train) [ 8000/10000]  lr: 1.4119e-05  eta: 0:16:21  time: 0.5375  data_time: 0.0802  memory: 12679  loss: 0.0267  decode.loss_ce: 0.0267  decode.acc_seg: 100.0000
# 02/25 21:30:31 - mmengine - INFO - Iter(val) [ 50/181]    eta: 0:01:06  time: 0.4784  data_time: 0.2699  memory: 1929
# 02/25 21:30:52 - mmengine - INFO - Iter(val) [100/181]    eta: 0:00:37  time: 0.3855  data_time: 0.1744  memory: 1929
# 02/25 21:31:14 - mmengine - INFO - Iter(val) [150/181]    eta: 0:00:14  time: 0.4630  data_time: 0.2480  memory: 1929
# 02/25 21:31:27 - mmengine - INFO - per class results:
# 02/25 21:31:27 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 87.62 | 92.31 |
# |  CADE | 88.18 | 93.82 |
# |  PILA | 75.31 | 86.49 |
# |  PIPJ | 86.84 | 96.04 |
# |  PSME | 78.99 | 84.95 |
# +-------+-------+-------+
# 02/25 21:31:27 - mmengine - INFO - Iter(val) [181/181]    aAcc: 91.5500  mIoU: 83.3900  mAcc: 90.7200  data_time: 0.2428  time: 0.4508
# 02/25 21:31:51 - mmengine - INFO - Iter(train) [ 8050/10000]  lr: 1.3766e-05  eta: 0:15:57  time: 0.4759  data_time: 0.0127  memory: 12679  loss: 0.0339  decode.loss_ce: 0.0339  decode.acc_seg: 60.8586
# 02/25 21:32:14 - mmengine - INFO - Iter(train) [ 8100/10000]  lr: 1.3413e-05  eta: 0:15:32  time: 0.4750  data_time: 0.0130  memory: 12679  loss: 0.0273  decode.loss_ce: 0.0273  decode.acc_seg: 96.2767
# 02/25 21:32:38 - mmengine - INFO - Iter(train) [ 8150/10000]  lr: 1.3060e-05  eta: 0:15:07  time: 0.4708  data_time: 0.0124  memory: 12679  loss: 0.0140  decode.loss_ce: 0.0140  decode.acc_seg: 97.7588
# 02/25 21:33:03 - mmengine - INFO - Iter(train) [ 8200/10000]  lr: 1.2707e-05  eta: 0:14:43  time: 0.4808  data_time: 0.0142  memory: 12679  loss: 0.0221  decode.loss_ce: 0.0221  decode.acc_seg: 100.0000
# 02/25 21:33:27 - mmengine - INFO - Iter(train) [ 8250/10000]  lr: 1.2354e-05  eta: 0:14:18  time: 0.4762  data_time: 0.0134  memory: 12679  loss: 0.0293  decode.loss_ce: 0.0293  decode.acc_seg: 70.5921
# 02/25 21:33:52 - mmengine - INFO - Iter(train) [ 8300/10000]  lr: 1.2001e-05  eta: 0:13:54  time: 0.5070  data_time: 0.0472  memory: 12679  loss: 0.0274  decode.loss_ce: 0.0274  decode.acc_seg: 100.0000
# 02/25 21:34:18 - mmengine - INFO - Iter(train) [ 8350/10000]  lr: 1.1648e-05  eta: 0:13:29  time: 0.4726  data_time: 0.0116  memory: 12679  loss: 0.0161  decode.loss_ce: 0.0161  decode.acc_seg: 100.0000
# 02/25 21:34:42 - mmengine - INFO - Iter(train) [ 8400/10000]  lr: 1.1295e-05  eta: 0:13:05  time: 0.4746  data_time: 0.0147  memory: 12679  loss: 0.0282  decode.loss_ce: 0.0282  decode.acc_seg: 92.1276
# 02/25 21:35:06 - mmengine - INFO - Iter(train) [ 8450/10000]  lr: 1.0942e-05  eta: 0:12:40  time: 0.4746  data_time: 0.0167  memory: 12679  loss: 0.0372  decode.loss_ce: 0.0372  decode.acc_seg: 95.3911
# 02/25 21:35:31 - mmengine - INFO - Iter(train) [ 8500/10000]  lr: 1.0589e-05  eta: 0:12:16  time: 0.5004  data_time: 0.0502  memory: 12679  loss: 0.0161  decode.loss_ce: 0.0161  decode.acc_seg: 93.4551
# 02/25 21:35:55 - mmengine - INFO - Iter(train) [ 8550/10000]  lr: 1.0236e-05  eta: 0:11:51  time: 0.4746  data_time: 0.0153  memory: 12679  loss: 0.0240  decode.loss_ce: 0.0240  decode.acc_seg: 96.2432
# 02/25 21:36:21 - mmengine - INFO - Iter(train) [ 8600/10000]  lr: 9.8835e-06  eta: 0:11:27  time: 0.5244  data_time: 0.0630  memory: 12679  loss: 0.0268  decode.loss_ce: 0.0268  decode.acc_seg: 99.3925
# 02/25 21:36:45 - mmengine - INFO - Iter(train) [ 8650/10000]  lr: 9.5305e-06  eta: 0:11:02  time: 0.4906  data_time: 0.0315  memory: 12679  loss: 0.0195  decode.loss_ce: 0.0195  decode.acc_seg: 99.6300
# 02/25 21:37:11 - mmengine - INFO - Iter(train) [ 8700/10000]  lr: 9.1776e-06  eta: 0:10:38  time: 0.5653  data_time: 0.1036  memory: 12679  loss: 0.0144  decode.loss_ce: 0.0144  decode.acc_seg: 95.9171
# 02/25 21:37:37 - mmengine - INFO - Iter(train) [ 8750/10000]  lr: 8.8246e-06  eta: 0:10:13  time: 0.4820  data_time: 0.0130  memory: 12679  loss: 0.0252  decode.loss_ce: 0.0252  decode.acc_seg: 94.6619
# 02/25 21:38:01 - mmengine - INFO - Iter(train) [ 8800/10000]  lr: 8.4716e-06  eta: 0:09:49  time: 0.4803  data_time: 0.0134  memory: 12679  loss: 0.0303  decode.loss_ce: 0.0303  decode.acc_seg: 88.1899
# 02/25 21:38:25 - mmengine - INFO - Iter(train) [ 8850/10000]  lr: 8.1186e-06  eta: 0:09:24  time: 0.4850  data_time: 0.0134  memory: 12679  loss: 0.0205  decode.loss_ce: 0.0205  decode.acc_seg: 89.9095
# 02/25 21:38:49 - mmengine - INFO - Iter(train) [ 8900/10000]  lr: 7.7656e-06  eta: 0:09:00  time: 0.4804  data_time: 0.0147  memory: 12679  loss: 0.0315  decode.loss_ce: 0.0315  decode.acc_seg: 93.2320
# 02/25 21:39:13 - mmengine - INFO - Iter(train) [ 8950/10000]  lr: 7.4126e-06  eta: 0:08:35  time: 0.4785  data_time: 0.0175  memory: 12679  loss: 0.0109  decode.loss_ce: 0.0109  decode.acc_seg: 97.9782
# 02/25 21:39:38 - mmengine - INFO - Exp name: MVMT_chips_lassic_valley_20240225_201445
# 02/25 21:39:38 - mmengine - INFO - Iter(train) [ 9000/10000]  lr: 7.0597e-06  eta: 0:08:10  time: 0.6076  data_time: 0.1491  memory: 12679  loss: 0.0129  decode.loss_ce: 0.0129  decode.acc_seg: 100.0000
# 02/25 21:40:04 - mmengine - INFO - Iter(val) [ 50/181]    eta: 0:01:07  time: 0.4903  data_time: 0.2900  memory: 1929
# 02/25 21:40:26 - mmengine - INFO - Iter(val) [100/181]    eta: 0:00:38  time: 0.3974  data_time: 0.1910  memory: 1929
# 02/25 21:40:49 - mmengine - INFO - Iter(val) [150/181]    eta: 0:00:14  time: 0.4853  data_time: 0.2798  memory: 1929
# 02/25 21:41:02 - mmengine - INFO - per class results:
# 02/25 21:41:02 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO |  87.9 | 91.77 |
# |  CADE | 88.04 | 95.66 |
# |  PILA | 74.76 | 80.79 |
# |  PIPJ | 87.64 | 95.36 |
# |  PSME | 79.43 | 88.73 |
# +-------+-------+-------+
# 02/25 21:41:02 - mmengine - INFO - Iter(val) [181/181]    aAcc: 91.7200  mIoU: 83.5500  mAcc: 90.4600  data_time: 0.2523  time: 0.4602
# 02/25 21:41:25 - mmengine - INFO - Iter(train) [ 9050/10000]  lr: 6.7067e-06  eta: 0:07:46  time: 0.4755  data_time: 0.0127  memory: 12679  loss: 0.0092  decode.loss_ce: 0.0092  decode.acc_seg: 98.6686
# 02/25 21:41:51 - mmengine - INFO - Iter(train) [ 9100/10000]  lr: 6.3537e-06  eta: 0:07:21  time: 0.5514  data_time: 0.0855  memory: 12679  loss: 0.0189  decode.loss_ce: 0.0189  decode.acc_seg: 37.4302
# 02/25 21:42:15 - mmengine - INFO - Iter(train) [ 9150/10000]  lr: 6.0007e-06  eta: 0:06:57  time: 0.4751  data_time: 0.0165  memory: 12679  loss: 0.0406  decode.loss_ce: 0.0406  decode.acc_seg: 92.1419
# 02/25 21:42:40 - mmengine - INFO - Iter(train) [ 9200/10000]  lr: 5.6477e-06  eta: 0:06:32  time: 0.4738  data_time: 0.0116  memory: 12679  loss: 0.0215  decode.loss_ce: 0.0215  decode.acc_seg: 88.7899
# 02/25 21:43:05 - mmengine - INFO - Iter(train) [ 9250/10000]  lr: 5.2947e-06  eta: 0:06:08  time: 0.4754  data_time: 0.0132  memory: 12679  loss: 0.0317  decode.loss_ce: 0.0317  decode.acc_seg: 91.3453
# 02/25 21:43:29 - mmengine - INFO - Iter(train) [ 9300/10000]  lr: 4.9418e-06  eta: 0:05:43  time: 0.4974  data_time: 0.0408  memory: 12679  loss: 0.0238  decode.loss_ce: 0.0238  decode.acc_seg: 66.5474
# 02/25 21:43:54 - mmengine - INFO - Iter(train) [ 9350/10000]  lr: 4.5888e-06  eta: 0:05:19  time: 0.5052  data_time: 0.0554  memory: 12679  loss: 0.0221  decode.loss_ce: 0.0221  decode.acc_seg: 90.4341
# 02/25 21:44:20 - mmengine - INFO - Iter(train) [ 9400/10000]  lr: 4.2358e-06  eta: 0:04:54  time: 0.5445  data_time: 0.0817  memory: 12679  loss: 0.0075  decode.loss_ce: 0.0075  decode.acc_seg: 100.0000
# 02/25 21:44:45 - mmengine - INFO - Iter(train) [ 9450/10000]  lr: 3.8828e-06  eta: 0:04:30  time: 0.4898  data_time: 0.0151  memory: 12679  loss: 0.0182  decode.loss_ce: 0.0182  decode.acc_seg: 93.5054
# 02/25 21:45:09 - mmengine - INFO - Iter(train) [ 9500/10000]  lr: 3.5298e-06  eta: 0:04:05  time: 0.4836  data_time: 0.0148  memory: 12679  loss: 0.0183  decode.loss_ce: 0.0183  decode.acc_seg: 71.8580
# 02/25 21:45:33 - mmengine - INFO - Iter(train) [ 9550/10000]  lr: 3.1768e-06  eta: 0:03:40  time: 0.4709  data_time: 0.0127  memory: 12679  loss: 0.0171  decode.loss_ce: 0.0171  decode.acc_seg: 90.4332
# 02/25 21:45:57 - mmengine - INFO - Iter(train) [ 9600/10000]  lr: 2.8239e-06  eta: 0:03:16  time: 0.4856  data_time: 0.0139  memory: 12679  loss: 0.0184  decode.loss_ce: 0.0184  decode.acc_seg: 100.0000
# 02/25 21:46:22 - mmengine - INFO - Iter(train) [ 9650/10000]  lr: 2.4709e-06  eta: 0:02:51  time: 0.5214  data_time: 0.0570  memory: 12679  loss: 0.0411  decode.loss_ce: 0.0411  decode.acc_seg: 95.8078
# 02/25 21:46:47 - mmengine - INFO - Iter(train) [ 9700/10000]  lr: 2.1179e-06  eta: 0:02:27  time: 0.4744  data_time: 0.0132  memory: 12679  loss: 0.0249  decode.loss_ce: 0.0249  decode.acc_seg: 97.3091
# 02/25 21:47:12 - mmengine - INFO - Iter(train) [ 9750/10000]  lr: 1.7649e-06  eta: 0:02:02  time: 0.5166  data_time: 0.0517  memory: 12679  loss: 0.0106  decode.loss_ce: 0.0106  decode.acc_seg: 98.6950
# 02/25 21:47:38 - mmengine - INFO - Iter(train) [ 9800/10000]  lr: 1.4119e-06  eta: 0:01:38  time: 0.5314  data_time: 0.0675  memory: 12679  loss: 0.0160  decode.loss_ce: 0.0160  decode.acc_seg: 100.0000
# 02/25 21:48:03 - mmengine - INFO - Iter(train) [ 9850/10000]  lr: 1.0589e-06  eta: 0:01:13  time: 0.5331  data_time: 0.0706  memory: 12679  loss: 0.0194  decode.loss_ce: 0.0194  decode.acc_seg: 94.9909
# 02/25 21:48:29 - mmengine - INFO - Iter(train) [ 9900/10000]  lr: 7.0597e-07  eta: 0:00:49  time: 0.5634  data_time: 0.0990  memory: 12679  loss: 0.0209  decode.loss_ce: 0.0209  decode.acc_seg: 100.0000
# 02/25 21:48:54 - mmengine - INFO - Iter(train) [ 9950/10000]  lr: 3.5298e-07  eta: 0:00:24  time: 0.4626  data_time: 0.0110  memory: 12679  loss: 0.0224  decode.loss_ce: 0.0224  decode.acc_seg: 99.4024
# 02/25 21:49:19 - mmengine - INFO - Exp name: MVMT_chips_lassic_valley_20240225_201445
# 02/25 21:49:19 - mmengine - INFO - Iter(train) [10000/10000]  lr: 0.0000e+00  eta: 0:00:00  time: 0.5393  data_time: 0.0698  memory: 12679  loss: 0.0166  decode.loss_ce: 0.0166  decode.acc_seg: 91.7013
# 02/25 21:49:19 - mmengine - INFO - Saving checkpoint at 10000 iterations
# 02/25 21:49:48 - mmengine - INFO - Iter(val) [ 50/181]    eta: 0:01:06  time: 0.5239  data_time: 0.3326  memory: 1929
# 02/25 21:50:10 - mmengine - INFO - Iter(val) [100/181]    eta: 0:00:38  time: 0.3941  data_time: 0.1883  memory: 1929
# 02/25 21:50:33 - mmengine - INFO - Iter(val) [150/181]    eta: 0:00:14  time: 0.4801  data_time: 0.2768  memory: 1929
# 02/25 21:50:45 - mmengine - INFO - per class results:
# 02/25 21:50:45 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 88.56 | 93.17 |
# |  CADE | 88.71 | 94.68 |
# |  PILA | 77.69 | 87.11 |
# |  PIPJ | 88.52 |  95.1 |
# |  PSME | 80.98 | 88.23 |
# +-------+-------+-------+
# 02/25 21:50:45 - mmengine - INFO - Iter(val) [181/181]    aAcc: 92.3800  mIoU: 84.8900  mAcc: 91.6600  data_time: 0.2522  time: 0.4537
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/openmmlab/bin/python /ofo-share/repos-david/mmsegmentation/tools/train.py /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/MVMT_chips_lassic_valley.py --work-dir /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic_valley/work_dir', returncode=0)

# %% [markdown]
# # Move resuts from scratch

# %%
TRAINING_DATA_FOLDER = get_training_data_folder(training_sites=TRAINING_SITES, is_ortho=False, is_scratch=False)
shutil.move(TRAINING_DATA_FOLDER_SCRATCH, TRAINING_DATA_FOLDER)
# Out:
# PosixPath('/ofo-share/scratch-david/organized-str-disp-MVMT-experiments/models/multi_site/MVMT_chips_lassic_valley')
