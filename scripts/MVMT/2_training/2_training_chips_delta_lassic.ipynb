# %%
# Standard library imports
import subprocess
import json
import shutil
import sys

# Contributed library imports
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread
from pathlib import Path

# Imports from the constants
sys.path.append("../..")
from constants import (
    get_aggregated_images_folder,
    get_aggregated_labels_folder,
    get_images_near_labels_folder,
    get_render_folder,
    get_training_data_folder,
    get_work_dir,
    MMSEG_PYTHON,
    TRAIN_SCRIPT,
    MMSEG_UTILS_PYTHON,
    FOLDER_TO_CITYSCAPES_SCRIPT,
)

# %% [markdown]
# # Set constants
# You should be able to define most of the behavior from these constants

# %%
TRAINING_SITES = sorted(["chips", "delta", "lassic"])

# %%
AGGREGATED_IMAGES_FOLDER = get_aggregated_images_folder(
    training_sites=TRAINING_SITES, is_ortho=False
)
AGGREGATED_LABELS_FOLDER = get_aggregated_labels_folder(
    training_sites=TRAINING_SITES, is_ortho=False
)

# We need to merge all the imagery together
# I think this should be stored in the models folder, alongside the real models
# It should be as simple as creating the folders and symlinking the existing ones into it
Path(AGGREGATED_IMAGES_FOLDER).mkdir(exist_ok=True, parents=True)
Path(AGGREGATED_LABELS_FOLDER).mkdir(exist_ok=True, parents=True)

for training_site in TRAINING_SITES:
    render_folder = get_render_folder(training_site)
    images_near_labels_folder = get_images_near_labels_folder(training_site)

    output_render_folder = Path(AGGREGATED_LABELS_FOLDER, training_site)
    output_image_folder = Path(AGGREGATED_IMAGES_FOLDER, training_site)

    # Unlink if symlink
    output_render_folder.unlink(missing_ok=True)
    output_image_folder.unlink(missing_ok=True)
    # Remove if folder
    shutil.rmtree(output_render_folder, ignore_errors=True)
    shutil.rmtree(output_image_folder, ignore_errors=True)

    shutil.copytree(render_folder, output_render_folder, ignore_dangling_symlinks=True)
    shutil.copytree(images_near_labels_folder, output_image_folder, ignore_dangling_symlinks=True)

# %%
TRAINING_DATA_FOLDER_SCRATCH = get_training_data_folder(
    training_sites=TRAINING_SITES, is_ortho=False, is_scratch=True
)

# Use one of the render folders, assuming they are all the same
IDs_to_labels_file = Path(render_folder, "IDs_to_labels.json")
with open(IDs_to_labels_file, "r") as infile:
    data = json.load(infile)

class_names = list(data.values())
class_names_str = " ".join(class_names)
print(class_names_str)

run_str = (
    f"{MMSEG_UTILS_PYTHON} {FOLDER_TO_CITYSCAPES_SCRIPT} --images-folder {AGGREGATED_IMAGES_FOLDER}"
    + f" --labels-folder {AGGREGATED_LABELS_FOLDER} --output-folder "
    + f"{TRAINING_DATA_FOLDER_SCRATCH} --classes {class_names_str} --remove-old"
)
print(run_str)
subprocess.run(
    run_str,
    shell=True,
)
# Out:
# ABCO CADE PILA PIPJ PSME
# /ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/MVMT/inputs/images --labels-folder /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/MVMT/inputs/labels --output-folder /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic --classes ABCO CADE PILA PIPJ PSME --remove-old
# Checking for completely null images: 100%|██████████| 1341/1341 [02:08<00:00, 10.41it/s]
# Linking files into either train or test folders: 100%|██████████| 1329/1329 [00:13<00:00, 98.06it/s]
# 100%|██████████| 20/20 [00:07<00:00,  2.77it/s]
# (3992372, 3)
# mean: [114.30548906765202, 120.08890504191493, 108.62509230101804], std: [66.45615492825216, 63.69699400286447, 58.64490793335219]
# About to save config to /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/MVMT_chips_delta_lassic.py
# visualizing to /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/vis/train: 100%|██████████| 11/11 [00:24<00:00,  2.19s/it]
# visualizing to /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/vis/val: 100%|██████████| 11/11 [00:25<00:00,  2.34s/it]
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/MVMT/inputs/images --labels-folder /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/MVMT/inputs/labels --output-folder /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic --classes ABCO CADE PILA PIPJ PSME --remove-old', returncode=0)

# %% [markdown]
# # Show some of the formatted example images

# %%
cmap_file = Path(TRAINING_DATA_FOLDER_SCRATCH, "colormap.png")
plt.imshow(imread(cmap_file))
plt.show()

vis_folder = Path(TRAINING_DATA_FOLDER_SCRATCH, "vis")
vis_files = list(vis_folder.rglob("*JPG"))
for file in np.random.choice(vis_files, 10):
    print(f"showing {file}")
    plt.imshow(imread(file))
    plt.show()
# Out:
# /tmp/ipykernel_797563/4204227826.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(cmap_file))
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/vis/train/chips_ChipsB_120m_PART_02_101MEDIA_DJI_0674_rgb.JPG
# /tmp/ipykernel_797563/4204227826.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(file))
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/vis/train/lassic_Lassic_120m_pt3_103MEDIA_DJI_0217_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/vis/val/lassic_Lassic_120m_part1_n_103MEDIA_DJI_0229_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/vis/val/lassic_Lassic_120m_pt3_101MEDIA_DJI_0664_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/vis/val/lassic_Lassic_120m_pt3_101MEDIA_DJI_0664_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/vis/val/delta_DeltaB_120m_PART_01_102MEDIA_DJI_0061_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/vis/val/delta_DeltaB_120m_PART_01_102MEDIA_DJI_0691_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/vis/val/delta_DeltaB_120m_PART_01_102MEDIA_DJI_0691_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/vis/val/chips_ChipsB_120m_PART_02_101MEDIA_DJI_0226_rgb.JPG
# showing /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/vis/train/delta_DeltaB_120m_PART_03_101MEDIA_DJI_0140_rgb.JPG

# %% [markdown]
# # Train a model

# %%
WORK_DIR_SCRATCH = get_work_dir(training_sites=TRAINING_SITES, is_ortho=False, is_scratch=True)

# Identify the config file as the only python file in the
config_file = list(Path(TRAINING_DATA_FOLDER_SCRATCH).glob("*py"))[0]
subprocess.run(
    f"{MMSEG_PYTHON} {TRAIN_SCRIPT} {config_file} --work-dir {WORK_DIR_SCRATCH}", shell=True
)
# Out:
# 03/06 05:41:43 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1489378479
#     GPU 0: GRID A100X-40C
#     CUDA_HOME: /ofo-share/repos-david/conda/envs/MVMT-stable
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1489378479
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/06 05:41:44 - mmengine - INFO - Config:
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[114.30548906765202, 120.08890504191493, 108.62509230101804],
#     std=[66.45615492825216, 63.69699400286447, 58.64490793335219],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(1024, 1024))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[114.30548906765202, 120.08890504191493, 108.62509230101804],
#         std=[66.45615492825216, 63.69699400286447, 58.64490793335219],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(1024, 1024)),
#     pretrained=None,
#     backbone=dict(
#         type='MixVisionTransformer',
#         in_channels=3,
#         embed_dims=64,
#         num_stages=4,
#         num_layers=[3, 6, 40, 3],
#         num_heads=[1, 2, 5, 8],
#         patch_sizes=[7, 3, 3, 3],
#         sr_ratios=[8, 4, 2, 1],
#         out_indices=(0, 1, 2, 3),
#         mlp_ratio=4,
#         qkv_bias=True,
#         drop_rate=0.0,
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
#         )),
#     decode_head=dict(
#         type='SegformerHead',
#         in_channels=[64, 128, 320, 512],
#         in_index=[0, 1, 2, 3],
#         channels=256,
#         dropout_ratio=0.1,
#         num_classes=5,
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='slide', crop_size=(1024, 1024), stride=(768, 768)))
# dataset_type = 'CityscapesForestsDataset'
# data_root = '/ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic'
# img_suffix = '_rgb.JPG'
# classes = ['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME']
# crop_size = (1024, 1024)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(2048, 1024),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(2048, 1024),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(
#                 type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(
#         type='AdamW', lr=6e-05, betas=(0.9, 0.999), weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             pos_block=dict(decay_mult=0.0),
#             norm=dict(decay_mult=0.0),
#             head=dict(lr_mult=10.0))))
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=1e-06, by_epoch=False, begin=0,
#         end=1500),
#     dict(
#         type='PolyLR',
#         eta_min=0.0,
#         power=1.0,
#         begin=1500,
#         end=10000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=10000, val_interval=1000)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=5000),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# checkpoint = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
# launcher = 'none'
# work_dir = '/ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/work_dir'
#
# 03/06 05:41:54 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 03/06 05:41:54 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /ofo-share/repos-david/mmsegmentation/mmseg/models/builder.py:42: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn(
# /ofo-share/repos-david/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:245: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# /ofo-share/repos-david/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:64: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn(
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:lr=6e-05
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:weight_decay=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:decay_mult=0.0
# 03/06 05:41:58 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.attn.norm.weight:lr=6e-05
# ...
# 03/06 06:51:09 - mmengine - INFO - Iter(train) [ 7100/10000]  lr: 2.0473e-05  eta: 0:22:55  time: 0.4658  data_time: 0.0104  memory: 12679  loss: 0.0101  decode.loss_ce: 0.0101  decode.acc_seg: 93.3518
# 03/06 06:51:33 - mmengine - INFO - Iter(train) [ 7150/10000]  lr: 2.0120e-05  eta: 0:22:31  time: 0.4703  data_time: 0.0114  memory: 12679  loss: 0.0257  decode.loss_ce: 0.0257  decode.acc_seg: 94.2223
# 03/06 06:51:56 - mmengine - INFO - Iter(train) [ 7200/10000]  lr: 1.9767e-05  eta: 0:22:07  time: 0.4678  data_time: 0.0103  memory: 12679  loss: 0.0121  decode.loss_ce: 0.0121  decode.acc_seg: 88.1170
# 03/06 06:52:19 - mmengine - INFO - Iter(train) [ 7250/10000]  lr: 1.9414e-05  eta: 0:21:43  time: 0.4648  data_time: 0.0099  memory: 12679  loss: 0.0098  decode.loss_ce: 0.0098  decode.acc_seg: 94.3739
# 03/06 06:52:43 - mmengine - INFO - Iter(train) [ 7300/10000]  lr: 1.9061e-05  eta: 0:21:20  time: 0.4683  data_time: 0.0111  memory: 12679  loss: 0.0085  decode.loss_ce: 0.0085  decode.acc_seg: 98.6764
# 03/06 06:53:06 - mmengine - INFO - Iter(train) [ 7350/10000]  lr: 1.8708e-05  eta: 0:20:56  time: 0.4665  data_time: 0.0103  memory: 12679  loss: 0.0095  decode.loss_ce: 0.0095  decode.acc_seg: 80.6328
# 03/06 06:53:30 - mmengine - INFO - Iter(train) [ 7400/10000]  lr: 1.8355e-05  eta: 0:20:32  time: 0.4690  data_time: 0.0108  memory: 12679  loss: 0.0109  decode.loss_ce: 0.0109  decode.acc_seg: 96.1860
# 03/06 06:53:53 - mmengine - INFO - Iter(train) [ 7450/10000]  lr: 1.8002e-05  eta: 0:20:08  time: 0.4687  data_time: 0.0110  memory: 12679  loss: 0.0191  decode.loss_ce: 0.0191  decode.acc_seg: 97.7782
# 03/06 06:54:17 - mmengine - INFO - Iter(train) [ 7500/10000]  lr: 1.7649e-05  eta: 0:19:44  time: 0.4771  data_time: 0.0112  memory: 12679  loss: 0.0151  decode.loss_ce: 0.0151  decode.acc_seg: 97.8984
# 03/06 06:54:40 - mmengine - INFO - Iter(train) [ 7550/10000]  lr: 1.7296e-05  eta: 0:19:21  time: 0.4672  data_time: 0.0112  memory: 12679  loss: 0.0111  decode.loss_ce: 0.0111  decode.acc_seg: 90.1119
# 03/06 06:55:03 - mmengine - INFO - Iter(train) [ 7600/10000]  lr: 1.6943e-05  eta: 0:18:57  time: 0.4728  data_time: 0.0120  memory: 12679  loss: 0.0077  decode.loss_ce: 0.0077  decode.acc_seg: 77.2865
# 03/06 06:55:27 - mmengine - INFO - Iter(train) [ 7650/10000]  lr: 1.6590e-05  eta: 0:18:33  time: 0.4675  data_time: 0.0113  memory: 12679  loss: 0.0102  decode.loss_ce: 0.0102  decode.acc_seg: 91.4588
# 03/06 06:55:50 - mmengine - INFO - Iter(train) [ 7700/10000]  lr: 1.6237e-05  eta: 0:18:09  time: 0.4666  data_time: 0.0100  memory: 12679  loss: 0.0147  decode.loss_ce: 0.0147  decode.acc_seg: 96.4430
# 03/06 06:56:13 - mmengine - INFO - Iter(train) [ 7750/10000]  lr: 1.5884e-05  eta: 0:17:45  time: 0.4662  data_time: 0.0106  memory: 12679  loss: 0.0279  decode.loss_ce: 0.0279  decode.acc_seg: 98.9495
# 03/06 06:56:37 - mmengine - INFO - Iter(train) [ 7800/10000]  lr: 1.5531e-05  eta: 0:17:22  time: 0.4722  data_time: 0.0122  memory: 12679  loss: 0.0047  decode.loss_ce: 0.0047  decode.acc_seg: 97.0777
# 03/06 06:57:00 - mmengine - INFO - Iter(train) [ 7850/10000]  lr: 1.5178e-05  eta: 0:16:58  time: 0.4649  data_time: 0.0100  memory: 12679  loss: 0.0258  decode.loss_ce: 0.0258  decode.acc_seg: 95.3253
# 03/06 06:57:24 - mmengine - INFO - Iter(train) [ 7900/10000]  lr: 1.4825e-05  eta: 0:16:34  time: 0.4634  data_time: 0.0099  memory: 12679  loss: 0.0132  decode.loss_ce: 0.0132  decode.acc_seg: 92.4652
# 03/06 06:57:47 - mmengine - INFO - Iter(train) [ 7950/10000]  lr: 1.4472e-05  eta: 0:16:10  time: 0.4771  data_time: 0.0150  memory: 12679  loss: 0.0060  decode.loss_ce: 0.0060  decode.acc_seg: 99.9640
# 03/06 06:58:10 - mmengine - INFO - Exp name: MVMT_chips_delta_lassic_20240306_054141
# 03/06 06:58:10 - mmengine - INFO - Iter(train) [ 8000/10000]  lr: 1.4119e-05  eta: 0:15:47  time: 0.4670  data_time: 0.0107  memory: 12679  loss: 0.0183  decode.loss_ce: 0.0183  decode.acc_seg: 92.6383
# 03/06 06:58:33 - mmengine - INFO - Iter(val) [ 50/265]    eta: 0:01:35  time: 0.4505  data_time: 0.2522  memory: 1865
# 03/06 06:58:53 - mmengine - INFO - Iter(val) [100/265]    eta: 0:01:09  time: 0.3644  data_time: 0.1642  memory: 1865
# 03/06 06:59:13 - mmengine - INFO - Iter(val) [150/265]    eta: 0:00:48  time: 0.4407  data_time: 0.2420  memory: 1865
# 03/06 06:59:34 - mmengine - INFO - Iter(val) [200/265]    eta: 0:00:26  time: 0.3693  data_time: 0.1723  memory: 1865
# 03/06 06:59:55 - mmengine - INFO - Iter(val) [250/265]    eta: 0:00:06  time: 0.4517  data_time: 0.2541  memory: 1865
# 03/06 07:00:00 - mmengine - INFO - per class results:
# 03/06 07:00:00 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 87.95 | 94.23 |
# |  CADE | 87.29 | 91.55 |
# |  PILA | 82.69 | 86.44 |
# |  PIPJ | 86.61 | 92.23 |
# |  PSME | 81.43 |  93.8 |
# +-------+-------+-------+
# 03/06 07:00:00 - mmengine - INFO - Iter(val) [265/265]    aAcc: 92.0200  mIoU: 85.1900  mAcc: 91.6500  data_time: 0.2159  time: 0.4140
# 03/06 07:00:24 - mmengine - INFO - Iter(train) [ 8050/10000]  lr: 1.3766e-05  eta: 0:15:23  time: 0.4680  data_time: 0.0115  memory: 12679  loss: 0.0077  decode.loss_ce: 0.0077  decode.acc_seg: 100.0000
# 03/06 07:00:47 - mmengine - INFO - Iter(train) [ 8100/10000]  lr: 1.3413e-05  eta: 0:14:59  time: 0.4669  data_time: 0.0102  memory: 12679  loss: 0.0049  decode.loss_ce: 0.0049  decode.acc_seg: 97.4165
# 03/06 07:01:10 - mmengine - INFO - Iter(train) [ 8150/10000]  lr: 1.3060e-05  eta: 0:14:35  time: 0.4660  data_time: 0.0099  memory: 12679  loss: 0.0129  decode.loss_ce: 0.0129  decode.acc_seg: 99.2848
# 03/06 07:01:34 - mmengine - INFO - Iter(train) [ 8200/10000]  lr: 1.2707e-05  eta: 0:14:12  time: 0.4759  data_time: 0.0133  memory: 12679  loss: 0.0178  decode.loss_ce: 0.0178  decode.acc_seg: 90.3327
# 03/06 07:01:58 - mmengine - INFO - Iter(train) [ 8250/10000]  lr: 1.2354e-05  eta: 0:13:48  time: 0.4705  data_time: 0.0107  memory: 12679  loss: 0.0111  decode.loss_ce: 0.0111  decode.acc_seg: 76.6071
# 03/06 07:02:22 - mmengine - INFO - Iter(train) [ 8300/10000]  lr: 1.2001e-05  eta: 0:13:24  time: 0.4682  data_time: 0.0105  memory: 12679  loss: 0.0094  decode.loss_ce: 0.0094  decode.acc_seg: 100.0000
# 03/06 07:02:45 - mmengine - INFO - Iter(train) [ 8350/10000]  lr: 1.1648e-05  eta: 0:13:01  time: 0.4779  data_time: 0.0142  memory: 12679  loss: 0.0164  decode.loss_ce: 0.0164  decode.acc_seg: 92.7741
# 03/06 07:03:09 - mmengine - INFO - Iter(train) [ 8400/10000]  lr: 1.1295e-05  eta: 0:12:37  time: 0.4783  data_time: 0.0138  memory: 12679  loss: 0.0107  decode.loss_ce: 0.0107  decode.acc_seg: 88.4157
# 03/06 07:03:33 - mmengine - INFO - Iter(train) [ 8450/10000]  lr: 1.0942e-05  eta: 0:12:13  time: 0.4775  data_time: 0.0135  memory: 12679  loss: 0.0097  decode.loss_ce: 0.0097  decode.acc_seg: 93.1414
# 03/06 07:03:57 - mmengine - INFO - Iter(train) [ 8500/10000]  lr: 1.0589e-05  eta: 0:11:50  time: 0.4698  data_time: 0.0115  memory: 12679  loss: 0.0071  decode.loss_ce: 0.0071  decode.acc_seg: 99.7752
# 03/06 07:04:21 - mmengine - INFO - Iter(train) [ 8550/10000]  lr: 1.0236e-05  eta: 0:11:26  time: 0.4720  data_time: 0.0115  memory: 12679  loss: 0.0129  decode.loss_ce: 0.0129  decode.acc_seg: 91.8354
# 03/06 07:04:44 - mmengine - INFO - Iter(train) [ 8600/10000]  lr: 9.8835e-06  eta: 0:11:02  time: 0.4726  data_time: 0.0124  memory: 12679  loss: 0.0099  decode.loss_ce: 0.0099  decode.acc_seg: 98.9901
# 03/06 07:05:08 - mmengine - INFO - Iter(train) [ 8650/10000]  lr: 9.5305e-06  eta: 0:10:39  time: 0.4688  data_time: 0.0110  memory: 12679  loss: 0.0135  decode.loss_ce: 0.0135  decode.acc_seg: 100.0000
# 03/06 07:05:31 - mmengine - INFO - Iter(train) [ 8700/10000]  lr: 9.1776e-06  eta: 0:10:15  time: 0.4686  data_time: 0.0101  memory: 12679  loss: 0.0081  decode.loss_ce: 0.0081  decode.acc_seg: 87.0846
# 03/06 07:05:54 - mmengine - INFO - Iter(train) [ 8750/10000]  lr: 8.8246e-06  eta: 0:09:51  time: 0.4640  data_time: 0.0096  memory: 12679  loss: 0.0093  decode.loss_ce: 0.0093  decode.acc_seg: 98.0476
# 03/06 07:06:18 - mmengine - INFO - Iter(train) [ 8800/10000]  lr: 8.4716e-06  eta: 0:09:28  time: 0.4709  data_time: 0.0116  memory: 12679  loss: 0.0051  decode.loss_ce: 0.0051  decode.acc_seg: 88.8726
# 03/06 07:06:41 - mmengine - INFO - Iter(train) [ 8850/10000]  lr: 8.1186e-06  eta: 0:09:04  time: 0.4660  data_time: 0.0105  memory: 12679  loss: 0.0213  decode.loss_ce: 0.0213  decode.acc_seg: 98.8337
# 03/06 07:07:05 - mmengine - INFO - Iter(train) [ 8900/10000]  lr: 7.7656e-06  eta: 0:08:40  time: 0.4661  data_time: 0.0105  memory: 12679  loss: 0.0125  decode.loss_ce: 0.0125  decode.acc_seg: 87.3199
# 03/06 07:07:28 - mmengine - INFO - Iter(train) [ 8950/10000]  lr: 7.4126e-06  eta: 0:08:16  time: 0.4658  data_time: 0.0107  memory: 12679  loss: 0.0129  decode.loss_ce: 0.0129  decode.acc_seg: 97.5646
# 03/06 07:07:51 - mmengine - INFO - Exp name: MVMT_chips_delta_lassic_20240306_054141
# 03/06 07:07:51 - mmengine - INFO - Iter(train) [ 9000/10000]  lr: 7.0597e-06  eta: 0:07:53  time: 0.4678  data_time: 0.0107  memory: 12679  loss: 0.0108  decode.loss_ce: 0.0108  decode.acc_seg: 91.1748
# 03/06 07:08:13 - mmengine - INFO - Iter(val) [ 50/265]    eta: 0:01:33  time: 0.4406  data_time: 0.2456  memory: 1865
# 03/06 07:08:33 - mmengine - INFO - Iter(val) [100/265]    eta: 0:01:08  time: 0.3653  data_time: 0.1686  memory: 1865
# 03/06 07:08:53 - mmengine - INFO - Iter(val) [150/265]    eta: 0:00:47  time: 0.4395  data_time: 0.2410  memory: 1865
# 03/06 07:09:13 - mmengine - INFO - Iter(val) [200/265]    eta: 0:00:26  time: 0.3746  data_time: 0.1767  memory: 1865
# 03/06 07:09:34 - mmengine - INFO - Iter(val) [250/265]    eta: 0:00:06  time: 0.4524  data_time: 0.2541  memory: 1865
# 03/06 07:09:40 - mmengine - INFO - per class results:
# 03/06 07:09:40 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 89.83 | 95.19 |
# |  CADE | 88.98 | 93.33 |
# |  PILA | 86.04 | 90.72 |
# |  PIPJ |  88.4 | 93.98 |
# |  PSME | 84.36 |  92.7 |
# +-------+-------+-------+
# 03/06 07:09:40 - mmengine - INFO - Iter(val) [265/265]    aAcc: 93.3500  mIoU: 87.5200  mAcc: 93.1800  data_time: 0.2124  time: 0.4097
# 03/06 07:10:04 - mmengine - INFO - Iter(train) [ 9050/10000]  lr: 6.7067e-06  eta: 0:07:29  time: 0.4688  data_time: 0.0114  memory: 12679  loss: 0.0130  decode.loss_ce: 0.0130  decode.acc_seg: 95.9504
# 03/06 07:10:27 - mmengine - INFO - Iter(train) [ 9100/10000]  lr: 6.3537e-06  eta: 0:07:05  time: 0.4715  data_time: 0.0119  memory: 12679  loss: 0.0113  decode.loss_ce: 0.0113  decode.acc_seg: 91.4826
# 03/06 07:10:51 - mmengine - INFO - Iter(train) [ 9150/10000]  lr: 6.0007e-06  eta: 0:06:42  time: 0.4668  data_time: 0.0106  memory: 12679  loss: 0.0089  decode.loss_ce: 0.0089  decode.acc_seg: 100.0000
# 03/06 07:11:14 - mmengine - INFO - Iter(train) [ 9200/10000]  lr: 5.6477e-06  eta: 0:06:18  time: 0.4676  data_time: 0.0112  memory: 12679  loss: 0.0055  decode.loss_ce: 0.0055  decode.acc_seg: 99.2868
# 03/06 07:11:38 - mmengine - INFO - Iter(train) [ 9250/10000]  lr: 5.2947e-06  eta: 0:05:54  time: 0.4649  data_time: 0.0100  memory: 12679  loss: 0.0071  decode.loss_ce: 0.0071  decode.acc_seg: 85.3446
# 03/06 07:12:01 - mmengine - INFO - Iter(train) [ 9300/10000]  lr: 4.9418e-06  eta: 0:05:31  time: 0.4649  data_time: 0.0102  memory: 12679  loss: 0.0049  decode.loss_ce: 0.0049  decode.acc_seg: 93.9735
# 03/06 07:12:24 - mmengine - INFO - Iter(train) [ 9350/10000]  lr: 4.5888e-06  eta: 0:05:07  time: 0.4691  data_time: 0.0113  memory: 12679  loss: 0.0102  decode.loss_ce: 0.0102  decode.acc_seg: 98.2202
# 03/06 07:12:48 - mmengine - INFO - Iter(train) [ 9400/10000]  lr: 4.2358e-06  eta: 0:04:43  time: 0.4686  data_time: 0.0108  memory: 12679  loss: 0.0081  decode.loss_ce: 0.0081  decode.acc_seg: 98.3092
# 03/06 07:13:11 - mmengine - INFO - Iter(train) [ 9450/10000]  lr: 3.8828e-06  eta: 0:04:20  time: 0.4668  data_time: 0.0110  memory: 12679  loss: 0.0120  decode.loss_ce: 0.0120  decode.acc_seg: 67.0623
# 03/06 07:13:35 - mmengine - INFO - Iter(train) [ 9500/10000]  lr: 3.5298e-06  eta: 0:03:56  time: 0.4665  data_time: 0.0106  memory: 12679  loss: 0.0130  decode.loss_ce: 0.0130  decode.acc_seg: 95.3423
# 03/06 07:13:58 - mmengine - INFO - Iter(train) [ 9550/10000]  lr: 3.1768e-06  eta: 0:03:32  time: 0.4720  data_time: 0.0123  memory: 12679  loss: 0.0090  decode.loss_ce: 0.0090  decode.acc_seg: 96.0456
# 03/06 07:14:22 - mmengine - INFO - Iter(train) [ 9600/10000]  lr: 2.8239e-06  eta: 0:03:09  time: 0.4699  data_time: 0.0114  memory: 12679  loss: 0.0119  decode.loss_ce: 0.0119  decode.acc_seg: 97.4024
# 03/06 07:14:45 - mmengine - INFO - Iter(train) [ 9650/10000]  lr: 2.4709e-06  eta: 0:02:45  time: 0.4700  data_time: 0.0106  memory: 12679  loss: 0.0089  decode.loss_ce: 0.0089  decode.acc_seg: 91.9070
# 03/06 07:15:09 - mmengine - INFO - Iter(train) [ 9700/10000]  lr: 2.1179e-06  eta: 0:02:21  time: 0.4708  data_time: 0.0106  memory: 12679  loss: 0.0159  decode.loss_ce: 0.0159  decode.acc_seg: 100.0000
# 03/06 07:15:32 - mmengine - INFO - Iter(train) [ 9750/10000]  lr: 1.7649e-06  eta: 0:01:58  time: 0.4665  data_time: 0.0100  memory: 12679  loss: 0.0135  decode.loss_ce: 0.0135  decode.acc_seg: 97.6294
# 03/06 07:15:55 - mmengine - INFO - Iter(train) [ 9800/10000]  lr: 1.4119e-06  eta: 0:01:34  time: 0.4667  data_time: 0.0099  memory: 12679  loss: 0.0073  decode.loss_ce: 0.0073  decode.acc_seg: 95.3155
# 03/06 07:16:19 - mmengine - INFO - Iter(train) [ 9850/10000]  lr: 1.0589e-06  eta: 0:01:10  time: 0.4743  data_time: 0.0131  memory: 12679  loss: 0.0101  decode.loss_ce: 0.0101  decode.acc_seg: 97.8364
# 03/06 07:16:42 - mmengine - INFO - Iter(train) [ 9900/10000]  lr: 7.0597e-07  eta: 0:00:47  time: 0.4692  data_time: 0.0112  memory: 12679  loss: 0.0102  decode.loss_ce: 0.0102  decode.acc_seg: 96.0448
# 03/06 07:17:06 - mmengine - INFO - Iter(train) [ 9950/10000]  lr: 3.5298e-07  eta: 0:00:23  time: 0.4682  data_time: 0.0111  memory: 12679  loss: 0.0049  decode.loss_ce: 0.0049  decode.acc_seg: 98.8582
# 03/06 07:17:29 - mmengine - INFO - Exp name: MVMT_chips_delta_lassic_20240306_054141
# 03/06 07:17:29 - mmengine - INFO - Iter(train) [10000/10000]  lr: 0.0000e+00  eta: 0:00:00  time: 0.4669  data_time: 0.0102  memory: 12679  loss: 0.0117  decode.loss_ce: 0.0117  decode.acc_seg: 94.2351
# 03/06 07:17:29 - mmengine - INFO - Saving checkpoint at 10000 iterations
# 03/06 07:17:56 - mmengine - INFO - Iter(val) [ 50/265]    eta: 0:01:33  time: 0.4412  data_time: 0.2431  memory: 1865
# 03/06 07:18:16 - mmengine - INFO - Iter(val) [100/265]    eta: 0:01:09  time: 0.3750  data_time: 0.1771  memory: 1865
# 03/06 07:18:37 - mmengine - INFO - Iter(val) [150/265]    eta: 0:00:47  time: 0.4473  data_time: 0.2455  memory: 1865
# 03/06 07:18:57 - mmengine - INFO - Iter(val) [200/265]    eta: 0:00:26  time: 0.3732  data_time: 0.1749  memory: 1865
# 03/06 07:19:18 - mmengine - INFO - Iter(val) [250/265]    eta: 0:00:06  time: 0.4406  data_time: 0.2400  memory: 1865
# 03/06 07:19:23 - mmengine - INFO - per class results:
# 03/06 07:19:23 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 90.07 | 95.45 |
# |  CADE | 88.89 |  92.1 |
# |  PILA | 86.66 | 92.13 |
# |  PIPJ | 88.77 | 95.07 |
# |  PSME | 85.16 | 92.32 |
# +-------+-------+-------+
# 03/06 07:19:23 - mmengine - INFO - Iter(val) [265/265]    aAcc: 93.5800  mIoU: 87.9100  mAcc: 93.4100  data_time: 0.2125  time: 0.4120
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/openmmlab/bin/python /ofo-share/repos-david/mmsegmentation/tools/train.py /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/MVMT_chips_delta_lassic.py --work-dir /ofo-share/scratch-derek/organized-str-disp-MVMT-experiments_scratch/models/multi_site/MVMT_chips_delta_lassic/work_dir', returncode=0)

# %% [markdown]
# # Move resuts from scratch

# %%
TRAINING_DATA_FOLDER = get_training_data_folder(training_sites=TRAINING_SITES, is_ortho=False, is_scratch=False)
shutil.move(TRAINING_DATA_FOLDER_SCRATCH, TRAINING_DATA_FOLDER)
# Out:
# PosixPath('/ofo-share/scratch-derek/organized-str-disp-MVMT-experiments/models/multi_site/MVMT_chips_delta_lassic')
