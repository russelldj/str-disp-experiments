# %%
# Standard library imports
import subprocess
import json
import shutil
import sys

# Contributed library imports
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread
from pathlib import Path

# Imports from the constants
sys.path.append("../..")
from constants import (
    get_aggregated_images_folder,
    get_aggregated_labels_folder,
    get_images_near_labels_folder,
    get_render_folder,
    get_training_data_scratch_folder,
    MMSEG_PYTHON,
    TRAIN_SCRIPT,
    MMSEG_UTILS_PYTHON,
    FOLDER_TO_CITYSCAPES_SCRIPT,
    get_work_dir,
)

# %% [markdown]
# # Set constants
# You should be able to define most of the behavior from these constants

# %%
TRAINING_SITES = sorted(["chips", "lassic"])

# %%
AGGREGATED_IMAGES_FOLDER = get_aggregated_images_folder(training_sites=TRAINING_SITES, is_ortho=False)
AGGREGATED_LABELS_FOLDER = get_aggregated_labels_folder(training_sites=TRAINING_SITES, is_ortho=False)

# We need to merge all the imagery together
# I think this should be stored in the models folder, alongside the real models
# It should be as simple as creating the folders and symlinking the existing ones into it
Path(AGGREGATED_IMAGES_FOLDER).mkdir(exist_ok=True, parents=True)
Path(AGGREGATED_LABELS_FOLDER).mkdir(exist_ok=True, parents=True)

for training_site in TRAINING_SITES:
    render_folder = get_render_folder(training_site)
    images_near_labels_folder = get_images_near_labels_folder(training_site)

    output_render_folder = Path(AGGREGATED_LABELS_FOLDER, training_site)
    output_image_folder = Path(AGGREGATED_IMAGES_FOLDER, training_site)

    # Unlink if symlink
    output_render_folder.unlink(missing_ok=True)
    output_image_folder.unlink(missing_ok=True)
    # Remove if folder
    shutil.rmtree(output_render_folder, ignore_errors=True)
    shutil.rmtree(output_image_folder, ignore_errors=True)

    shutil.copytree(render_folder, output_render_folder)
    shutil.copytree(images_near_labels_folder, output_image_folder)

# %%
TRAINING_DATA_FOLDER_SCRATCH = get_training_data_scratch_folder(
    training_sites=TRAINING_SITES, is_ortho=False
)

# Use one of the render folders, assuming they are all the same
IDs_to_labels_file = Path(render_folder, "IDs_to_labels.json")
with open(IDs_to_labels_file, "r") as infile:
    data = json.load(infile)

class_names = list(data.values())
class_names_str = " ".join(class_names)
print(class_names_str)

run_str = (
    f"{MMSEG_UTILS_PYTHON} {FOLDER_TO_CITYSCAPES_SCRIPT} --images-folder {AGGREGATED_IMAGES_FOLDER}"
    + f" --labels-folder {AGGREGATED_LABELS_FOLDER} --output-folder {TRAINING_DATA_FOLDER_SCRATCH} --classes {class_names_str} --remove-old"
)
print(run_str)
subprocess.run(
    run_str,
    shell=True,
)
# Out:
# ABCO CADE PILA PIPJ PSME
# /ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/MVMT/inputs/images --labels-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/MVMT/inputs/labels --output-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic --classes ABCO CADE PILA PIPJ PSME --remove-old
# Checking for completely null images: 100%|██████████| 933/933 [01:20<00:00, 11.58it/s]
# Linking files into either train or test folders: 100%|██████████| 791/791 [00:00<00:00, 11295.05it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.25it/s]
# (3992372, 3)
# mean: [115.26468450334788, 120.65501937194229, 105.57726709835657], std: [70.67909778684195, 68.4115768593933, 62.807070217888175]
# About to save config to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/MVMT_chips_lassic.py
# visualizing to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/vis/train: 100%|██████████| 11/11 [00:23<00:00,  2.15s/it]
# visualizing to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/vis/val: 100%|██████████| 11/11 [00:23<00:00,  2.15s/it]
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/MVMT/inputs/images --labels-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/MVMT/inputs/labels --output-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic --classes ABCO CADE PILA PIPJ PSME --remove-old', returncode=0)

# %% [markdown]
# # Show some of the formatted example images

# %%
cmap_file = Path(TRAINING_DATA_FOLDER_SCRATCH, "colormap.png")
plt.imshow(imread(cmap_file))
plt.show()

vis_folder = Path(TRAINING_DATA_FOLDER_SCRATCH, "vis")
vis_files = list(vis_folder.rglob("*JPG"))
for file in np.random.choice(vis_files, 10):
    print(f"showing {file}")
    plt.imshow(imread(file))
    plt.show()
# Out:
# /tmp/ipykernel_8227/4204227826.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(cmap_file))
# /tmp/ipykernel_8227/4204227826.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(file))
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/vis/val/chips_ChipsB_80m_2021_complete_SD_card_25_103MEDIA_DJI_0956_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/vis/train/lassic_Lassic_80m_pt3_ns_100MEDIA_DJI_0623_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/vis/train/lassic_Lassic_80m_pt3_ew_104MEDIA_DJI_0814_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/vis/train/lassic_Lassic_80m_pt3_ns_101MEDIA_DJI_0419_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/vis/train/lassic_Lassic_80m_pt1_ns_104MEDIA_DJI_0577_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/vis/val/lassic_Lassic_80m_pt3_ns_101MEDIA_DJI_0207_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/vis/train/chips_ChipsB_80m_2021_complete_SD_card_25_103MEDIA_DJI_0935_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/vis/train/chips_ChipsB_80m_2021_complete_SD_card_26_101MEDIA_DJI_0343_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/vis/val/lassic_Lassic_80m_pt2_ew_105MEDIA_DJI_0532_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/vis/val/chips_ChipsB_80m_2021_complete_SD_card_25_104MEDIA_DJI_0115_rgb.JPG

# %% [markdown]
# # Train a model

# %%
WORK_DIR = get_work_dir(training_sites=TRAINING_SITES, is_ortho=False)

# Identify the config file as the only python file in the
config_file = list(Path(TRAINING_DATA_FOLDER_SCRATCH).glob("*py"))[0]
subprocess.run(
    f"{MMSEG_PYTHON} {TRAIN_SCRIPT} {config_file} --work-dir {WORK_DIR}", shell=True
)
# Out:
# 02/21 17:32:38 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1623452227
#     GPU 0: GRID A100X-20C
#     CUDA_HOME: /ofo-share/repos-david/conda/envs/MVMT-stable
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1623452227
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/21 17:32:39 - mmengine - INFO - Config:
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[115.26468450334788, 120.65501937194229, 105.57726709835657],
#     std=[70.67909778684195, 68.4115768593933, 62.807070217888175],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(1024, 1024))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[115.26468450334788, 120.65501937194229, 105.57726709835657],
#         std=[70.67909778684195, 68.4115768593933, 62.807070217888175],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(1024, 1024)),
#     pretrained=None,
#     backbone=dict(
#         type='MixVisionTransformer',
#         in_channels=3,
#         embed_dims=64,
#         num_stages=4,
#         num_layers=[3, 6, 40, 3],
#         num_heads=[1, 2, 5, 8],
#         patch_sizes=[7, 3, 3, 3],
#         sr_ratios=[8, 4, 2, 1],
#         out_indices=(0, 1, 2, 3),
#         mlp_ratio=4,
#         qkv_bias=True,
#         drop_rate=0.0,
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
#         )),
#     decode_head=dict(
#         type='SegformerHead',
#         in_channels=[64, 128, 320, 512],
#         in_index=[0, 1, 2, 3],
#         channels=256,
#         dropout_ratio=0.1,
#         num_classes=5,
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='slide', crop_size=(1024, 1024), stride=(768, 768)))
# dataset_type = 'CityscapesForestsDataset'
# data_root = '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic'
# img_suffix = '_rgb.JPG'
# classes = ['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME']
# crop_size = (1024, 1024)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(2048, 1024),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(2048, 1024),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(
#                 type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPJ', 'PSME'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(
#         type='AdamW', lr=6e-05, betas=(0.9, 0.999), weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             pos_block=dict(decay_mult=0.0),
#             norm=dict(decay_mult=0.0),
#             head=dict(lr_mult=10.0))))
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=1e-06, by_epoch=False, begin=0,
#         end=1500),
#     dict(
#         type='PolyLR',
#         eta_min=0.0,
#         power=1.0,
#         begin=1500,
#         end=10000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=10000, val_interval=1000)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=5000),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# checkpoint = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
# launcher = 'none'
# work_dir = '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/MVMT_chips_lassic/work_dir'
# /ofo-share/repos-david/mmsegmentation/mmseg/models/builder.py:42: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn(
# /ofo-share/repos-david/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:245: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 02/21 17:32:49 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/21 17:32:49 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /ofo-share/repos-david/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:64: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn(
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:weight_decay=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:decay_mult=0.0
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.attn.norm.weight:lr=6e-05
# 02/21 17:32:52 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.attn.norm.weight:weight_decay=0.0
# ...
# 02/21 18:01:46 - mmengine - INFO - Iter(train) [ 3300/10000]  lr: 4.7300e-05  eta: 0:52:11  time: 0.4602  data_time: 0.0095  memory: 12679  loss: 0.0210  decode.loss_ce: 0.0210  decode.acc_seg: 90.3847
# 02/21 18:02:09 - mmengine - INFO - Iter(train) [ 3350/10000]  lr: 4.6947e-05  eta: 0:51:47  time: 0.4614  data_time: 0.0096  memory: 12679  loss: 0.0428  decode.loss_ce: 0.0428  decode.acc_seg: 89.9078
# 02/21 18:02:33 - mmengine - INFO - Iter(train) [ 3400/10000]  lr: 4.6594e-05  eta: 0:51:24  time: 0.4633  data_time: 0.0108  memory: 12679  loss: 0.0327  decode.loss_ce: 0.0327  decode.acc_seg: 37.3926
# 02/21 18:02:56 - mmengine - INFO - Iter(train) [ 3450/10000]  lr: 4.6241e-05  eta: 0:51:00  time: 0.4584  data_time: 0.0091  memory: 12679  loss: 0.0310  decode.loss_ce: 0.0310  decode.acc_seg: 95.9168
# 02/21 18:03:18 - mmengine - INFO - Iter(train) [ 3500/10000]  lr: 4.5888e-05  eta: 0:50:36  time: 0.4587  data_time: 0.0089  memory: 12679  loss: 0.0301  decode.loss_ce: 0.0301  decode.acc_seg: 87.6108
# 02/21 18:03:41 - mmengine - INFO - Iter(train) [ 3550/10000]  lr: 4.5535e-05  eta: 0:50:11  time: 0.4552  data_time: 0.0085  memory: 12679  loss: 0.0339  decode.loss_ce: 0.0339  decode.acc_seg: 100.0000
# 02/21 18:04:04 - mmengine - INFO - Iter(train) [ 3600/10000]  lr: 4.5182e-05  eta: 0:49:47  time: 0.4579  data_time: 0.0085  memory: 12679  loss: 0.0258  decode.loss_ce: 0.0258  decode.acc_seg: 100.0000
# 02/21 18:04:27 - mmengine - INFO - Iter(train) [ 3650/10000]  lr: 4.4829e-05  eta: 0:49:23  time: 0.4608  data_time: 0.0097  memory: 12679  loss: 0.0232  decode.loss_ce: 0.0232  decode.acc_seg: 65.1012
# 02/21 18:04:50 - mmengine - INFO - Iter(train) [ 3700/10000]  lr: 4.4476e-05  eta: 0:48:59  time: 0.4568  data_time: 0.0081  memory: 12679  loss: 0.0311  decode.loss_ce: 0.0311  decode.acc_seg: 94.5280
# 02/21 18:05:13 - mmengine - INFO - Iter(train) [ 3750/10000]  lr: 4.4123e-05  eta: 0:48:35  time: 0.4592  data_time: 0.0083  memory: 12679  loss: 0.0794  decode.loss_ce: 0.0794  decode.acc_seg: 100.0000
# 02/21 18:05:36 - mmengine - INFO - Iter(train) [ 3800/10000]  lr: 4.3770e-05  eta: 0:48:11  time: 0.4589  data_time: 0.0086  memory: 12679  loss: 0.0392  decode.loss_ce: 0.0392  decode.acc_seg: 91.8356
# 02/21 18:05:59 - mmengine - INFO - Iter(train) [ 3850/10000]  lr: 4.3417e-05  eta: 0:47:47  time: 0.4611  data_time: 0.0104  memory: 12679  loss: 0.0200  decode.loss_ce: 0.0200  decode.acc_seg: 96.3612
# 02/21 18:06:22 - mmengine - INFO - Iter(train) [ 3900/10000]  lr: 4.3064e-05  eta: 0:47:24  time: 0.4627  data_time: 0.0101  memory: 12679  loss: 0.0453  decode.loss_ce: 0.0453  decode.acc_seg: 92.2590
# 02/21 18:06:45 - mmengine - INFO - Iter(train) [ 3950/10000]  lr: 4.2711e-05  eta: 0:47:00  time: 0.4610  data_time: 0.0098  memory: 12679  loss: 0.0353  decode.loss_ce: 0.0353  decode.acc_seg: 99.1074
# 02/21 18:07:08 - mmengine - INFO - Exp name: MVMT_chips_lassic_20240221_173236
# 02/21 18:07:08 - mmengine - INFO - Iter(train) [ 4000/10000]  lr: 4.2358e-05  eta: 0:46:36  time: 0.4573  data_time: 0.0086  memory: 12679  loss: 0.0501  decode.loss_ce: 0.0501  decode.acc_seg: 85.4924
# 02/21 18:07:29 - mmengine - INFO - Iter(val) [ 50/158]    eta: 0:00:44  time: 0.4139  data_time: 0.2151  memory: 1906
# 02/21 18:07:48 - mmengine - INFO - Iter(val) [100/158]    eta: 0:00:23  time: 0.3631  data_time: 0.1638  memory: 1865
# 02/21 18:08:08 - mmengine - INFO - Iter(val) [150/158]    eta: 0:00:03  time: 0.4280  data_time: 0.2307  memory: 1865
# 02/21 18:08:10 - mmengine - INFO - per class results:
# 02/21 18:08:10 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 78.41 | 84.18 |
# |  CADE | 82.21 | 91.58 |
# |  PILA | 58.78 | 90.56 |
# |  PIPJ | 80.38 |  92.6 |
# |  PSME | 63.36 |  66.7 |
# +-------+-------+-------+
# 02/21 18:08:10 - mmengine - INFO - Iter(val) [158/158]    aAcc: 84.6600  mIoU: 72.6300  mAcc: 85.1200  data_time: 0.1946  time: 0.3924
# 02/21 18:08:33 - mmengine - INFO - Iter(train) [ 4050/10000]  lr: 4.2005e-05  eta: 0:46:13  time: 0.4612  data_time: 0.0103  memory: 12679  loss: 0.0189  decode.loss_ce: 0.0189  decode.acc_seg: 83.7649
# 02/21 18:08:56 - mmengine - INFO - Iter(train) [ 4100/10000]  lr: 4.1652e-05  eta: 0:45:49  time: 0.4588  data_time: 0.0101  memory: 12679  loss: 0.0473  decode.loss_ce: 0.0473  decode.acc_seg: 97.5144
# 02/21 18:09:19 - mmengine - INFO - Iter(train) [ 4150/10000]  lr: 4.1299e-05  eta: 0:45:25  time: 0.4648  data_time: 0.0113  memory: 12679  loss: 0.0392  decode.loss_ce: 0.0392  decode.acc_seg: 90.8991
# 02/21 18:09:42 - mmengine - INFO - Iter(train) [ 4200/10000]  lr: 4.0946e-05  eta: 0:45:01  time: 0.4595  data_time: 0.0095  memory: 12679  loss: 0.0558  decode.loss_ce: 0.0558  decode.acc_seg: 90.9752
# 02/21 18:10:05 - mmengine - INFO - Iter(train) [ 4250/10000]  lr: 4.0593e-05  eta: 0:44:38  time: 0.4557  data_time: 0.0082  memory: 12679  loss: 0.0222  decode.loss_ce: 0.0222  decode.acc_seg: 100.0000
# 02/21 18:10:28 - mmengine - INFO - Iter(train) [ 4300/10000]  lr: 4.0240e-05  eta: 0:44:14  time: 0.4588  data_time: 0.0090  memory: 12679  loss: 0.0383  decode.loss_ce: 0.0383  decode.acc_seg: 85.7306
# 02/21 18:10:51 - mmengine - INFO - Iter(train) [ 4350/10000]  lr: 3.9887e-05  eta: 0:43:50  time: 0.4590  data_time: 0.0089  memory: 12679  loss: 0.0147  decode.loss_ce: 0.0147  decode.acc_seg: 95.0216
# 02/21 18:11:14 - mmengine - INFO - Iter(train) [ 4400/10000]  lr: 3.9534e-05  eta: 0:43:26  time: 0.4563  data_time: 0.0081  memory: 12679  loss: 0.0300  decode.loss_ce: 0.0300  decode.acc_seg: 86.7603
# 02/21 18:11:37 - mmengine - INFO - Iter(train) [ 4450/10000]  lr: 3.9181e-05  eta: 0:43:02  time: 0.4566  data_time: 0.0082  memory: 12679  loss: 0.0345  decode.loss_ce: 0.0345  decode.acc_seg: 100.0000
# 02/21 18:12:00 - mmengine - INFO - Iter(train) [ 4500/10000]  lr: 3.8828e-05  eta: 0:42:39  time: 0.4586  data_time: 0.0091  memory: 12679  loss: 0.0273  decode.loss_ce: 0.0273  decode.acc_seg: 97.9211
# 02/21 18:12:23 - mmengine - INFO - Iter(train) [ 4550/10000]  lr: 3.8475e-05  eta: 0:42:15  time: 0.4605  data_time: 0.0090  memory: 12679  loss: 0.0318  decode.loss_ce: 0.0318  decode.acc_seg: 93.8050
# 02/21 18:12:46 - mmengine - INFO - Iter(train) [ 4600/10000]  lr: 3.8122e-05  eta: 0:41:52  time: 0.4594  data_time: 0.0097  memory: 12679  loss: 0.0344  decode.loss_ce: 0.0344  decode.acc_seg: 87.6950
# 02/21 18:13:09 - mmengine - INFO - Iter(train) [ 4650/10000]  lr: 3.7769e-05  eta: 0:41:28  time: 0.4596  data_time: 0.0099  memory: 12679  loss: 0.0431  decode.loss_ce: 0.0431  decode.acc_seg: 100.0000
# 02/21 18:13:32 - mmengine - INFO - Iter(train) [ 4700/10000]  lr: 3.7416e-05  eta: 0:41:05  time: 0.4604  data_time: 0.0106  memory: 12679  loss: 0.0416  decode.loss_ce: 0.0416  decode.acc_seg: 87.7359
# 02/21 18:13:55 - mmengine - INFO - Iter(train) [ 4750/10000]  lr: 3.7063e-05  eta: 0:40:41  time: 0.4605  data_time: 0.0097  memory: 12679  loss: 0.0464  decode.loss_ce: 0.0464  decode.acc_seg: 82.7304
# 02/21 18:14:18 - mmengine - INFO - Iter(train) [ 4800/10000]  lr: 3.6710e-05  eta: 0:40:17  time: 0.4590  data_time: 0.0094  memory: 12679  loss: 0.0123  decode.loss_ce: 0.0123  decode.acc_seg: 93.6510
# 02/21 18:14:40 - mmengine - INFO - Iter(train) [ 4850/10000]  lr: 3.6357e-05  eta: 0:39:54  time: 0.4551  data_time: 0.0082  memory: 12679  loss: 0.0193  decode.loss_ce: 0.0193  decode.acc_seg: 92.3329
# 02/21 18:15:03 - mmengine - INFO - Iter(train) [ 4900/10000]  lr: 3.6004e-05  eta: 0:39:30  time: 0.4565  data_time: 0.0087  memory: 12679  loss: 0.0234  decode.loss_ce: 0.0234  decode.acc_seg: 84.0187
# 02/21 18:15:26 - mmengine - INFO - Iter(train) [ 4950/10000]  lr: 3.5651e-05  eta: 0:39:06  time: 0.4551  data_time: 0.0084  memory: 12679  loss: 0.0196  decode.loss_ce: 0.0196  decode.acc_seg: 94.0449
# 02/21 18:15:49 - mmengine - INFO - Exp name: MVMT_chips_lassic_20240221_173236
# 02/21 18:15:49 - mmengine - INFO - Iter(train) [ 5000/10000]  lr: 3.5298e-05  eta: 0:38:43  time: 0.4590  data_time: 0.0097  memory: 12679  loss: 0.0244  decode.loss_ce: 0.0244  decode.acc_seg: 90.1900
# 02/21 18:15:49 - mmengine - INFO - Saving checkpoint at 5000 iterations
# 02/21 18:16:15 - mmengine - INFO - Iter(val) [ 50/158]    eta: 0:00:46  time: 0.4396  data_time: 0.2424  memory: 1906
# 02/21 18:16:34 - mmengine - INFO - Iter(val) [100/158]    eta: 0:00:23  time: 0.3615  data_time: 0.1652  memory: 1865
# 02/21 18:16:55 - mmengine - INFO - Iter(val) [150/158]    eta: 0:00:03  time: 0.4411  data_time: 0.2447  memory: 1865
# 02/21 18:16:57 - mmengine - INFO - per class results:
# 02/21 18:16:57 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 82.17 | 86.74 |
# |  CADE | 85.25 | 92.76 |
# |  PILA | 66.26 | 73.71 |
# |  PIPJ | 82.78 | 92.05 |
# |  PSME | 75.44 | 90.99 |
# +-------+-------+-------+
# 02/21 18:16:57 - mmengine - INFO - Iter(val) [158/158]    aAcc: 88.5200  mIoU: 78.3800  mAcc: 87.2500  data_time: 0.2083  time: 0.4055
# 02/21 18:17:20 - mmengine - INFO - Iter(train) [ 5050/10000]  lr: 3.4945e-05  eta: 0:38:19  time: 0.4574  data_time: 0.0085  memory: 12679  loss: 0.0375  decode.loss_ce: 0.0375  decode.acc_seg: 92.1635
# 02/21 18:17:43 - mmengine - INFO - Iter(train) [ 5100/10000]  lr: 3.4592e-05  eta: 0:37:56  time: 0.4546  data_time: 0.0083  memory: 12679  loss: 0.0115  decode.loss_ce: 0.0115  decode.acc_seg: 72.7794
# 02/21 18:18:06 - mmengine - INFO - Iter(train) [ 5150/10000]  lr: 3.4239e-05  eta: 0:37:32  time: 0.4595  data_time: 0.0101  memory: 12679  loss: 0.0388  decode.loss_ce: 0.0388  decode.acc_seg: 85.6962
# 02/21 18:18:29 - mmengine - INFO - Iter(train) [ 5200/10000]  lr: 3.3886e-05  eta: 0:37:09  time: 0.4585  data_time: 0.0097  memory: 12679  loss: 0.0438  decode.loss_ce: 0.0438  decode.acc_seg: 90.8047
# 02/21 18:18:52 - mmengine - INFO - Iter(train) [ 5250/10000]  lr: 3.3533e-05  eta: 0:36:45  time: 0.4588  data_time: 0.0099  memory: 12679  loss: 0.0463  decode.loss_ce: 0.0463  decode.acc_seg: 92.0424
# 02/21 18:19:15 - mmengine - INFO - Iter(train) [ 5300/10000]  lr: 3.3180e-05  eta: 0:36:22  time: 0.4590  data_time: 0.0101  memory: 12679  loss: 0.0353  decode.loss_ce: 0.0353  decode.acc_seg: 99.6659
# 02/21 18:19:38 - mmengine - INFO - Iter(train) [ 5350/10000]  lr: 3.2827e-05  eta: 0:35:58  time: 0.4570  data_time: 0.0095  memory: 12679  loss: 0.0418  decode.loss_ce: 0.0418  decode.acc_seg: 93.4319
# 02/21 18:20:01 - mmengine - INFO - Iter(train) [ 5400/10000]  lr: 3.2474e-05  eta: 0:35:35  time: 0.4576  data_time: 0.0093  memory: 12679  loss: 0.0396  decode.loss_ce: 0.0396  decode.acc_seg: 96.5556
# 02/21 18:20:24 - mmengine - INFO - Iter(train) [ 5450/10000]  lr: 3.2121e-05  eta: 0:35:11  time: 0.4621  data_time: 0.0132  memory: 12679  loss: 0.0298  decode.loss_ce: 0.0298  decode.acc_seg: 90.5986
# 02/21 18:20:47 - mmengine - INFO - Iter(train) [ 5500/10000]  lr: 3.1768e-05  eta: 0:34:48  time: 0.4577  data_time: 0.0095  memory: 12679  loss: 0.0277  decode.loss_ce: 0.0277  decode.acc_seg: 92.1227
# 02/21 18:21:10 - mmengine - INFO - Iter(train) [ 5550/10000]  lr: 3.1415e-05  eta: 0:34:25  time: 0.4677  data_time: 0.0195  memory: 12679  loss: 0.0224  decode.loss_ce: 0.0224  decode.acc_seg: 100.0000
# 02/21 18:21:33 - mmengine - INFO - Iter(train) [ 5600/10000]  lr: 3.1062e-05  eta: 0:34:02  time: 0.4620  data_time: 0.0098  memory: 12679  loss: 0.0410  decode.loss_ce: 0.0410  decode.acc_seg: 99.5782
# 02/21 18:21:58 - mmengine - INFO - Iter(train) [ 5650/10000]  lr: 3.0709e-05  eta: 0:33:39  time: 0.4850  data_time: 0.0305  memory: 12679  loss: 0.0238  decode.loss_ce: 0.0238  decode.acc_seg: 99.8019
# 02/21 18:22:21 - mmengine - INFO - Iter(train) [ 5700/10000]  lr: 3.0357e-05  eta: 0:33:16  time: 0.4672  data_time: 0.0163  memory: 12679  loss: 0.0515  decode.loss_ce: 0.0515  decode.acc_seg: 89.4891
# 02/21 18:22:44 - mmengine - INFO - Iter(train) [ 5750/10000]  lr: 3.0004e-05  eta: 0:32:53  time: 0.4567  data_time: 0.0089  memory: 12679  loss: 0.0452  decode.loss_ce: 0.0452  decode.acc_seg: 76.6969
# 02/21 18:23:07 - mmengine - INFO - Iter(train) [ 5800/10000]  lr: 2.9651e-05  eta: 0:32:30  time: 0.4650  data_time: 0.0109  memory: 12679  loss: 0.0353  decode.loss_ce: 0.0353  decode.acc_seg: 87.1051
# 02/21 18:23:30 - mmengine - INFO - Iter(train) [ 5850/10000]  lr: 2.9298e-05  eta: 0:32:06  time: 0.4793  data_time: 0.0308  memory: 12679  loss: 0.0261  decode.loss_ce: 0.0261  decode.acc_seg: 93.9172
# 02/21 18:23:54 - mmengine - INFO - Iter(train) [ 5900/10000]  lr: 2.8945e-05  eta: 0:31:44  time: 0.4729  data_time: 0.0126  memory: 12679  loss: 0.0186  decode.loss_ce: 0.0186  decode.acc_seg: 83.5904
# 02/21 18:24:18 - mmengine - INFO - Iter(train) [ 5950/10000]  lr: 2.8592e-05  eta: 0:31:21  time: 0.4666  data_time: 0.0121  memory: 12679  loss: 0.0154  decode.loss_ce: 0.0154  decode.acc_seg: 94.5475
# 02/21 18:24:41 - mmengine - INFO - Exp name: MVMT_chips_lassic_20240221_173236
# 02/21 18:24:41 - mmengine - INFO - Iter(train) [ 6000/10000]  lr: 2.8239e-05  eta: 0:30:57  time: 0.4660  data_time: 0.0124  memory: 12679  loss: 0.0214  decode.loss_ce: 0.0214  decode.acc_seg: 97.4292
# 02/21 18:25:03 - mmengine - INFO - Iter(val) [ 50/158]    eta: 0:00:47  time: 0.4418  data_time: 0.2443  memory: 1906
# 02/21 18:25:23 - mmengine - INFO - Iter(val) [100/158]    eta: 0:00:24  time: 0.3745  data_time: 0.1744  memory: 1865
# 02/21 18:25:44 - mmengine - INFO - Iter(val) [150/158]    eta: 0:00:03  time: 0.4303  data_time: 0.2295  memory: 1865
# 02/21 18:25:46 - mmengine - INFO - per class results:
# 02/21 18:25:46 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 81.49 | 89.08 |
# |  CADE | 87.15 | 94.84 |
# |  PILA |  66.6 | 71.74 |
# |  PIPJ | 82.51 | 89.73 |
# |  PSME | 76.29 |  91.4 |
# +-------+-------+-------+
# 02/21 18:25:46 - mmengine - INFO - Iter(val) [158/158]    aAcc: 88.8500  mIoU: 78.8100  mAcc: 87.3600  data_time: 0.2141  time: 0.4133
# 02/21 18:26:10 - mmengine - INFO - Iter(train) [ 6050/10000]  lr: 2.7886e-05  eta: 0:30:35  time: 0.4707  data_time: 0.0134  memory: 12679  loss: 0.0112  decode.loss_ce: 0.0112  decode.acc_seg: 100.0000
# 02/21 18:26:34 - mmengine - INFO - Iter(train) [ 6100/10000]  lr: 2.7533e-05  eta: 0:30:11  time: 0.4716  data_time: 0.0135  memory: 12679  loss: 0.0354  decode.loss_ce: 0.0354  decode.acc_seg: 91.4163
# 02/21 18:26:57 - mmengine - INFO - Iter(train) [ 6150/10000]  lr: 2.7180e-05  eta: 0:29:48  time: 0.4631  data_time: 0.0104  memory: 12679  loss: 0.0070  decode.loss_ce: 0.0070  decode.acc_seg: 93.0116
# 02/21 18:27:20 - mmengine - INFO - Iter(train) [ 6200/10000]  lr: 2.6827e-05  eta: 0:29:25  time: 0.4663  data_time: 0.0121  memory: 12679  loss: 0.0419  decode.loss_ce: 0.0419  decode.acc_seg: 100.0000
# 02/21 18:27:44 - mmengine - INFO - Iter(train) [ 6250/10000]  lr: 2.6474e-05  eta: 0:29:02  time: 0.4705  data_time: 0.0138  memory: 12679  loss: 0.0194  decode.loss_ce: 0.0194  decode.acc_seg: 93.6137
# 02/21 18:28:07 - mmengine - INFO - Iter(train) [ 6300/10000]  lr: 2.6121e-05  eta: 0:28:39  time: 0.4626  data_time: 0.0108  memory: 12679  loss: 0.0314  decode.loss_ce: 0.0314  decode.acc_seg: 95.1183
# 02/21 18:28:31 - mmengine - INFO - Iter(train) [ 6350/10000]  lr: 2.5768e-05  eta: 0:28:16  time: 0.4696  data_time: 0.0129  memory: 12679  loss: 0.0178  decode.loss_ce: 0.0178  decode.acc_seg: 94.0523
# 02/21 18:28:54 - mmengine - INFO - Iter(train) [ 6400/10000]  lr: 2.5415e-05  eta: 0:27:53  time: 0.4649  data_time: 0.0126  memory: 12679  loss: 0.0275  decode.loss_ce: 0.0275  decode.acc_seg: 92.2129
# 02/21 18:29:18 - mmengine - INFO - Iter(train) [ 6450/10000]  lr: 2.5062e-05  eta: 0:27:30  time: 0.4610  data_time: 0.0102  memory: 12679  loss: 0.0151  decode.loss_ce: 0.0151  decode.acc_seg: 100.0000
# 02/21 18:29:41 - mmengine - INFO - Iter(train) [ 6500/10000]  lr: 2.4709e-05  eta: 0:27:06  time: 0.4686  data_time: 0.0126  memory: 12679  loss: 0.0112  decode.loss_ce: 0.0112  decode.acc_seg: 100.0000
