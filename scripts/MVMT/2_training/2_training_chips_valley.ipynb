# %%
# Standard library imports
import subprocess
import os
import json
import shutil

# Contributed library imports
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread
from pathlib import Path

# %% [markdown]
# # Set constants
# You should be able to define most of the behavior from these constants

# %%
training_sites = ["chips", "valley"]

# %%
## Python interpreter and script locations
MMSEG_UTILS_PYTHON = "/ofo-share/repos-david/conda/envs/mmseg-utils/bin/python"
MMSEG_PYTHON = "/ofo-share/repos-david/conda/envs/openmmlab/bin/python"

FOLDER_TO_CITYSCAPES_SCRIPT = "/ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py"
VIS_PREDS_SCRIPT = "/ofo-share/repos-david/mmsegmentation_utils/dev/visualization/visualize_semantic_labels.py"
TRAIN_SCRIPT = "/ofo-share/repos-david/mmsegmentation/tools/train.py"

LONG_SITE_NAME_DICT = {"valley": "ValleyA", "chips": "ChipsB", "delta": "DeltaB"}

# One folder up from scripts
PROJECT_ROOT = Path(os.path.abspath(""), "..", "..", "..").resolve()
SCRATCH_ROOT = Path(Path.home(), "scratch", "organized_str_disp_MVMT_experiments")

TRAINING_SITES_STR = "_".join(training_sites)

TRAINING_DATA_FOLDER = Path(
    SCRATCH_ROOT,
    "models",
    "multi_site",
    TRAINING_SITES_STR,
)
AGGREGATED_LABELS_FOLDER = Path(TRAINING_DATA_FOLDER, "inputs", "labels")
AGGREGATED_IMAGES_FOLDER = Path(TRAINING_DATA_FOLDER, "inputs", "images")
WORK_DIR = Path(TRAINING_DATA_FOLDER, "work_dir")

# %%
# We need to merge all the imagery together
# I think this should be stored in the models folder, alongside the real models
# It should be as simple as creating the folders and symlinking the existing ones into it
Path(AGGREGATED_IMAGES_FOLDER).mkdir(exist_ok=True, parents=True)
Path(AGGREGATED_LABELS_FOLDER).mkdir(exist_ok=True, parents=True)

for training_site in training_sites:
    long_site_name = LONG_SITE_NAME_DICT[training_site]
    render_folder = Path(
        PROJECT_ROOT,
        "per_site_processing",
        training_site,
        "03_training_data",
        "renders",
    )
    images_near_labels_folder = Path(
        PROJECT_ROOT, "per_site_processing", training_site, "03_training_data", "images_near_labels"
    )
    output_render_folder = Path(AGGREGATED_LABELS_FOLDER, training_site)
    output_image_folder = Path(AGGREGATED_IMAGES_FOLDER, training_site)

    # Unlink if symlink
    output_render_folder.unlink(missing_ok=True)
    output_image_folder.unlink(missing_ok=True)
    # Remove if folder
    shutil.rmtree(output_render_folder, ignore_errors=True)
    shutil.rmtree(output_image_folder, ignore_errors=True)

    shutil.copytree(render_folder, output_render_folder)
    shutil.copytree(images_near_labels_folder, output_image_folder)

# %%
# Use one of the render folders, assuming they are all the same
IDs_to_labels_file = Path(render_folder, "IDs_to_labels.json")
with open(IDs_to_labels_file, "r") as infile:
    data = json.load(infile)

class_names = list(data.values())
class_names_str = " ".join(class_names)
print(class_names_str)

run_str = (
    f"{MMSEG_UTILS_PYTHON} {FOLDER_TO_CITYSCAPES_SCRIPT} --images-folder {AGGREGATED_IMAGES_FOLDER}"
    + f" --labels-folder {AGGREGATED_LABELS_FOLDER} --output-folder {TRAINING_DATA_FOLDER} --classes {class_names_str} --remove-old"
)
print(run_str)
subprocess.run(
    run_str,
    shell=True,
)
# Out:
# ABCO CADE PILA PIPO PSME QUEV SNAG
# /ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/inputs/images --labels-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/inputs/labels --output-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley --classes ABCO CADE PILA PIPO PSME QUEV SNAG --remove-old
# Checking for completely null images: 100%|██████████| 562/562 [00:49<00:00, 11.41it/s]
# Linking files into either train or test folders: 100%|██████████| 499/499 [00:00<00:00, 12706.77it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.92it/s]
# (3992372, 3)
# mean: [114.9329999809637, 121.5565127698521, 106.75362591461918], std: [66.76771942850385, 64.24493966731306, 60.58259509661404]
# About to save config to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/chips_valley.py
# visualizing to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/vis/train: 100%|██████████| 20/20 [00:39<00:00,  1.98s/it]
# visualizing to /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/vis/val: 100%|██████████| 5/5 [00:10<00:00,  2.06s/it]
# CompletedProcess(args='/ofo-share/repos-david/conda/envs/mmseg-utils/bin/python /ofo-share/repos-david/mmsegmentation_utils/dev/dataset_creation/folder_to_cityscapes.py --images-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/inputs/images --labels-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/inputs/labels --output-folder /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley --classes ABCO CADE PILA PIPO PSME QUEV SNAG --remove-old', returncode=0)

# %% [markdown]
# # Show some of the formatted example images

# %%
cmap_file = Path(TRAINING_DATA_FOLDER, "colormap.png")
plt.imshow(imread(cmap_file))
plt.show()

vis_folder = Path(TRAINING_DATA_FOLDER, "vis")
vis_files = list(vis_folder.rglob("*JPG"))
for file in np.random.choice(vis_files, 10):
    print(f"showing {file}")
    plt.imshow(imread(file))
    plt.show()
# Out:
# /tmp/ipykernel_2974/2317022773.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(cmap_file))
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/vis/train/chips_ChipsB_80m_2021_complete_SD_card_26_100MEDIA_DJI_0832_rgb.JPG
# /tmp/ipykernel_2974/2317022773.py:9: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imread(file))
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/vis/train/chips_ChipsB_80m_2021_complete_SD_card_25_104MEDIA_DJI_0056_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/vis/train/chips_ChipsB_80m_2021_complete_SD_card_26_100MEDIA_DJI_0867_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/vis/train/chips_ChipsB_80m_2021_complete_SD_card_26_100MEDIA_DJI_0867_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/vis/train/valley_PART_01_101MEDIA_DJI_0029_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/vis/train/valley_PART_01_101MEDIA_DJI_0330_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/vis/train/chips_ChipsB_80m_2021_complete_SD_card_25_103MEDIA_DJI_0986_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/vis/train/chips_ChipsB_80m_2021_complete_SD_card_26_100MEDIA_DJI_0905_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/vis/train/chips_ChipsB_80m_2021_complete_SD_card_26_101MEDIA_DJI_0529_rgb.JPG
# showing /home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/vis/train/chips_ChipsB_80m_2021_complete_SD_card_26_101MEDIA_DJI_0438_rgb.JPG

# %% [markdown]
# # Train a model

# %%
# Identify the config file as the only python file in the
config_file = list(Path(TRAINING_DATA_FOLDER).glob("*py"))[0]
subprocess.run(
    f"{MMSEG_PYTHON} {TRAIN_SCRIPT} {config_file} --work-dir {WORK_DIR}", shell=True
)
# Out:
# 02/11 17:32:14 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.16 (default, Mar  2 2023, 03:21:46) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1818556067
#     GPU 0: GRID A100X-20C
#     CUDA_HOME: /ofo-share/repos-david/conda/envs/MVMT-stable
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.7.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1818556067
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/11 17:32:15 - mmengine - INFO - Config:
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[114.9329999809637, 121.5565127698521, 106.75362591461918],
#     std=[66.76771942850385, 64.24493966731306, 60.58259509661404],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(1024, 1024))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[114.9329999809637, 121.5565127698521, 106.75362591461918],
#         std=[66.76771942850385, 64.24493966731306, 60.58259509661404],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(1024, 1024)),
#     pretrained=None,
#     backbone=dict(
#         type='MixVisionTransformer',
#         in_channels=3,
#         embed_dims=64,
#         num_stages=4,
#         num_layers=[3, 6, 40, 3],
#         num_heads=[1, 2, 5, 8],
#         patch_sizes=[7, 3, 3, 3],
#         sr_ratios=[8, 4, 2, 1],
#         out_indices=(0, 1, 2, 3),
#         mlp_ratio=4,
#         qkv_bias=True,
#         drop_rate=0.0,
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
#         )),
#     decode_head=dict(
#         type='SegformerHead',
#         in_channels=[64, 128, 320, 512],
#         in_index=[0, 1, 2, 3],
#         channels=256,
#         dropout_ratio=0.1,
#         num_classes=7,
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         align_corners=False,
#         loss_decode=dict(
#             type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='slide', crop_size=(1024, 1024), stride=(768, 768)))
# dataset_type = 'CityscapesForestsDataset'
# data_root = '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley'
# img_suffix = '_rgb.JPG'
# classes = ['ABCO', 'CADE', 'PILA', 'PIPO', 'PSME', 'QUEV', 'SNAG']
# crop_size = (1024, 1024)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         type='RandomResize',
#         scale=(2048, 1024),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPO', 'PSME', 'QUEV', 'SNAG'],
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 type='RandomResize',
#                 scale=(2048, 1024),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(
#                 type='RandomCrop', crop_size=(1024, 1024), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPO', 'PSME', 'QUEV', 'SNAG'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CityscapesForestsDataset',
#         data_root=
#         '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley',
#         img_suffix='_rgb.JPG',
#         classes=['ABCO', 'CADE', 'PILA', 'PIPO', 'PSME', 'QUEV', 'SNAG'],
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 1024), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(
#         type='AdamW', lr=6e-05, betas=(0.9, 0.999), weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             pos_block=dict(decay_mult=0.0),
#             norm=dict(decay_mult=0.0),
#             head=dict(lr_mult=10.0))))
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=1e-06, by_epoch=False, begin=0,
#         end=1500),
#     dict(
#         type='PolyLR',
#         eta_min=0.0,
#         power=1.0,
#         begin=1500,
#         end=10000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=10000, val_interval=1000)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=5000),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# checkpoint = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b5_20220624-658746d9.pth'
# launcher = 'none'
# work_dir = '/home/russelldj/scratch/organized_str_disp_MVMT_experiments/models/multi_site/chips_valley/work_dir'
# /ofo-share/repos-david/mmsegmentation/mmseg/models/builder.py:42: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn(
# /ofo-share/repos-david/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:245: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 02/11 17:32:27 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/11 17:32:27 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /ofo-share/repos-david/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:64: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn(
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.2.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.2.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.3.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.4.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.5.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.2.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.3.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.4.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.5.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.attn.norm.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.6.norm2.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.weight:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:lr=6e-05
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:weight_decay=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.norm1.bias:decay_mult=0.0
# 02/11 17:32:30 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.7.attn.norm.weight:lr=6e-05
# ...
# 02/11 18:07:47 - mmengine - INFO - Iter(train) [ 4250/10000]  lr: 4.0593e-05  eta: 0:44:09  time: 0.4564  data_time: 0.0088  memory: 12682  loss: 0.0195  decode.loss_ce: 0.0195  decode.acc_seg: 100.0000
# 02/11 18:08:10 - mmengine - INFO - Iter(train) [ 4300/10000]  lr: 4.0240e-05  eta: 0:43:46  time: 0.4532  data_time: 0.0082  memory: 12682  loss: 0.0342  decode.loss_ce: 0.0342  decode.acc_seg: 93.9363
# 02/11 18:08:33 - mmengine - INFO - Iter(train) [ 4350/10000]  lr: 3.9887e-05  eta: 0:43:22  time: 0.4542  data_time: 0.0088  memory: 12682  loss: 0.0690  decode.loss_ce: 0.0690  decode.acc_seg: 94.4230
# 02/11 18:08:55 - mmengine - INFO - Iter(train) [ 4400/10000]  lr: 3.9534e-05  eta: 0:42:59  time: 0.4563  data_time: 0.0085  memory: 12682  loss: 0.0396  decode.loss_ce: 0.0396  decode.acc_seg: 83.5611
# 02/11 18:09:18 - mmengine - INFO - Iter(train) [ 4450/10000]  lr: 3.9181e-05  eta: 0:42:36  time: 0.4546  data_time: 0.0086  memory: 12682  loss: 0.0447  decode.loss_ce: 0.0447  decode.acc_seg: 99.9970
# 02/11 18:09:41 - mmengine - INFO - Iter(train) [ 4500/10000]  lr: 3.8828e-05  eta: 0:42:12  time: 0.4561  data_time: 0.0082  memory: 12682  loss: 0.0588  decode.loss_ce: 0.0588  decode.acc_seg: 91.5016
# 02/11 18:10:04 - mmengine - INFO - Iter(train) [ 4550/10000]  lr: 3.8475e-05  eta: 0:41:49  time: 0.4539  data_time: 0.0079  memory: 12682  loss: 0.0626  decode.loss_ce: 0.0626  decode.acc_seg: 95.3049
# 02/11 18:10:27 - mmengine - INFO - Iter(train) [ 4600/10000]  lr: 3.8122e-05  eta: 0:41:26  time: 0.4513  data_time: 0.0075  memory: 12682  loss: 0.0220  decode.loss_ce: 0.0220  decode.acc_seg: 88.1390
# 02/11 18:10:49 - mmengine - INFO - Iter(train) [ 4650/10000]  lr: 3.7769e-05  eta: 0:41:02  time: 0.4526  data_time: 0.0072  memory: 12682  loss: 0.0101  decode.loss_ce: 0.0101  decode.acc_seg: 100.0000
# 02/11 18:11:12 - mmengine - INFO - Iter(train) [ 4700/10000]  lr: 3.7416e-05  eta: 0:40:39  time: 0.4542  data_time: 0.0083  memory: 12682  loss: 0.0250  decode.loss_ce: 0.0250  decode.acc_seg: 89.6489
# 02/11 18:11:35 - mmengine - INFO - Iter(train) [ 4750/10000]  lr: 3.7063e-05  eta: 0:40:15  time: 0.4557  data_time: 0.0084  memory: 12682  loss: 0.0246  decode.loss_ce: 0.0246  decode.acc_seg: 80.2399
# 02/11 18:11:57 - mmengine - INFO - Iter(train) [ 4800/10000]  lr: 3.6710e-05  eta: 0:39:52  time: 0.4538  data_time: 0.0082  memory: 12682  loss: 0.1689  decode.loss_ce: 0.1689  decode.acc_seg: 94.2218
# 02/11 18:12:20 - mmengine - INFO - Iter(train) [ 4850/10000]  lr: 3.6357e-05  eta: 0:39:29  time: 0.4543  data_time: 0.0079  memory: 12682  loss: 0.0260  decode.loss_ce: 0.0260  decode.acc_seg: 95.3187
# 02/11 18:12:43 - mmengine - INFO - Iter(train) [ 4900/10000]  lr: 3.6004e-05  eta: 0:39:06  time: 0.4565  data_time: 0.0088  memory: 12682  loss: 0.0464  decode.loss_ce: 0.0464  decode.acc_seg: 100.0000
# 02/11 18:13:06 - mmengine - INFO - Iter(train) [ 4950/10000]  lr: 3.5651e-05  eta: 0:38:42  time: 0.4561  data_time: 0.0086  memory: 12682  loss: 0.0316  decode.loss_ce: 0.0316  decode.acc_seg: 100.0000
# 02/11 18:13:28 - mmengine - INFO - Exp name: chips_valley_20240211_173212
# 02/11 18:13:28 - mmengine - INFO - Iter(train) [ 5000/10000]  lr: 3.5298e-05  eta: 0:38:19  time: 0.4563  data_time: 0.0088  memory: 12682  loss: 0.0410  decode.loss_ce: 0.0410  decode.acc_seg: 100.0000
# 02/11 18:13:28 - mmengine - INFO - Saving checkpoint at 5000 iterations
# 02/11 18:13:52 - mmengine - INFO - Iter(val) [50/99]    eta: 0:00:19  time: 0.4098  data_time: 0.2088  memory: 2048
# 02/11 18:14:10 - mmengine - INFO - per class results:
# 02/11 18:14:10 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 68.91 | 73.19 |
# |  CADE |  0.0  |  0.0  |
# |  PILA | 70.93 | 90.42 |
# |  PIPO | 85.08 | 96.94 |
# |  PSME | 72.89 | 78.33 |
# |  QUEV | 61.05 | 92.22 |
# |  SNAG | 10.65 |  10.9 |
# +-------+-------+-------+
# 02/11 18:14:10 - mmengine - INFO - Iter(val) [99/99]    aAcc: 86.2600  mIoU: 52.7900  mAcc: 63.1400  data_time: 0.1845  time: 0.3873
# 02/11 18:14:33 - mmengine - INFO - Iter(train) [ 5050/10000]  lr: 3.4945e-05  eta: 0:37:56  time: 0.4554  data_time: 0.0084  memory: 12682  loss: 0.0166  decode.loss_ce: 0.0166  decode.acc_seg: 97.6327
# 02/11 18:14:56 - mmengine - INFO - Iter(train) [ 5100/10000]  lr: 3.4592e-05  eta: 0:37:33  time: 0.4558  data_time: 0.0084  memory: 12682  loss: 0.0264  decode.loss_ce: 0.0264  decode.acc_seg: 83.3257
# 02/11 18:15:19 - mmengine - INFO - Iter(train) [ 5150/10000]  lr: 3.4239e-05  eta: 0:37:10  time: 0.4565  data_time: 0.0084  memory: 12682  loss: 0.0151  decode.loss_ce: 0.0151  decode.acc_seg: 93.4882
# 02/11 18:15:42 - mmengine - INFO - Iter(train) [ 5200/10000]  lr: 3.3886e-05  eta: 0:36:47  time: 0.4592  data_time: 0.0092  memory: 12682  loss: 0.0287  decode.loss_ce: 0.0287  decode.acc_seg: 14.9676
# 02/11 18:16:05 - mmengine - INFO - Iter(train) [ 5250/10000]  lr: 3.3533e-05  eta: 0:36:24  time: 0.4573  data_time: 0.0084  memory: 12682  loss: 0.0152  decode.loss_ce: 0.0152  decode.acc_seg: 100.0000
# 02/11 18:16:27 - mmengine - INFO - Iter(train) [ 5300/10000]  lr: 3.3180e-05  eta: 0:36:00  time: 0.4568  data_time: 0.0083  memory: 12682  loss: 0.0211  decode.loss_ce: 0.0211  decode.acc_seg: 100.0000
# 02/11 18:16:50 - mmengine - INFO - Iter(train) [ 5350/10000]  lr: 3.2827e-05  eta: 0:35:37  time: 0.4572  data_time: 0.0089  memory: 12682  loss: 0.0142  decode.loss_ce: 0.0142  decode.acc_seg: 88.8153
# 02/11 18:17:13 - mmengine - INFO - Iter(train) [ 5400/10000]  lr: 3.2474e-05  eta: 0:35:14  time: 0.4543  data_time: 0.0081  memory: 12682  loss: 0.0120  decode.loss_ce: 0.0120  decode.acc_seg: 84.6894
# 02/11 18:17:36 - mmengine - INFO - Iter(train) [ 5450/10000]  lr: 3.2121e-05  eta: 0:34:51  time: 0.4585  data_time: 0.0094  memory: 12682  loss: 0.0232  decode.loss_ce: 0.0232  decode.acc_seg: 94.3049
# 02/11 18:17:59 - mmengine - INFO - Iter(train) [ 5500/10000]  lr: 3.1768e-05  eta: 0:34:28  time: 0.4550  data_time: 0.0087  memory: 12682  loss: 0.0331  decode.loss_ce: 0.0331  decode.acc_seg: 92.7923
# 02/11 18:18:21 - mmengine - INFO - Iter(train) [ 5550/10000]  lr: 3.1415e-05  eta: 0:34:05  time: 0.4541  data_time: 0.0081  memory: 12682  loss: 0.0258  decode.loss_ce: 0.0258  decode.acc_seg: 79.5073
# 02/11 18:18:44 - mmengine - INFO - Iter(train) [ 5600/10000]  lr: 3.1062e-05  eta: 0:33:42  time: 0.4558  data_time: 0.0084  memory: 12682  loss: 0.0206  decode.loss_ce: 0.0206  decode.acc_seg: 100.0000
# 02/11 18:19:07 - mmengine - INFO - Iter(train) [ 5650/10000]  lr: 3.0709e-05  eta: 0:33:18  time: 0.4552  data_time: 0.0086  memory: 12682  loss: 0.0446  decode.loss_ce: 0.0446  decode.acc_seg: 96.5967
# 02/11 18:19:30 - mmengine - INFO - Iter(train) [ 5700/10000]  lr: 3.0357e-05  eta: 0:32:55  time: 0.4550  data_time: 0.0083  memory: 12682  loss: 0.0192  decode.loss_ce: 0.0192  decode.acc_seg: 97.4962
# 02/11 18:19:53 - mmengine - INFO - Iter(train) [ 5750/10000]  lr: 3.0004e-05  eta: 0:32:32  time: 0.4547  data_time: 0.0086  memory: 12682  loss: 0.0249  decode.loss_ce: 0.0249  decode.acc_seg: 100.0000
# 02/11 18:20:15 - mmengine - INFO - Iter(train) [ 5800/10000]  lr: 2.9651e-05  eta: 0:32:09  time: 0.4566  data_time: 0.0087  memory: 12682  loss: 0.0101  decode.loss_ce: 0.0101  decode.acc_seg: 92.9020
# 02/11 18:20:38 - mmengine - INFO - Iter(train) [ 5850/10000]  lr: 2.9298e-05  eta: 0:31:46  time: 0.4545  data_time: 0.0083  memory: 12682  loss: 0.0360  decode.loss_ce: 0.0360  decode.acc_seg: 96.4026
# 02/11 18:21:01 - mmengine - INFO - Iter(train) [ 5900/10000]  lr: 2.8945e-05  eta: 0:31:23  time: 0.4562  data_time: 0.0087  memory: 12682  loss: 0.0286  decode.loss_ce: 0.0286  decode.acc_seg: 91.5876
# 02/11 18:21:24 - mmengine - INFO - Iter(train) [ 5950/10000]  lr: 2.8592e-05  eta: 0:31:00  time: 0.4570  data_time: 0.0085  memory: 12682  loss: 0.0228  decode.loss_ce: 0.0228  decode.acc_seg: 90.6405
# 02/11 18:21:46 - mmengine - INFO - Exp name: chips_valley_20240211_173212
# 02/11 18:21:46 - mmengine - INFO - Iter(train) [ 6000/10000]  lr: 2.8239e-05  eta: 0:30:37  time: 0.4546  data_time: 0.0081  memory: 12682  loss: 0.0383  decode.loss_ce: 0.0383  decode.acc_seg: 100.0000
# 02/11 18:22:07 - mmengine - INFO - Iter(val) [50/99]    eta: 0:00:19  time: 0.3973  data_time: 0.1969  memory: 2048
# 02/11 18:22:25 - mmengine - INFO - per class results:
# 02/11 18:22:25 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 78.74 | 82.26 |
# |  CADE |  0.0  |  0.0  |
# |  PILA | 74.75 | 88.48 |
# |  PIPO | 87.87 | 94.46 |
# |  PSME | 78.59 | 87.82 |
# |  QUEV | 75.72 | 78.99 |
# |  SNAG | 23.54 | 24.43 |
# +-------+-------+-------+
# 02/11 18:22:25 - mmengine - INFO - Iter(val) [99/99]    aAcc: 89.1000  mIoU: 59.8900  mAcc: 65.2100  data_time: 0.1862  time: 0.3885
# 02/11 18:22:48 - mmengine - INFO - Iter(train) [ 6050/10000]  lr: 2.7886e-05  eta: 0:30:14  time: 0.4531  data_time: 0.0076  memory: 12682  loss: 0.0167  decode.loss_ce: 0.0167  decode.acc_seg: 98.3950
# 02/11 18:23:11 - mmengine - INFO - Iter(train) [ 6100/10000]  lr: 2.7533e-05  eta: 0:29:51  time: 0.4540  data_time: 0.0079  memory: 12682  loss: 0.0245  decode.loss_ce: 0.0245  decode.acc_seg: 100.0000
# 02/11 18:23:33 - mmengine - INFO - Iter(train) [ 6150/10000]  lr: 2.7180e-05  eta: 0:29:27  time: 0.4537  data_time: 0.0077  memory: 12682  loss: 0.0414  decode.loss_ce: 0.0414  decode.acc_seg: 94.0089
# 02/11 18:23:56 - mmengine - INFO - Iter(train) [ 6200/10000]  lr: 2.6827e-05  eta: 0:29:04  time: 0.4547  data_time: 0.0077  memory: 12682  loss: 0.0338  decode.loss_ce: 0.0338  decode.acc_seg: 95.0253
# 02/11 18:24:19 - mmengine - INFO - Iter(train) [ 6250/10000]  lr: 2.6474e-05  eta: 0:28:41  time: 0.4649  data_time: 0.0085  memory: 12682  loss: 0.0216  decode.loss_ce: 0.0216  decode.acc_seg: 99.2692
# 02/11 18:24:42 - mmengine - INFO - Iter(train) [ 6300/10000]  lr: 2.6121e-05  eta: 0:28:18  time: 0.4577  data_time: 0.0086  memory: 12682  loss: 0.0412  decode.loss_ce: 0.0412  decode.acc_seg: 100.0000
# 02/11 18:25:05 - mmengine - INFO - Iter(train) [ 6350/10000]  lr: 2.5768e-05  eta: 0:27:55  time: 0.4567  data_time: 0.0086  memory: 12682  loss: 0.0347  decode.loss_ce: 0.0347  decode.acc_seg: 93.1788
# 02/11 18:25:27 - mmengine - INFO - Iter(train) [ 6400/10000]  lr: 2.5415e-05  eta: 0:27:32  time: 0.4550  data_time: 0.0084  memory: 12682  loss: 0.0291  decode.loss_ce: 0.0291  decode.acc_seg: 88.7012
# 02/11 18:25:50 - mmengine - INFO - Iter(train) [ 6450/10000]  lr: 2.5062e-05  eta: 0:27:09  time: 0.4543  data_time: 0.0079  memory: 12682  loss: 0.0242  decode.loss_ce: 0.0242  decode.acc_seg: 98.9260
# 02/11 18:26:13 - mmengine - INFO - Iter(train) [ 6500/10000]  lr: 2.4709e-05  eta: 0:26:46  time: 0.4545  data_time: 0.0085  memory: 12682  loss: 0.0195  decode.loss_ce: 0.0195  decode.acc_seg: 91.3431
# 02/11 18:26:36 - mmengine - INFO - Iter(train) [ 6550/10000]  lr: 2.4356e-05  eta: 0:26:23  time: 0.4559  data_time: 0.0084  memory: 12682  loss: 0.0379  decode.loss_ce: 0.0379  decode.acc_seg: 100.0000
# 02/11 18:26:58 - mmengine - INFO - Iter(train) [ 6600/10000]  lr: 2.4003e-05  eta: 0:26:00  time: 0.4537  data_time: 0.0079  memory: 12682  loss: 0.0257  decode.loss_ce: 0.0257  decode.acc_seg: 93.2711
# 02/11 18:27:21 - mmengine - INFO - Iter(train) [ 6650/10000]  lr: 2.3650e-05  eta: 0:25:37  time: 0.4541  data_time: 0.0078  memory: 12682  loss: 0.0293  decode.loss_ce: 0.0293  decode.acc_seg: 99.6353
# 02/11 18:27:44 - mmengine - INFO - Iter(train) [ 6700/10000]  lr: 2.3297e-05  eta: 0:25:14  time: 0.4559  data_time: 0.0086  memory: 12682  loss: 0.0130  decode.loss_ce: 0.0130  decode.acc_seg: 100.0000
# 02/11 18:28:07 - mmengine - INFO - Iter(train) [ 6750/10000]  lr: 2.2944e-05  eta: 0:24:51  time: 0.4594  data_time: 0.0106  memory: 12682  loss: 0.0276  decode.loss_ce: 0.0276  decode.acc_seg: 88.0059
# 02/11 18:28:30 - mmengine - INFO - Iter(train) [ 6800/10000]  lr: 2.2591e-05  eta: 0:24:28  time: 0.4550  data_time: 0.0083  memory: 12682  loss: 0.0351  decode.loss_ce: 0.0351  decode.acc_seg: 86.7532
# 02/11 18:28:52 - mmengine - INFO - Iter(train) [ 6850/10000]  lr: 2.2238e-05  eta: 0:24:05  time: 0.4558  data_time: 0.0081  memory: 12682  loss: 0.0322  decode.loss_ce: 0.0322  decode.acc_seg: 91.5346
# 02/11 18:29:15 - mmengine - INFO - Iter(train) [ 6900/10000]  lr: 2.1885e-05  eta: 0:23:42  time: 0.4549  data_time: 0.0078  memory: 12682  loss: 0.0259  decode.loss_ce: 0.0259  decode.acc_seg: 82.3863
# 02/11 18:29:38 - mmengine - INFO - Iter(train) [ 6950/10000]  lr: 2.1532e-05  eta: 0:23:19  time: 0.4566  data_time: 0.0083  memory: 12682  loss: 0.0311  decode.loss_ce: 0.0311  decode.acc_seg: 75.6784
# 02/11 18:30:01 - mmengine - INFO - Exp name: chips_valley_20240211_173212
# 02/11 18:30:01 - mmengine - INFO - Iter(train) [ 7000/10000]  lr: 2.1179e-05  eta: 0:22:56  time: 0.4531  data_time: 0.0077  memory: 12682  loss: 0.0233  decode.loss_ce: 0.0233  decode.acc_seg: 93.9100
# 02/11 18:30:21 - mmengine - INFO - Iter(val) [50/99]    eta: 0:00:19  time: 0.4163  data_time: 0.2150  memory: 2048
# 02/11 18:30:40 - mmengine - INFO - per class results:
# 02/11 18:30:40 - mmengine - INFO -
# +-------+-------+-------+
# | Class |  IoU  |  Acc  |
# +-------+-------+-------+
# |  ABCO | 80.06 | 86.57 |
# |  CADE |  4.21 |  4.32 |
# |  PILA | 77.02 | 86.08 |
# |  PIPO | 87.65 | 97.12 |
# |  PSME | 80.15 |  87.4 |
# |  QUEV | 80.38 | 93.18 |
# |  SNAG | 32.61 | 34.48 |
# +-------+-------+-------+
# 02/11 18:30:40 - mmengine - INFO - Iter(val) [99/99]    aAcc: 89.8800  mIoU: 63.1600  mAcc: 69.8800  data_time: 0.1878  time: 0.3894
# 02/11 18:31:02 - mmengine - INFO - Iter(train) [ 7050/10000]  lr: 2.0826e-05  eta: 0:22:33  time: 0.4542  data_time: 0.0081  memory: 12682  loss: 0.0172  decode.loss_ce: 0.0172  decode.acc_seg: 94.7460
# 02/11 18:31:25 - mmengine - INFO - Iter(train) [ 7100/10000]  lr: 2.0473e-05  eta: 0:22:10  time: 0.4560  data_time: 0.0086  memory: 12682  loss: 0.0347  decode.loss_ce: 0.0347  decode.acc_seg: 99.9755
# 02/11 18:31:48 - mmengine - INFO - Iter(train) [ 7150/10000]  lr: 2.0120e-05  eta: 0:21:47  time: 0.4564  data_time: 0.0093  memory: 12682  loss: 0.0177  decode.loss_ce: 0.0177  decode.acc_seg: 92.5962
# 02/11 18:32:10 - mmengine - INFO - Iter(train) [ 7200/10000]  lr: 1.9767e-05  eta: 0:21:24  time: 0.4539  data_time: 0.0078  memory: 12682  loss: 0.0152  decode.loss_ce: 0.0152  decode.acc_seg: 99.3716
# 02/11 18:32:33 - mmengine - INFO - Iter(train) [ 7250/10000]  lr: 1.9414e-05  eta: 0:21:01  time: 0.4566  data_time: 0.0089  memory: 12682  loss: 0.0220  decode.loss_ce: 0.0220  decode.acc_seg: 91.5839
# 02/11 18:32:56 - mmengine - INFO - Iter(train) [ 7300/10000]  lr: 1.9061e-05  eta: 0:20:38  time: 0.4571  data_time: 0.0087  memory: 12682  loss: 0.0338  decode.loss_ce: 0.0338  decode.acc_seg: 89.3904
# 02/11 18:33:19 - mmengine - INFO - Iter(train) [ 7350/10000]  lr: 1.8708e-05  eta: 0:20:15  time: 0.4566  data_time: 0.0084  memory: 12682  loss: 0.0114  decode.loss_ce: 0.0114  decode.acc_seg: 98.3014
# 02/11 18:33:41 - mmengine - INFO - Iter(train) [ 7400/10000]  lr: 1.8355e-05  eta: 0:19:52  time: 0.4540  data_time: 0.0081  memory: 12682  loss: 0.0199  decode.loss_ce: 0.0199  decode.acc_seg: 100.0000
# 02/11 18:34:04 - mmengine - INFO - Iter(train) [ 7450/10000]  lr: 1.8002e-05  eta: 0:19:29  time: 0.4550  data_time: 0.0083  memory: 12682  loss: 0.0168  decode.loss_ce: 0.0168  decode.acc_seg: 100.0000
# 02/11 18:34:27 - mmengine - INFO - Iter(train) [ 7500/10000]  lr: 1.7649e-05  eta: 0:19:06  time: 0.4588  data_time: 0.0086  memory: 12682  loss: 0.0255  decode.loss_ce: 0.0255  decode.acc_seg: 92.4001
# 02/11 18:34:50 - mmengine - INFO - Iter(train) [ 7550/10000]  lr: 1.7296e-05  eta: 0:18:43  time: 0.4559  data_time: 0.0085  memory: 12682  loss: 0.0256  decode.loss_ce: 0.0256  decode.acc_seg: 91.7008
# 02/11 18:35:13 - mmengine - INFO - Iter(train) [ 7600/10000]  lr: 1.6943e-05  eta: 0:18:20  time: 0.4563  data_time: 0.0086  memory: 12682  loss: 0.0172  decode.loss_ce: 0.0172  decode.acc_seg: 94.2394
